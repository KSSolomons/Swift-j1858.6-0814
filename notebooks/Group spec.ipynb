# %% [markdown]
# # 5. Spectral Grouping
#
# This notebook executes the dedicated grouping script (`05_regroup_spectra.sh`) to apply consistent binning across both the EPIC-pn and RGS instruments using HEASOFT's `ftgrouppha`.
#
# ### Workflow:
# 1. **Run**: Execute the bash script to group the spectra.
# 2. **Verify**: Run the Python sanity check to ensure the `_grp.fits` and `_grp.pha` files were created successfully.

# %%
import os
import glob

# Ensure HEASOFT and SAS are initialized in your environment before running.
os.environ['PROJECT_ROOT'] = '/media/kyle/kyle_phd/Swift-j1858.6-0814/'
os.environ['OBSID'] = '0865600201'

project_root = os.environ.get('PROJECT_ROOT')
obsid = os.environ.get('OBSID')
# %matplotlib notebook

# %%
# Execute the grouping script
# !../scripts/regroup_spectra.sh > logs/regroup_spectra.log 2>&1
print("Grouping script execution finished. Check logs/05_regroup_spectra.log for details.")
# Out:
# Grouping script execution finished. Check logs/05_regroup_spectra.log for details.
