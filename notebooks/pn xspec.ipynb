# %%
import xspec as x
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np
from astropy.io import fits
# %matplotlib widget

# %%
#Load relxill and test it

# --- STEP 1: DEFINE PATHS ---
# Path to the folder where you compiled relxill (contains lmodel.dat)
# relxill_dir = "/home/kyle/software/relxill"

# Path to the folder containing the heavy FITS tables (often the same dir)
# relxill_tables = "/home/kyle/software/relxill"

# --- STEP 2: SET ENVIRONMENT VARIABLE ---
# This tells relxill where to look for the tables so you don't have to copy them
# os.environ["RELXILL_TABLE_PATH"] = relxill_tables

# --- STEP 3: LOAD THE MODEL ---
# This mimics the "lmod relxill /path" command
# print("Loading Relxill...")
# x.AllModels.lmod("relxill", relxill_dir)

# --- STEP 4: USE IT ---
# Now you can use 'relxill', 'relxillCp', 'relxilllp', etc.
# Example: simple relativistic reflection
# m = x.Model("tbabs * relxillns")

# Verify it loaded
# print(m.componentNames)

# %%
# --- 1. SETUP & DATA LOADING ---
x.AllData.clear()
x.AllModels.clear()

# --- PN: interval + full-spectrum options ---
time_intervals_pn = {
    "Full": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_spectrum.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_spectrum.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf.arf",
    },
    "Full_grp": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_spectrum_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_spectrum.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf.arf",
    },
    "Dipping": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Dipping.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Dipping.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Dipping.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Dipping.arf",
    },
    "Dipping_grp": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Dipping_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Dipping.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Dipping.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Dipping.arf",
    },
    "Persistent": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Persistent.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Persistent.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Persistent.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Persistent.arf",
    },
    "Persistent_grp": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Persistent_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Persistent.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Persistent.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Persistent.arf",
    },
    "Shallow": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Shallow.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Shallow.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Shallow.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Shallow.arf",
    },
    "Shallow_grp": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Shallow_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Shallow.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Shallow.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Shallow.arf",
    },
    "Dipping_LowFlux": {
        "pn_spec": "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_LowFlux.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/flux_resolved/pn_bkg_Dipping_LowFlux.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_LowFlux.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_LowFlux.arf",
    },
    "Dipping_LowFlux_grp": {
        "pn_spec": "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_LowFlux_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/flux_resolved/pn_bkg_Dipping_LowFlux.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_LowFlux.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_LowFlux.arf",
    },
    "Dipping_HighFlux": {
        "pn_spec": "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_HighFlux.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/flux_resolved/pn_bkg_Dipping_HighFlux.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_HighFlux.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_HighFlux.arf",
    },
    "Dipping_HighFlux_grp": {
        "pn_spec": "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_HighFlux_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/flux_resolved/pn_bkg_Dipping_HighFlux.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_HighFlux.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_HighFlux.arf",
    },
}

# %%
# Choose: "Full", "Dipping", "Persistent", "Shallow", "Dipping_LowFlux", "Dipping_HighFlux"
def interval_key(interval, grouped=False):
    return f"{interval}_grp" if grouped else interval

base_interval = "Full"
use_grouped = True
use_background = True
run_line_search = False

selected_interval = interval_key(base_interval, use_grouped)
pn_data = time_intervals_pn[selected_interval]

plot_dir = os.path.join("..", "products", "0865600201", "pn", "spec", "plots", selected_interval)
os.makedirs(plot_dir, exist_ok=True)

pn_spec = pn_data["pn_spec"]
pn_bkg  = pn_data["pn_bkg"]
pn_rmf  = pn_data["pn_rmf"]
pn_arf  = pn_data["pn_arf"]

# Load PN (once)the
x.AllData(pn_spec)
s = x.AllData(1)
if use_background:
    s.background = pn_bkg
s.response = pn_rmf
s.response.arf = pn_arf

x.AllData.ignore("bad")
s.ignore("**-0.7 10.0-**")  # Ignore outside 0.8-10 keV

# Global XSPEC settings
x.Plot.device = "/null"
x.Plot.xAxis = "keV"
x.Xset.xsect = "vern"
x.Xset.abund = "wilm"


# --- 2. MODEL DEFINITION ---
# Defining the model for the loaded PN data
m1 = x.Model("tbabs * (nthcomp + diskbb)")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: ../products/0865600201/pn/spec/pn_source_spectrum_grp.pha  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  8.183e+00 +/- 1.003e-02
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-3303
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 8.128e+04 sec
#  Using fit statistic: cstat
#  No response loaded.
#
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Net count rate (cts/s) for Spectrum:1  5.910e+00 +/- 1.986e-02 (72.2 % total)
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Response successfully loaded.
# Arf successfully loaded.
#
# ignore:  1099 channels ignored from  source number 1
#     95 channels (1-95) ignored in spectrum #     1
#   1376 channels (1928-3303) ignored in spectrum #     1
#
#  Cross Section Table set to vern:  Verner, Ferland, Korista, and Yakovlev 1996
#  Solar Abundance Vector set to wilm:  Wilms, J., Allen, A. & McCray, R. ApJ 542 914 (2000) (abundances are set to zero for those elements not included in the paper).
#
# ========================================================================
# Model TBabs<1>(nthComp<2> + diskbb<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   nthComp    Gamma               1.70000      +/-  0.0
#    3    2   nthComp    kT_e       keV      100.000      +/-  0.0
#    4    2   nthComp    kT_bb      keV      0.100000     frozen
#    5    2   nthComp    inp_type   0/1      0.0          frozen
#    6    2   nthComp    Redshift            0.0          frozen
#    7    2   nthComp    norm                1.00000      +/-  0.0
#    8    3   diskbb     Tin        keV      1.00000      +/-  0.0
#    9    3   diskbb     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.130967e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              5.976552e+09     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.

# %%
# --- 4. FITTING ---



m1(1).values = 0.25
m1(1).frozen = False
m1(2).values = 1.8
m1(3).values = 50
m1(3).frozen = False
m1(4).link = "p8"

m1(5).values = 1
m1(5).frozen = True
m1(7).values = 0.005
m1(8).values = 0.8
m1(9).values = 0.002

# m1(10).values = 10
# m1(11).values = 0.5
# Out:
# Fit statistic  : C-Statistic              1.723740e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.286537e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#   parameter 1 is not frozen.
#
# Fit statistic  : C-Statistic              1.608567e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.152496e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.609730e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.153711e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#   parameter 3 is not frozen.
#
# Fit statistic  : C-Statistic              6.736510e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              2.317097e+11     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              2.559587e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              2.742261e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#   parameter 5 is already frozen.
#
# Fit statistic  : C-Statistic                364743.0     using 1832 bins.
#
# Test statistic : Chi-Squared                515149.5     using 1832 bins.
#  Null hypothesis probability of 0.0e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                127765.9     using 1832 bins.
#
# Test statistic : Chi-Squared                148713.4     using 1832 bins.
#  Null hypothesis probability of 0.0e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                30482.02     using 1832 bins.
#
# Test statistic : Chi-Squared                30449.13     using 1832 bins.
#  Null hypothesis probability of 0.00e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.

# %%
x.Fit.statMethod = "cstat"
x.Fit.query = "yes"
x.Fit.perform()
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
#
# Fit statistic  : C-Statistic                30482.02     using 1832 bins.
#
# Test statistic : Chi-Squared                30449.13     using 1832 bins.
#  Null hypothesis probability of 0.00e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH       2:Gamma        3:kT_e        7:norm         8:Tin        9:norm
# 4214.95      4.0177e+06   -3      0.206919       1.83619       25.1373    0.00402680      0.788276   0.000471589
# 2921.65      840815       -3      0.204377       1.88631       3.49069    0.00374874      0.817420   0.000225868
# 1937.31      113221       -3      0.218239       1.77158       6.10850    0.00360803      0.852835   4.10794e-06
# 1911.57      31330.3      -1      0.223314       1.79117       5.15467    0.00361069      0.854725    0.00613187
# 1910.2       5413.13       0      0.223697       1.79288       5.01618    0.00361028      0.854654    0.00629856
# 1908.93      1914.07       0      0.223925       1.79424       4.72452    0.00360996      0.854648    0.00641854
# 1907.96      15294.7       0      0.223995       1.79555       4.56808    0.00360898      0.854241    0.00625061
# 1907.41      12284.1       0      0.223952       1.79650       4.46551    0.00360813      0.853923    0.00605961
# 1907.14      9046.61       0      0.223851       1.79715       4.39991    0.00360745      0.853727    0.00586274
# 1907.08      6408.82      -1      0.223020       1.79860       4.20452    0.00360503      0.854609    0.00477661
# 1906.88      11805.9      -1      0.222443       1.79927       4.35704    0.00360326      0.855533    0.00411014
# 1906.63      7428.32      -2      0.221306       1.80491       4.56292    0.00359507      0.865700    0.00444345
# 1906.24      10315.1      -3      0.218898       1.81315       5.09201    0.00351710      0.897612     0.0274097
# 1905.66      2166.69      -1      0.219336       1.81275       4.83761    0.00351517      0.898256     0.0264359
# 1905.5       9000.45      -2      0.218868       1.81232       4.87789    0.00350662      0.899449     0.0281043
# 1905.47      1583.5       -2      0.218749       1.81187       4.80761    0.00349897      0.900860     0.0302738
# 1905.43      3885.04      -2      0.218660       1.81127       4.88394    0.00349132      0.902017     0.0324952
# 1905.4       3329.76       0      0.218676       1.81120       4.84797    0.00349139      0.902127     0.0325535
# 1905.39      1490.99      -1      0.218669       1.81121       4.83811    0.00349054      0.902212     0.0327425
# ======================================================================
#  Variances and Principal Axes
#                  1        2        3        7        8        9
#  3.8709E-11|  0.0019   0.0013   0.0000  -1.0000  -0.0018  -0.0020
#  4.7914E-06|  0.7991  -0.3953  -0.0036   0.0009   0.3547  -0.2818
#  2.8207E-05|  0.5818   0.6832  -0.0017   0.0018  -0.2753   0.3449
#  5.8928E-04|  0.1483  -0.5876   0.0337   0.0002  -0.7177   0.3412
#  3.6172E-02| -0.0315  -0.1741   0.0961  -0.0029   0.5316   0.8227
#  9.9185E+00|  0.0019   0.0364   0.9948   0.0003  -0.0263  -0.0915
# ----------------------------------------------------------------------
#
# ========================================================================
#   Covariance Matrix
#         1           2           3           4           5           6
#    9.898e-05   8.597e-04   1.910e-02   9.063e-06  -1.178e-03  -2.669e-03
#    8.597e-04   1.447e-02   3.587e-01   1.256e-04  -1.259e-02  -3.834e-02
#    1.910e-02   3.587e-01   9.816e+00   2.928e-03  -2.573e-01  -8.998e-01
#    9.063e-06   1.256e-04   2.928e-03   1.178e-06  -1.328e-04  -3.556e-04
#   -1.178e-03  -1.259e-02  -2.573e-01  -1.328e-04   1.737e-02   3.950e-02
#   -2.669e-03  -3.834e-02  -8.998e-01  -3.556e-04   3.950e-02   1.076e-01
# ------------------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(nthComp<2> + diskbb<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.218669     +/-  9.94876E-03
#    2    2   nthComp    Gamma               1.81121      +/-  0.120288
#    3    2   nthComp    kT_e       keV      4.83811      +/-  3.13301
#    4    2   nthComp    kT_bb      keV      0.902212     = p8
#    5    2   nthComp    inp_type   0/1      1.00000      frozen
#    6    2   nthComp    Redshift            0.0          frozen
#    7    2   nthComp    norm                3.49054E-03  +/-  1.08518E-03
#    8    3   diskbb     Tin        keV      0.902212     +/-  0.131794
#    9    3   diskbb     norm                3.27425E-02  +/-  0.327975
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 1905.39     using 1832 bins.
#
# Test statistic : Chi-Squared                 2041.78     using 1832 bins.
#  Null hypothesis probability of 2.80e-04 with 1826 degrees of freedom

# %%
print("\n" + "="*110)
print(f"{'GROUP':<5} | {'C#':<3} | {'P#':<3} | {'COMPONENT':<12} | {'PARAMETER':<12} | {'UNIT':<12} | {'VALUE':<12} | {'ERROR'}")
print("-" * 110)

global_par_idx = 1

for comp_idx, comp_name in enumerate(m1.componentNames, start=1):
    comp = getattr(m1, comp_name)
    for par_name in comp.parameterNames:
        par = getattr(comp, par_name)

        # 5 significant figures for numeric values
        val = par.values[0]
        val_str = f"{val:.5g}" if isinstance(val, (int, float, np.floating)) else str(val)

        # Unit column
        unit = getattr(par, "unit", "")
        unit_str = unit if unit not in ("", None) else "-"

        if par.link != "":
            err_str = f"LINKED ({par.link})"
        elif par.frozen:
            err_str = "FROZEN"
        else:
            err_str = f"+/- {par.sigma:.5g}" if par.sigma > 0 else "N/A"

        print(
            f"{'1':<5} | {comp_idx:<3} | {global_par_idx:<3} | "
            f"{comp_name:<12} | {par_name:<12} | {unit_str:<12} | {val_str:<12} | {err_str}"
        )

        global_par_idx += 1

print("-" * 110)
print(f"Final {x.Fit.statMethod.upper()}: {x.Fit.statistic:.5g}")
print(f"Degrees of Freedom: {x.Fit.dof}")
print(f"Reduced Statistic: {(x.Fit.statistic / x.Fit.dof):.5g}")
print("="*110 + "\n")
# Out:
# ==============================================================================================================
# GROUP | C#  | P#  | COMPONENT    | PARAMETER    | UNIT         | VALUE        | ERROR
# --------------------------------------------------------------------------------------------------------------
# 1     | 1   | 1   | TBabs        | nH           | 10^22        | 0.21867      | +/- 0.0099488
# 1     | 2   | 2   | nthComp      | Gamma        | -            | 1.8112       | +/- 0.12029
# 1     | 2   | 3   | nthComp      | kT_e         | keV          | 4.8381       | +/- 3.133
# 1     | 2   | 4   | nthComp      | kT_bb        | keV          | 0.90221      | LINKED (= p8)
# 1     | 2   | 5   | nthComp      | inp_type     | 0/1          | 1            | FROZEN
# 1     | 2   | 6   | nthComp      | Redshift     | -            | 0            | FROZEN
# 1     | 2   | 7   | nthComp      | norm         | -            | 0.0034905    | +/- 0.0010852
# 1     | 3   | 8   | diskbb       | Tin          | keV          | 0.90221      | +/- 0.13179
# 1     | 3   | 9   | diskbb       | norm         | -            | 0.032742     | +/- 0.32797
# --------------------------------------------------------------------------------------------------------------
# Final CSTAT: 1905.4
# Degrees of Freedom: 1826
# Reduced Statistic: 1.0435
# ==============================================================================================================

# %%
# --- 5. PLOTTING ---

# Set rebinning for the plot only (e.g., min significance 7, max 10 bins)
# x.Plot.setRebin(1,1)
x.Plot.device = "/null"
x.Plot.xAxis = "keV"
x.Plot.add = True

# Extract Data
x.Plot("data")
energy_x   = x.Plot.x(1)
energy_err = x.Plot.xErr(1)
data_y     = x.Plot.y(1)
data_err   = x.Plot.yErr(1)
model_y    = x.Plot.model(1)




y_units = x.Plot.labels()[1]
print(y_units)
# Extract Residuals
x.Plot("delchi")
residuals  = x.Plot.y(1)


e  = np.array(energy_x)
ee = np.array(energy_err)
dy = np.array(data_y)
de = np.array(data_err)
my = np.array(model_y)
res = np.array(residuals)

#background

if use_background:
    x.Plot("background")
    bkg = x.Plot.y(1)
    bkg_err = x.Plot.yErr(1)
# Out:
# counts s$^{-1}$ keV$^{-1}$

# %%
# Plotting


plt.style.use('default')


plt.figure(figsize=(16, 9), dpi=75)
gs = plt.GridSpec(2, 1, height_ratios=[3, 1], hspace=0)

# Top panel: Data and Model
ax1 = plt.subplot(gs[0])
ax1.errorbar(e, dy, xerr=ee, yerr=de, fmt='o', ms=2, elinewidth=0.8, label='PN Data')
ax1.step(e, my, where='mid', color='C1', lw=1.5, zorder=10, label='Model')
ax1.set_yscale("log")
ax1.set_ylabel(fr"{y_units}", fontsize=16)
#ax1.set_title(f"PN Spectrum for {selected_interval}: {m1.expression}")
#background
if use_background:
    ax1.errorbar(e, bkg, yerr=bkg_err, color='black', fmt='o',ms=2, elinewidth=0.8, label='Background')
ax1.set_ylim(1e-2,)

# Bottom panel: Residuals
ax2 = plt.subplot(gs[1], sharex=ax1)
ax2.step(e, res, where='mid', color='black', lw=1.2)
# ax2.errorbar(e, res, xerr=ee, fmt='none', ecolor='black', elinewidth=0.8, capsize=2)
ax2.axhline(0, color='red', linestyle='--')
# ax2.set_ylim(-4,4)

ax2.set_xlabel("Energy (keV)",fontsize=16)
ax2.set_ylabel(r"Residuals ($\chi$)", fontsize=16)
ax1.legend(fontsize=14, loc='best')
plt.tight_layout()
plt.savefig(os.path.join(plot_dir, f"pn_{selected_interval}_fit.png"), dpi=300, bbox_inches='tight')

# %%
# Quick check: Calculate counts from rates to decide on statistic
exposure = s.exposure
counts = np.array([r * exposure for r in s.values if r > 0])
min_counts = np.min(counts)
median_counts = np.median(counts)

print(f"Exposure: {exposure:.1f} s")
print(f"Min counts/bin: {min_counts:.1f}")
print(f"Median counts/bin: {median_counts:.1f}")

if min_counts < 20:
    print("\n--- RECOMMENDATION ---")
    print(f"Minimum counts ({min_counts:.1f}) is below 20.")
    print("Gaussian statistics (Chi-Squared) are invalid for low-count bins.")
    print("Use 'cstat' for the most reliable results.")
else:
    print("\n--- RECOMMENDATION ---")
    print(f"All bins have >= 20 counts (Min: {min_counts:.1f}).")
    print("You can safely use 'chi' (Chi-Squared) or 'cstat'.")
# Out:
# Exposure: 81275.1 s
# Min counts/bin: 20.0
# Median counts/bin: 147.0
#
# --- RECOMMENDATION ---
# Minimum counts (20.0) is below 20.
# Gaussian statistics (Chi-Squared) are invalid for low-count bins.
# Use 'cstat' for the most reliable results.

# %%
# import os
# import re
# import numpy as np
# from astropy.io import fits
#
# # -----------------------------
# # 1) Configure and run chain
# # -----------------------------
# x.AllChains.clear()
#
# chain_len = 5000
# burn_len = 500
# chain_file = f"../products/0865600201/pn/spec/pn_{selected_interval}_mcmc_chain.fits"
#
# if os.path.exists(chain_file):
#     os.remove(chain_file)
#
# x.AllChains.defLength = chain_len
# x.AllChains.defBurn = burn_len
# x.AllChains.defRand = True
#
# # Some builds support this, some may not
# try:
#     x.AllChains.defProposal = "gaussian fit"
# except Exception:
#     pass
#
# print("AllChains defaults:")
# print("  defLength :", x.AllChains.defLength)
# print("  defBurn   :", x.AllChains.defBurn)
# try:
#     print("  defProposal:", x.AllChains.defProposal)
# except Exception:
#     print("  defProposal: <not available in this PyXspec build>")
# print("  defRand   :", x.AllChains.defRand)
#
# print(f"\nRunning chain: {chain_file}")
# ch = x.Chain(chain_file)
#
#
# # Optional XSPEC-side chain info (works in most builds)
# try:
#     x.AllChains.show()
# except Exception:
#     pass
#
# # Version-safe chain length check: count FITS table rows
# with fits.open(chain_file) as hdul:
#     data = hdul[1].data
#     colnames = list(hdul[1].columns.names)
#     nrows = len(data)
#
# print(f"\nactual chain rows in FITS: {nrows}")
#
# # -----------------------------
# # 2) Build model parameter map
# # -----------------------------
# all_params = []
# global_idx = 1
# for comp_name in m1.componentNames:
#     comp = getattr(m1, comp_name)
#     for par_name in comp.parameterNames:
#         par = getattr(comp, par_name)
#         all_params.append({
#             "idx": global_idx,
#             "name": f"{comp_name}.{par_name}",
#             "frozen": par.frozen,
#             "linked": (par.link != ""),
#             "value": par.values[0],
#             "status": "LINKED" if par.link != "" else ("FROZEN" if par.frozen else "FREE"),
#             "link": par.link
#         })
#         global_idx += 1
#
# free_params = [p for p in all_params if (not p["frozen"] and not p["linked"])]
#
# # -----------------------------
# # 3) Identify chain parameter columns
# # -----------------------------
# exclude = {"FIT_STATISTIC", "STATISTIC", "CHI2", "CHAIN", "ACCEPT", "ACCEPTANCE"}
# par_cols = []
# for c in colnames:
#     if c.upper() in exclude:
#         continue
#     arr = np.asarray(data[c])
#     if np.issubdtype(arr.dtype, np.number):
#         par_cols.append(c)
#
#
# def parse_idx(col):
#     # XSPEC-style names often end with "__<global_index>", e.g. "Gamma__2"
#     m = re.search(r"__(\d+)$", col)
#     return int(m.group(1)) if m else None
#
#
# col_idx = {c: parse_idx(c) for c in par_cols}
# have_explicit_idx = all(v is not None for v in col_idx.values())
#
# if have_explicit_idx:
#     par_cols = sorted(par_cols, key=lambda c: col_idx[c])
#     free_by_idx = {p["idx"]: p for p in free_params}
#     mapped = []
#     for c in par_cols:
#         idx = col_idx[c]
#         if idx in free_by_idx:
#             mapped.append((c, free_by_idx[idx]))
#         else:
#             # Rare fallback if model state changed
#             mapped.append((c, {"idx": idx, "name": c, "status": "FREE"}))
# else:
#     # Fallback by order if no explicit index suffixes are present
#     if len(par_cols) != len(free_params):
#         raise RuntimeError(
#             "Could not map chain columns reliably by order. "
#             f"Columns={par_cols}, free_params={len(free_params)}"
#         )
#     mapped = list(zip(par_cols, free_params))
#
# # -----------------------------
# # 4) Posterior interval table (sampled params)
# # -----------------------------
# print("\n" + "=" * 130)
# print(f"{'P#':<4} {'PARAMETER':<34} {'MEDIAN':>12} {'68% CI':>30} {'90% CI':>30}")
# print("-" * 130)
#
# for col, p in mapped:
#     samples = np.asarray(data[col], dtype=float)
#
#     q16, q50, q84 = np.percentile(samples, [16, 50, 84])  # ~68%
#     q05, q95 = np.percentile(samples, [5, 95])  # 90%
#
#     lo68, hi68 = q50 - q16, q84 - q50
#     lo90, hi90 = q50 - q05, q95 - q50
#
#     print(
#         f"{p['idx']:<4} {p['name']:<34} "
#         f"{q50:>12.5g} "
#         f"[-{lo68:.5g}, +{hi68:.5g}]".rjust(30) + " "
#                                                   f"[-{lo90:.5g}, +{hi90:.5g}]".rjust(30)
#     )
#
# print("=" * 130)
#
# # -----------------------------
# # 5) Non-sampled params table (linked/frozen)
# # -----------------------------
# nonsampled = [p for p in all_params if p["status"] != "FREE"]
# if nonsampled:
#     print("\nNon-sampled model parameters:")
#     print("-" * 90)
#     print(f"{'P#':<4} {'PARAMETER':<34} {'VALUE':>12} {'STATUS':>12} {'LINK':>20}")
#     print("-" * 90)
#     for p in nonsampled:
#         link_txt = p["link"] if p["status"] == "LINKED" else "-"
#         print(f"{p['idx']:<4} {p['name']:<34} {p['value']:>12.5g} {p['status']:>12} {link_txt:>20}")
#     print("-" * 90)

# %%
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Optional extra visual burn-in cut (for plotting only)
# plot_burn_frac = 0.1  # set 0.0 to disable
# nrows = len(data)
# i0 = int(plot_burn_frac * nrows)
#
# n = len(mapped)
# ncols = 3
# nrows_grid = int(np.ceil(n / ncols))
#
# fig, axes = plt.subplots(nrows_grid, ncols, figsize=(5 * ncols, 3.5 * nrows_grid))
# axes = np.atleast_1d(axes).ravel()
#
# for k, (col, p) in enumerate(mapped):
#     s = np.asarray(data[col], dtype=float)[i0:]
#
#     q16, q50, q84 = np.percentile(s, [16, 50, 84])
#
#     ax = axes[k]
#     ax.hist(s, bins=60, density=True, alpha=0.75)
#     ax.axvline(q50, ls='-', lw=1.5, color='k', label='median')
#     ax.axvline(q16, ls='--', lw=1.2, color='k', alpha=0.8)
#     ax.axvline(q84, ls='--', lw=1.2, color='k', alpha=0.8)
#
#     ax.set_title(f"P{p['idx']}: {p['name']}")
#     ax.set_xlabel("value")
#     ax.set_ylabel("density")
#     ax.legend(fontsize=8)
#
# # Hide unused panels
# for j in range(n, len(axes)):
#     axes[j].axis("off")
#
# plt.tight_layout()
# plt.show()

# %%
# import numpy as np
# import corner
# import matplotlib.pyplot as plt
#
# plot_burn_frac = 0.1
# i0 = int(plot_burn_frac * len(data))
#
# samples = np.column_stack([np.asarray(data[col], dtype=float)[i0:] for col, _ in mapped])
# labels = [f"P{p['idx']} {p['name']}" for _, p in mapped]
#
# fig = corner.corner(
#     samples,
#     labels=labels,
#     quantiles=[0.16, 0.5, 0.84],
#     show_titles=True,
#     title_fmt=".4g",
#     bins=40
# )
# plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
#
# # burn-in cut for diagnostics
# i0 = int(0.1 * len(data))
#
# # find chain columns by XSPEC global index
# idx_to_col = {}
# for col, p in mapped:
#     idx_to_col[p["idx"]] = col
#
# if 7 not in idx_to_col or 8 not in idx_to_col:
#     raise RuntimeError("Could not find P7 (nthcomp.norm) and/or P8 (diskbb.Tin) in mapped chain columns.")
#
# n7 = np.asarray(data[idx_to_col[7]], dtype=float)[i0:]  # nthcomp.norm
# t8 = np.asarray(data[idx_to_col[8]], dtype=float)[i0:]  # diskbb.Tin
#
# r = np.corrcoef(n7, t8)[0, 1]
# print(f"Pearson r(P7 nthcomp.norm, P8 diskbb.Tin) = {r:.3f}")
#
# plt.figure(figsize=(6, 5))
# plt.scatter(t8, n7, s=3, alpha=0.2)
# plt.xlabel("P8 diskbb.Tin")
# plt.ylabel("P7 nthcomp.norm")
# plt.title(f"Degeneracy check: r = {r:.3f}")
# plt.tight_layout()
# plt.show()

# %%
# --- 6. MODEL COMPARISON: baseline vs zxipcf ---
def _set_par(model, comp_name, par_name, values=None, frozen=None, link=None):
    """Safely set a parameter only if component/parameter exists in the model."""
    cname_match = next((c for c in model.componentNames if c.lower() == comp_name.lower()), None)
    if not cname_match:
        return False
    comp = getattr(model, cname_match)
    pname_match = next((p for p in comp.parameterNames if p.lower() == par_name.lower()), None)
    if not pname_match:
        return False
    par = getattr(comp, pname_match)
    if values is not None:
        par.values = values
    if frozen is not None:
        par.frozen = frozen
    if link is not None:
        par.link = link
    return True
def _global_par_index(model, target_comp, target_par):
    """Return XSPEC global parameter index for link expressions (p#)."""
    idx = 1
    for comp_name in model.componentNames:
        comp = getattr(model, comp_name)
        for par_name in comp.parameterNames:
            if comp_name.lower() == target_comp.lower() and par_name.lower() == target_par.lower():
                return idx
            idx += 1
    return None
def _n_free_params(model):
    n_free = 0
    for comp_name in model.componentNames:
        comp = getattr(model, comp_name)
        for par_name in comp.parameterNames:
            p = getattr(comp, par_name)
            if (not p.frozen) and (p.link == ""):
                n_free += 1
    return n_free
def _safe_sigma(par):
    """Return finite positive sigma when XSPEC provides one."""
    try:
        sigma = float(par.sigma)
    except Exception:
        return np.nan
    return sigma if np.isfinite(sigma) and sigma > 0 else np.nan
def _apply_continuum_start_values(model):
    # Use bounded starts for continuum parameters to match the zxipcf setup style.
    _set_par(model, "tbabs", "nH", values=[0.2, 0.01, 0.01, 0.01, 5.0, 10.0], frozen=False)
    _set_par(model, "nthcomp", "Gamma", values=[1.8, 0.01, 1.0, 1.0, 3.5, 5.0])
    _set_par(model, "nthcomp", "kT_e", values=[50.0, 0.1, 1.0, 1.0, 200.0, 300.0], frozen=False)
    _set_par(model, "nthcomp", "inp_type", values=1.0, frozen=True)
    _set_par(model, "nthcomp", "Redshift", values=[0.0, 0.001, -0.01, -0.01, 0.01, 0.01], frozen=True)
    _set_par(model, "nthcomp", "norm", values=[0.003, 0.01, 1.0e-6, 1.0e-6, 1.0e3, 1.0e6])
    _set_par(model, "diskbb", "Tin", values=[0.8, 0.01, 0.05, 0.05, 3.0, 5.0])
    _set_par(model, "diskbb", "norm", values=[0.001, 0.01, 1.0e-4, 1.0e-4, 1.0e5, 1.0e6])
    # Keep kTbb tied to diskbb Tin as in the original setup.
    tin_idx = _global_par_index(model, "diskbb", "Tin")
    if tin_idx is not None:
        _set_par(model, "nthcomp", "kT_bb", link=f"p{tin_idx}")
def _apply_zxipcf_start_values(model, freeze_map=None):
    # zxipcf fits are much more stable if Redshift stays frozen at 0.
    # You can override each freeze flag independently via freeze_map.
    log_xi_lower_bound = 0.0
    candidates = {
        # XSPEC 6-value format: [val, delta, min, bottom, top, max]
        "Nh": [0.3, 0.01, 0.001, 0.001, 100.0, 100.0],
        # Set an explicit lower bound for log_xi to avoid unphysical low-ionization drifts.
        "log_xi": [3.0, 0.01, log_xi_lower_bound, log_xi_lower_bound, 6.0, 6.0],
        "CvrFract": [0.8, 0.01, 0.0, 0.0, 1.0, 1.0],
        "Redshift": [0.0, 0.001, -0.01, -0.01, 0.01, 0.01],
    }
    default_freeze = {
        "Nh": False,
        "log_xi": False,
        "CvrFract": False,
        "Redshift": True,
    }

    # Accept either exact keys or case-insensitive keys.
    user_freeze = {}
    if isinstance(freeze_map, dict):
        for k, v in freeze_map.items():
            user_freeze[str(k).lower()] = bool(v)

    if not any(c.lower() == "zxipcf" for c in model.componentNames):
        return

    for name, value in candidates.items():
        _set_par(model, "zxipcf", name, values=value)
        freeze_flag = default_freeze[name]
        if name.lower() in user_freeze:
            freeze_flag = user_freeze[name.lower()]
        _set_par(model, "zxipcf", name, frozen=freeze_flag)


def fit_model(label, expression, add_zxipcf=False, freeze_zxipcf_params=None):
    x.AllModels.clear()
    model = x.Model(expression)
    _apply_continuum_start_values(model)
    if add_zxipcf:
        _apply_zxipcf_start_values(model, freeze_map=freeze_zxipcf_params)
    try:
        x.Fit.perform()
    except Exception:
        print(f"Fit failed for {label}: {expression}")
        print(f"zxipcf enabled: {add_zxipcf}, freeze_zxipcf_params: {freeze_zxipcf_params}")
        raise
    stat = float(x.Fit.statistic)
    dof = int(x.Fit.dof)
    red_stat = stat / dof if dof > 0 else np.nan
    k_free = _n_free_params(model)
    n_bins = dof + k_free
    aic = stat + 2 * k_free
    bic = stat + k_free * np.log(n_bins) if n_bins > 0 else np.nan
    return {
        "model": label,
        "expression": expression,
        "stat": stat,
        "dof": dof,
        "red_stat": red_stat,
        "k_free": k_free,
        "n_bins": n_bins,
        "AIC": aic,
        "BIC": bic,
    }, model
# Use the same fit statistic as above
x.Fit.statMethod = "cstat"
x.Fit.query = "yes"
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
#
# Fit statistic  : C-Statistic                 1905.39     using 1832 bins.
#
# Test statistic : Chi-Squared                 2041.78     using 1832 bins.
#  Null hypothesis probability of 2.80e-04 with 1826 degrees of freedom
#  Current data and model not fit yet.

# %%
baseline_result, baseline_model = fit_model(
    "baseline",
    "tbabs * (nthcomp + diskbb)",
    add_zxipcf=False,
)

# IMPORTANT: Extract model data immediately while model is active
def _save_model_and_flux(model_obj):
    """Save parameters and extract folded model flux immediately."""
    params = {}
    for comp_name in model_obj.componentNames:
        comp = getattr(model_obj, comp_name)
        for par_name in comp.parameterNames:
            par = getattr(comp, par_name)
            params[f"{comp_name}.{par_name}"] = {
                "value": par.values[0],
                "frozen": par.frozen,
                "link": par.link,
                "sigma": _safe_sigma(par),
            }

    # Extract folded model data while active
    x.Plot("data")
    energy = np.array(x.Plot.x(1))
    energy_err = np.array(x.Plot.xErr(1))
    data_y = np.array(x.Plot.y(1))
    data_err = np.array(x.Plot.yErr(1))
    model_y = np.array(x.Plot.model(1))

    # Extract residuals
    x.Plot("delchi")
    residuals = np.array(x.Plot.y(1))

    return params, energy, energy_err, data_y, data_err, model_y, residuals


def _restore_model_from_snapshot(expression, snapshot):
    """Rebuild a live XSPEC model and restore saved parameter values/frozen/link states."""
    x.AllModels.clear()
    model_obj = x.Model(expression)

    # First pass: restore numeric values and frozen flags with links cleared.
    for comp_name in model_obj.componentNames:
        comp = getattr(model_obj, comp_name)
        for par_name in comp.parameterNames:
            key = f"{comp_name}.{par_name}"
            if key not in snapshot:
                continue
            p = getattr(comp, par_name)
            p.link = ""
            p.values = snapshot[key]["value"]
            p.frozen = snapshot[key]["frozen"]

    # Second pass: re-apply links after all parameter values are set.
    for comp_name in model_obj.componentNames:
        comp = getattr(model_obj, comp_name)
        for par_name in comp.parameterNames:
            key = f"{comp_name}.{par_name}"
            if key not in snapshot:
                continue
            link_expr = snapshot[key]["link"]
            if isinstance(link_expr, str):
                # Stored links may appear as "= p8"; XSPEC expects "p8".
                cleaned_link = link_expr.strip()
                if cleaned_link.startswith("="):
                    cleaned_link = cleaned_link[1:].strip()
            else:
                cleaned_link = ""

            if cleaned_link != "":
                try:
                    getattr(comp, par_name).link = cleaned_link
                except Exception:
                    # Skip malformed legacy link strings and continue restoring.
                    pass

    return model_obj

baseline_params, energy_x, energy_err, data_y, data_err, baseline_model_y, baseline_residuals = _save_model_and_flux(baseline_model)
# Out:
# ========================================================================
# Model TBabs<1>(nthComp<2> + diskbb<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   nthComp    Gamma               1.70000      +/-  0.0
#    3    2   nthComp    kT_e       keV      100.000      +/-  0.0
#    4    2   nthComp    kT_bb      keV      0.100000     frozen
#    5    2   nthComp    inp_type   0/1      0.0          frozen
#    6    2   nthComp    Redshift            0.0          frozen
#    7    2   nthComp    norm                1.00000      +/-  0.0
#    8    3   diskbb     Tin        keV      1.00000      +/-  0.0
#    9    3   diskbb     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.130967e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              5.976552e+09     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.793648e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.406266e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#   parameter 1 is not frozen.
#
# Fit statistic  : C-Statistic              1.677965e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.270676e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.679133e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.271905e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#   parameter 3 is not frozen.
#
# Fit statistic  : C-Statistic              1.678186e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.271544e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#   parameter 5 is already frozen.
#
# Fit statistic  : C-Statistic              1.678186e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.271544e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1825 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.678186e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.271544e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                108529.8     using 1832 bins.
#
# Test statistic : Chi-Squared                133562.8     using 1832 bins.
#  Null hypothesis probability of 0.0e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                30095.66     using 1832 bins.
#
# Test statistic : Chi-Squared                52814.71     using 1832 bins.
#  Null hypothesis probability of 0.00e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                30365.48     using 1832 bins.
#
# Test statistic : Chi-Squared                86768.07     using 1832 bins.
#  Null hypothesis probability of 0.00e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                11123.89     using 1832 bins.
#
# Test statistic : Chi-Squared                18211.80     using 1832 bins.
#  Null hypothesis probability of 0.00e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH       2:Gamma        3:kT_e        7:norm         8:Tin        9:norm
# 2307.12      1.49416e+06   0      0.187062       1.68540       22.2257    0.00316134      0.927415     0.0711830
# 2067.75      389436        0      0.191435       1.68896       19.6968    0.00318647      0.940791     0.0837464
# 1933.46      84901.2      -1      0.213215       1.72081       27.3632    0.00321413      0.962018      0.100327
# 1908.99      32402        -2      0.219656       1.76346       29.9069    0.00321873      0.990539     0.0932751
# 1908.32      3892.55      -1      0.219742       1.76878       29.0436    0.00321873      0.992772     0.0928158
# 1908.02      109.27       -1      0.219539       1.77220       27.1054    0.00321830      0.994721     0.0919513
# 1907.78      513.018      -1      0.219171       1.77526       24.8399    0.00321762      0.996295     0.0910626
# 1907.59      819.962      -1      0.218794       1.77792       23.2650    0.00321699      0.997695     0.0902439
# 1907.43      488.731      -1      0.218442       1.78027       21.9362    0.00321642      0.998950     0.0895009
# 1907.28      582.64       -1      0.218075       1.78269       20.3046    0.00321574      0.999929     0.0888344
# 1907.17      930.234      -1      0.217749       1.78481       19.1811    0.00321517       1.00081     0.0882458
# 1907.07      649.484      -1      0.217453       1.78677       18.1634    0.00321464       1.00156     0.0877227
# 1906.98      586.287      -1      0.217174       1.78861       17.2040    0.00321412       1.00217     0.0872604
# 1906.91      592.942      -1      0.216912       1.79034       16.3186    0.00321361       1.00266     0.0868549
# 1906.85      684.839      -1      0.216675       1.79191       15.5860    0.00321316       1.00305     0.0865024
# 1906.79      582.456      -1      0.216452       1.79339       14.8815    0.00321272       1.00334     0.0861943
# 1906.74      548.94       -1      0.216241       1.79478       14.2371    0.00321228       1.00354     0.0859289
# 1906.69      443.489      -1      0.216043       1.79609       13.6262    0.00321187       1.00364     0.0857047
# 1906.65      494.738      -1      0.215859       1.79730       13.0825    0.00321147       1.00366     0.0855163
# 1906.6       433.954      -1      0.215689       1.79843       12.5734    0.00321108       1.00362     0.0853640
# 1906.56      458.742      -1      0.215524       1.79951       12.0883    0.00321069       1.00349     0.0852418
# 1906.52      410.582      -1      0.215379       1.80045       11.6787    0.00321035       1.00332     0.0851481
# 1906.48      303.505      -1      0.215232       1.80140       11.2452    0.00320998       1.00307     0.0850799
# 1906.44      444.168      -1      0.215088       1.80229       10.8362    0.00320959       1.00274     0.0850383
# 1906.4       454.554      -1      0.214942       1.80319       10.4263    0.00320917       1.00233     0.0850238
# 1906.35      390.945      -1      0.214805       1.80401       10.0446    0.00320877       1.00186     0.0850377
# 1906.3       503.58       -1      0.214681       1.80472       9.71167    0.00320838       1.00135     0.0850763
# 1906.25      370.547      -1      0.214552       1.80544       9.36355    0.00320795       1.00075     0.0851378
# 1906.19      513.312      -1      0.214423       1.80611       9.03466    0.00320750       1.00008     0.0852235
# 1906.14      371.264      -1      0.214302       1.80669       8.72903    0.00320706      0.999367     0.0853346
# 1906.08      517.86       -1      0.214186       1.80723       8.43742    0.00320660      0.998588     0.0854691
# 1906.02      558.64       -1      0.214076       1.80768       8.16849    0.00320614      0.997760     0.0856287
# 1905.96      530.233      -1      0.213975       1.80803       7.92359    0.00320569      0.996891     0.0858106
# 1905.89      445.537      -1      0.213879       1.80833       7.68538    0.00320523      0.995964     0.0860177
# 1905.89      564.479      -2      0.213535       1.80814       5.90757    0.00320138      0.986271     0.0889931
# ======================================================================
#  Variances and Principal Axes
#                  1        2        3        7        8        9
#  3.6377E-11|  0.0018   0.0010   0.0000  -1.0000  -0.0022  -0.0028
#  4.9949E-06|  0.8375  -0.3110  -0.0021   0.0017   0.2538  -0.3708
#  3.0304E-05|  0.5307   0.6076   0.0018   0.0004  -0.1883   0.5601
#  7.0045E-04|  0.1249  -0.6154   0.0054   0.0003  -0.7142   0.3091
#  1.7603E-02| -0.0376  -0.3942   0.0070  -0.0037   0.6245   0.6731
#  3.4359E+02|  0.0004   0.0043   1.0000   0.0000   0.0004  -0.0082
# ----------------------------------------------------------------------
#
# ========================================================================
#   Covariance Matrix
#         1           2           3           4           5           6
#    1.030e-04   8.094e-04   1.377e-01   7.390e-06  -4.245e-04  -1.536e-03
#    8.094e-04   9.402e-03   1.482e+00   7.830e-05  -3.459e-03  -1.689e-02
#    1.377e-01   1.482e+00   3.436e+02   1.226e-02   1.325e-01  -2.805e+00
#    7.390e-06   7.830e-05   1.226e-02   6.762e-07  -3.589e-05  -1.437e-04
#   -4.245e-04  -3.459e-03   1.325e-01  -3.589e-05   7.275e-03   6.160e-03
#   -1.536e-03  -1.689e-02  -2.805e+00  -1.437e-04   6.160e-03   3.096e-02
# ------------------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(nthComp<2> + diskbb<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.213535     +/-  1.01513E-02
#    2    2   nthComp    Gamma               1.80814      +/-  9.69624E-02
#    3    2   nthComp    kT_e       keV      5.90757      +/-  18.5353
#    4    2   nthComp    kT_bb      keV      0.986271     = p8
#    5    2   nthComp    inp_type   0/1      1.00000      frozen
#    6    2   nthComp    Redshift            0.0          frozen
#    7    2   nthComp    norm                3.20138E-03  +/-  8.22302E-04
#    8    3   diskbb     Tin        keV      0.986271     +/-  8.52938E-02
#    9    3   diskbb     norm                8.89931E-02  +/-  0.175957
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 1905.89     using 1832 bins.
#
# Test statistic : Chi-Squared                 2024.86     using 1832 bins.
#  Null hypothesis probability of 7.13e-04 with 1826 degrees of freedom

# %%
zxipcf_freeze = {
    "Nh": False,
    "log_xi": False,
    "CvrFract": False,
    "Redshift": True,
}

zxipcf_result, zxipcf_model = fit_model(
    "zxipcf",
    "tbabs * zxipcf * (nthcomp + diskbb)",
    add_zxipcf=True,
    freeze_zxipcf_params=zxipcf_freeze,
)
# Out:
# ========================================================================
# Model TBabs<1>*zxipcf<2>(nthComp<3> + diskbb<4>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   zxipcf     Nh         10^22    10.0000      +/-  0.0
#    3    2   zxipcf     log_xi              3.00000      +/-  0.0
#    4    2   zxipcf     CvrFract            0.500000     +/-  0.0
#    5    2   zxipcf     Redshift            0.0          frozen
#    6    3   nthComp    Gamma               1.70000      +/-  0.0
#    7    3   nthComp    kT_e       keV      100.000      +/-  0.0
#    8    3   nthComp    kT_bb      keV      0.100000     frozen
#    9    3   nthComp    inp_type   0/1      0.0          frozen
#   10    3   nthComp    Redshift            0.0          frozen
#   11    3   nthComp    norm                1.00000      +/-  0.0
#   12    4   diskbb     Tin        keV      1.00000      +/-  0.0
#   13    4   diskbb     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.002980e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              4.775540e+09     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1823 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.571739e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.073608e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1823 degrees of freedom
#  Current data and model not fit yet.
#   parameter 1 is not frozen.
#
# Fit statistic  : C-Statistic              1.466465e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              9.629667e+09     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1823 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.467538e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              9.639869e+09     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1823 degrees of freedom
#  Current data and model not fit yet.
#   parameter 7 is not frozen.
#
# Fit statistic  : C-Statistic              1.466771e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              9.639188e+09     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1823 degrees of freedom
#  Current data and model not fit yet.
#   parameter 9 is already frozen.
#
# Fit statistic  : C-Statistic              1.466771e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              9.639188e+09     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1822 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.466771e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              9.639188e+09     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1823 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                58915.40     using 1832 bins.
#
# Test statistic : Chi-Squared                71975.07     using 1832 bins.
#  Null hypothesis probability of 0.00e+00 with 1823 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                23164.61     using 1832 bins.
#
# Test statistic : Chi-Squared                51492.27     using 1832 bins.
#  Null hypothesis probability of 0.00e+00 with 1823 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                35274.34     using 1832 bins.
#
# Test statistic : Chi-Squared                105837.0     using 1832 bins.
#  Null hypothesis probability of 0.0e+00 with 1823 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                17776.06     using 1832 bins.
#
# Test statistic : Chi-Squared                34129.58     using 1832 bins.
#  Null hypothesis probability of 0.00e+00 with 1823 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                11658.27     using 1832 bins.
#
# Test statistic : Chi-Squared                19227.77     using 1832 bins.
#  Null hypothesis probability of 0.00e+00 with 1823 degrees of freedom
#  Current data and model not fit yet.
#   parameter 2 is not frozen.
#
# Fit statistic  : C-Statistic                11658.27     using 1832 bins.
#
# Test statistic : Chi-Squared                19227.77     using 1832 bins.
#  Null hypothesis probability of 0.00e+00 with 1823 degrees of freedom
#  Current data and model not fit yet.
#   parameter 3 is not frozen.
#
# Fit statistic  : C-Statistic                11989.72     using 1832 bins.
#
# Test statistic : Chi-Squared                19882.25     using 1832 bins.
#  Null hypothesis probability of 0.00e+00 with 1823 degrees of freedom
#  Current data and model not fit yet.
#   parameter 4 is not frozen.
#
# Fit statistic  : C-Statistic                11989.72     using 1832 bins.
#
# Test statistic : Chi-Squared                19882.25     using 1832 bins.
#  Null hypothesis probability of 0.00e+00 with 1822 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                11989.72     using 1832 bins.
#
# Test statistic : Chi-Squared                19882.25     using 1832 bins.
#  Null hypothesis probability of 0.00e+00 with 1823 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:Nh      3:log_xi    4:CvrFract       6:Gamma        7:kT_e       11:norm        12:Tin       13:norm
# TableParamValueOutsideRange: Requested parameter value 1.14654e+20 outside tabulated range (5e+20, 5e+24)
#
# 2113.06      1.00681e+06   0      0.185381      0.147099       3.57495      0.356129       1.68537       21.7957    0.00318842      0.930719     0.0866684
# 2036.5       56255.2       0      0.192784      0.107680       2.26277      0.330560       1.69017       21.7560    0.00319779      0.937632     0.0912787
# 1923.95      84457.5      -1      0.203838      0.123777       1.71916      0.384753       1.71930       31.6443    0.00322880      0.955646      0.110871
# 1907.89      5858.45      -2      0.209111      0.175827       1.87733      0.265676       1.75404       39.8581    0.00323497      0.979231      0.102474
# 1907.06      2917.31      -1      0.208880      0.194391       1.87461      0.254900       1.75897       41.2678    0.00323624      0.981246      0.102581
# 1906.71      778.799      -1      0.208465      0.213243       1.86724      0.244551       1.76190       39.7101    0.00323688      0.982859      0.102165
# 1906.45      688.281      -1      0.207991      0.231018       1.85763      0.234448       1.76436       36.9474    0.00323714      0.984080      0.101638
# 1906.26      794.336      -1      0.207556      0.248084       1.84607      0.225131       1.76620       35.9021    0.00323745      0.985169      0.101119
# 1906.1       436.497      -1      0.207166      0.264434       1.83441      0.216531       1.76786       34.3406    0.00323766      0.986055      0.100626
# 1905.97      434.686      -1      0.206830      0.280196       1.82328      0.208622       1.76943       32.7081    0.00323781      0.986773      0.100174
# 1905.87      399.626      -1      0.206553      0.295732       1.81261      0.201436       1.77068       31.8274    0.00323804      0.987434     0.0997646
# 1905.78      304.812      -1      0.206320      0.310883       1.80320      0.194785       1.77192       30.5112    0.00323819      0.987941     0.0993873
# 1905.42      298.461      -2      0.206424      0.432896       1.78471      0.141777       1.77747       25.5617    0.00324113      0.989807     0.0973887
# 1905.03      6603.99      -1      0.206616      0.465245       1.77515      0.139681       1.77857       25.4327    0.00324216      0.989972     0.0977418
# 1904.93      191.17       -1      0.206586      0.493171       1.77482      0.136594       1.77921       25.3980    0.00324326      0.990001     0.0981219
# 1904.84      126.69       -1      0.206563      0.520015       1.77513      0.133609       1.77969       25.1666    0.00324420      0.989865     0.0984546
# 1904.77      76.167       -1      0.206569      0.546135       1.77548      0.130798       1.77996       25.0390    0.00324511      0.989651     0.0987692
# 1904.72      38.4646      -1      0.206601      0.571773       1.77598      0.128152       1.78014       24.9058    0.00324597      0.989369     0.0990735
# 1904.66      26.4012      -1      0.206655      0.597256       1.77655      0.125679       1.78018       24.9019    0.00324683      0.989058     0.0993719
# 1904.61      20.0362      -1      0.206725      0.622888       1.77714      0.123376       1.78009       25.0518    0.00324772      0.988738     0.0996656
# 1904.56      33.6192      -1      0.206792      0.648340       1.77849      0.121159       1.78020       24.6361    0.00324844      0.988294     0.0999482
# 1904.52      16.8358      -1      0.206873      0.674234       1.77969      0.119095       1.78017       24.5201    0.00324923      0.987872      0.100235
# 1904.48      63.1777      -1      0.206958      0.700648       1.78095      0.117159       1.78009       24.4270    0.00325002      0.987442      0.100519
# 1904.44      79.2396      -1      0.207043      0.727682       1.78227      0.115339       1.77999       24.3480    0.00325080      0.987004      0.100801
# 1904.4       56.7852      -1      0.207128      0.755368       1.78367      0.113622       1.77987       24.2753    0.00325159      0.986554      0.101080
# 1904.36      54.0734      -1      0.207214      0.783917       1.78498      0.112011       1.77970       24.3203    0.00325240      0.986120      0.101358
# 1904.33      117.851      -1      0.207296      0.813254       1.78637      0.110484       1.77953       24.2993    0.00325320      0.985674      0.101633
# 1904.29      90.3746      -1      0.207375      0.843448       1.78777      0.109036       1.77938       24.2697    0.00325399      0.985222      0.101906
# 1904.1       113.136      -2      0.208307       1.13814       1.81203     0.0949819       1.77819       23.3072    0.00326168      0.980759      0.104257
# 1903.68      4038.35      -2      0.210354       1.38518       1.87538     0.0921069       1.77780       22.3383    0.00327137      0.976386      0.108195
# 1903.53      4656.66      -1      0.210440       1.43569       1.89043     0.0925582       1.77757       22.3109    0.00327205      0.975874      0.108409
# 1903.48      51.5911      -1      0.210573       1.47951       1.90973     0.0926752       1.77753       22.1031    0.00327297      0.975411      0.108785
# 1903.37      205.355      -2      0.210574       1.64233       1.77149     0.0868427       1.77503       22.9771    0.00328391      0.969782      0.113168
# 1903.29      346.272      -1      0.210933       1.68127       1.80949     0.0875851       1.77477       22.7988    0.00328460      0.969308      0.113338
# 1903.2       66.4638      -1      0.211219       1.72568       1.84673     0.0882972       1.77457       22.7749    0.00328541      0.968882      0.113561
# 1903.12      133.365      -1      0.211456       1.77573       1.88333     0.0889756       1.77455       22.4545    0.00328616      0.968419      0.113805
# 1903.09      74.1317      -1      0.211671       1.83128       1.91928     0.0896224       1.77452       22.2267    0.00328697      0.967972      0.114072
# 1903.05      160.933       0      0.211639       1.83296       1.91110     0.0895456       1.77453       22.2323    0.00328715      0.967949      0.114153
# 1903.04      494.552       0      0.211609       1.83497       1.90684     0.0894798       1.77456       22.2363    0.00328730      0.967915      0.114228
# ==========================================================================================
#  Variances and Principal Axes
#                  1        2        3        4        6        7       11       12       13
#  3.9221E-11|  0.0019   0.0000  -0.0001   0.0010   0.0010   0.0000  -1.0000  -0.0024  -0.0025
#  4.9549E-06|  0.8483   0.0063  -0.0161   0.2272  -0.2705  -0.0003   0.0018   0.2234  -0.3245
#  3.5241E-05|  0.5003  -0.0091   0.0119  -0.1696   0.6025   0.0004   0.0003  -0.1592   0.5765
#  5.0936E-04|  0.1694  -0.0203   0.0395  -0.5803  -0.5370  -0.0001   0.0004  -0.5810   0.0819
#  5.1117E-03| -0.0255   0.0001  -0.0076   0.6946  -0.3782  -0.0002  -0.0004  -0.2752   0.5459
#  2.9387E-02|  0.0255  -0.0383   0.1561   0.3165   0.3602   0.0005   0.0036  -0.7005  -0.5029
#  3.9829E-01|  0.0035   0.0679  -0.9839   0.0156   0.0507  -0.0004   0.0006  -0.1403  -0.0689
#  1.4612E+01|  0.0035   0.9967   0.0741  -0.0037   0.0067  -0.0032   0.0001  -0.0320  -0.0057
#  7.9193E+05|  0.0000   0.0032  -0.0003   0.0001  -0.0005   1.0000   0.0000   0.0002  -0.0000
# ------------------------------------------------------------------------------------------
#
# ============================================================================================================
#   Covariance Matrix
#         1           2           3           4           5           6           7           8           9
#    1.432e-03   1.495e-01  -5.352e-03   2.076e-03  -1.623e-02   3.086e+01   2.438e-05   4.193e-03  -1.762e-03
#    1.495e-01   2.268e+01   4.046e-01   1.226e-01  -1.295e+00   2.542e+03   3.073e-03   6.981e-02  -1.622e-01
#   -5.352e-03   4.046e-01   5.177e-01  -2.278e-02   9.962e-02  -2.016e+02  -1.869e-04  -2.568e-02   2.470e-02
#    2.076e-03   1.226e-01  -2.278e-02   9.727e-03  -2.815e-02   5.517e+01   5.410e-05   5.275e-03  -4.574e-03
#   -1.623e-02  -1.295e+00   9.962e-02  -2.815e-02   2.446e-01  -4.344e+02  -1.326e-04  -1.049e-01   4.986e-03
#    3.086e+01   2.542e+03  -2.016e+02   5.517e+01  -4.344e+02   7.919e+05   3.605e-01   1.681e+02  -2.429e+01
#    2.438e-05   3.073e-03  -1.869e-04   5.410e-05  -1.326e-04   3.605e-01   9.702e-07  -9.520e-05  -9.467e-05
#    4.193e-03   6.981e-02  -2.568e-02   5.275e-03  -1.049e-01   1.681e+02  -9.520e-05   7.351e-02   1.092e-02
#   -1.762e-03  -1.622e-01   2.470e-02  -4.574e-03   4.986e-03  -2.429e+01  -9.467e-05   1.092e-02   1.208e-02
# ------------------------------------------------------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>*zxipcf<2>(nthComp<3> + diskbb<4>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.211609     +/-  3.78364E-02
#    2    2   zxipcf     Nh         10^22    1.83497      +/-  4.76194
#    3    2   zxipcf     log_xi              1.90684      +/-  0.719547
#    4    2   zxipcf     CvrFract            8.94798E-02  +/-  9.86277E-02
#    5    2   zxipcf     Redshift            0.0          frozen
#    6    3   nthComp    Gamma               1.77456      +/-  0.494608
#    7    3   nthComp    kT_e       keV      22.2363      +/-  889.897
#    8    3   nthComp    kT_bb      keV      0.967915     = p12
#    9    3   nthComp    inp_type   0/1      1.00000      frozen
#   10    3   nthComp    Redshift            0.0          frozen
#   11    3   nthComp    norm                3.28730E-03  +/-  9.85011E-04
#   12    4   diskbb     Tin        keV      0.967915     +/-  0.271124
#   13    4   diskbb     norm                0.114228     +/-  0.109905
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 1903.04     using 1832 bins.
#
# Test statistic : Chi-Squared                 2005.93     using 1832 bins.
#  Null hypothesis probability of 1.62e-03 with 1823 degrees of freedom

# %%
# Save zxipcf parameters and flux immediately
zxipcf_params, _, _, _, _, zxipcf_model_y, zxipcf_residuals = _save_model_and_flux(zxipcf_model)
fit_compare = pd.DataFrame([baseline_result, zxipcf_result]).set_index("model")
fit_compare["delta_stat_vs_baseline"] = fit_compare["stat"] - fit_compare.loc["baseline", "stat"]
fit_compare["delta_dof_vs_baseline"] = fit_compare["dof"] - fit_compare.loc["baseline", "dof"]
fit_compare["delta_AIC_vs_baseline"] = fit_compare["AIC"] - fit_compare.loc["baseline", "AIC"]
fit_compare["delta_BIC_vs_baseline"] = fit_compare["BIC"] - fit_compare.loc["baseline", "BIC"]

preferred = "zxipcf" if fit_compare.loc["zxipcf", "delta_AIC_vs_baseline"] < 2 else "baseline"
preferred_bic = "zxipcf" if fit_compare.loc["zxipcf", "delta_BIC_vs_baseline"] < 2 else "baseline"

preferred_result = zxipcf_result if preferred_bic == "zxipcf" else baseline_result
preferred_expression = preferred_result["expression"]
preferred_snapshot = zxipcf_params if preferred_bic == "zxipcf" else baseline_params

# %%
from IPython.display import display, Markdown

def _format_param_with_error(param_dict):
    val = float(param_dict["value"])
    if param_dict["link"] != "":
        return f"{val:.5g} (linked)"
    if param_dict["frozen"]:
        return f"{val:.5g} (frozen)"
    sigma = float(param_dict.get("sigma", np.nan))
    if np.isfinite(sigma) and sigma > 0:
        return f"{val:.5g} +/- {sigma:.2g}"
    return f"{val:.5g} (err N/A)"

all_keys = list(baseline_params.keys()) + [k for k in zxipcf_params.keys() if k not in baseline_params]

table_rows = []
for k in all_keys:
    b_str = _format_param_with_error(baseline_params[k]) if k in baseline_params else "-"
    z_str = _format_param_with_error(zxipcf_params[k]) if k in zxipcf_params else "-"
    table_rows.append({"Metric / Parameter": k, "Baseline": b_str, "zxipcf": z_str})

table_rows.append({"Metric / Parameter": "--- Fit Statistics ---", "Baseline": "", "zxipcf": ""})
table_rows.append({"Metric / Parameter": "C-stat / DoF",
                   "Baseline": f"{baseline_result['stat']:.2f} / {baseline_result['dof']}",
                   "zxipcf": f"{zxipcf_result['stat']:.2f} / {zxipcf_result['dof']}"})
table_rows.append({"Metric / Parameter": "AIC",
                   "Baseline": f"{baseline_result['AIC']:.2f}",
                   "zxipcf": f"{zxipcf_result['AIC']:.2f}"})
table_rows.append({"Metric / Parameter": "BIC",
                   "Baseline": f"{baseline_result['BIC']:.2f}",
                   "zxipcf": f"{zxipcf_result['BIC']:.2f}"})
table_rows.append({"Metric / Parameter": "Delta AIC (from baseline)",
                   "Baseline": "-",
                   "zxipcf": f"{fit_compare.loc['zxipcf', 'delta_AIC_vs_baseline']:.2f}"})
table_append = table_rows.append({"Metric / Parameter": "Delta BIC (from baseline)",
                   "Baseline": "-",
                   "zxipcf": f"{fit_compare.loc['zxipcf', 'delta_BIC_vs_baseline']:.2f}"})

unified_df = pd.DataFrame(table_rows)

table_md = f"""### Unified Parameter and Fit Comparison (PN)
**Preferred by AIC:** {preferred} | **Preferred by BIC:** {preferred_bic}

{unified_df.to_markdown(index=False)}
"""

display(Markdown(table_md))

unified_csv_path = os.path.join(plot_dir, f"pn_{selected_interval}_comparison.csv")
try:
    unified_df.to_csv(unified_csv_path, index=False)
except Exception:
    pass
# Out:
# ### Unified Parameter and Fit Comparison (PN)
# **Preferred by AIC:** baseline | **Preferred by BIC:** baseline
#
# | Metric / Parameter        | Baseline              | zxipcf                |
# |:--------------------------|:----------------------|:----------------------|
# | TBabs.nH                  | 0.21354 +/- 0.01      | 0.21161 +/- 0.038     |
# | nthComp.Gamma             | 1.8081 +/- 0.097      | 1.7746 +/- 0.49       |
# | nthComp.kT_e              | 5.9076 +/- 19         | 22.236 +/- 8.9e+02    |
# | nthComp.kT_bb             | 0.98627 (linked)      | 0.96791 (linked)      |
# | nthComp.inp_type          | 1 (frozen)            | 1 (frozen)            |
# | nthComp.Redshift          | 0 (frozen)            | 0 (frozen)            |
# | nthComp.norm              | 0.0032014 +/- 0.00082 | 0.0032873 +/- 0.00099 |
# | diskbb.Tin                | 0.98627 +/- 0.085     | 0.96791 +/- 0.27      |
# | diskbb.norm               | 0.088993 +/- 0.18     | 0.11423 +/- 0.11      |
# | zxipcf.Nh                 | -                     | 1.835 +/- 4.8         |
# | zxipcf.log_xi             | -                     | 1.9068 +/- 0.72       |
# | zxipcf.CvrFract           | -                     | 0.08948 +/- 0.099     |
# | zxipcf.Redshift           | -                     | 0 (frozen)            |
# | --- Fit Statistics ---    |                       |                       |
# | C-stat / DoF              | 1905.89 / 1826        | 1903.04 / 1823        |
# | AIC                       | 1917.89               | 1921.04               |
# | BIC                       | 1950.97               | 1970.66               |
# | Delta AIC (from baseline) | -                     | 3.15                  |
# | Delta BIC (from baseline) | -                     | 19.69                 |

# %%
# Keep the best model object in m1 for any follow-up cells.
m1 = _restore_model_from_snapshot(preferred_expression, preferred_snapshot)
# Out:
# ========================================================================
# Model TBabs<1>(nthComp<2> + diskbb<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   nthComp    Gamma               1.70000      +/-  0.0
#    3    2   nthComp    kT_e       keV      100.000      +/-  0.0
#    4    2   nthComp    kT_bb      keV      0.100000     frozen
#    5    2   nthComp    inp_type   0/1      0.0          frozen
#    6    2   nthComp    Redshift            0.0          frozen
#    7    2   nthComp    norm                1.00000      +/-  0.0
#    8    3   diskbb     Tin        keV      1.00000      +/-  0.0
#    9    3   diskbb     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.130967e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              5.976552e+09     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.130967e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              5.976552e+09     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.774095e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.371726e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#   parameter 1 is not frozen.
#
# Fit statistic  : C-Statistic              1.774095e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.371726e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.649800e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.226863e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#   parameter 2 is not frozen.
#
# Fit statistic  : C-Statistic              1.649800e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.226863e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.665961e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.244305e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#   parameter 3 is not frozen.
#
# Fit statistic  : C-Statistic              1.665961e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              1.244305e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              6.965502e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              2.468543e+11     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1826 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              6.965502e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              2.468543e+11     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1825 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              6.965502e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              2.468543e+11     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1825 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              2.657527e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              2.942401e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1825 degrees of freedom
#  Current data and model not fit yet.
#   parameter 5 is already frozen.
#
# Fit statistic  : C-Statistic              2.657527e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              2.942401e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1825 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              2.657527e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              2.942401e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1825 degrees of freedom
#  Current data and model not fit yet.
#   parameter 6 is already frozen.
#
# Fit statistic  : C-Statistic              2.657527e+08     using 1832 bins.
#
# Test statistic : Chi-Squared              2.942401e+10     using 1832 bins.
#  Null hypothesis probability of 0.000000e+00 with 1825 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                179384.7     using 1832 bins.
#
# Test statistic : Chi-Squared                222091.0     using 1832 bins.
#  Null hypothesis probability of 0.0e+00 with 1825 degrees of freedom
#  Current data and model not fit yet.
#   parameter 7 is not frozen.
#
# Fit statistic  : C-Statistic                179384.7     using 1832 bins.
#
# Test statistic : Chi-Squared                222091.0     using 1832 bins.
#  Null hypothesis probability of 0.0e+00 with 1825 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                163702.8     using 1832 bins.
#
# Test statistic : Chi-Squared                199522.7     using 1832 bins.
#  Null hypothesis probability of 0.0e+00 with 1825 degrees of freedom
#  Current data and model not fit yet.
#   parameter 8 is not frozen.
#
# Fit statistic  : C-Statistic                163702.8     using 1832 bins.
#
# Test statistic : Chi-Squared                199522.7     using 1832 bins.
#  Null hypothesis probability of 0.0e+00 with 1825 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                 1905.89     using 1832 bins.
#
# Test statistic : Chi-Squared                 2024.86     using 1832 bins.
#  Null hypothesis probability of 6.74e-04 with 1825 degrees of freedom
#  Current data and model not fit yet.
#   parameter 9 is not frozen.
#
# Fit statistic  : C-Statistic                 1905.89     using 1832 bins.
#
# Test statistic : Chi-Squared                 2024.86     using 1832 bins.
#  Null hypothesis probability of 7.13e-04 with 1826 degrees of freedom
#  Current data and model not fit yet.

# %%
# --- 7. PLOT COMPARISON: baseline vs zxipcf ---
# Create comparison plot
plt.figure(figsize=(16, 10), dpi=75)
gs = plt.GridSpec(2, 1, height_ratios=[3, 1], hspace=0)
# Top panel: Data and both models as overlays
ax1 = plt.subplot(gs[0])
ax1.errorbar(energy_x, data_y, xerr=energy_err, yerr=data_err, fmt='o', ms=2,
             elinewidth=0.8, label='PN Data', color='black', alpha=0.7, zorder=20)

baseline_label_suffix = " (Selected)" if preferred_bic == "baseline" else ""
ax1.step(energy_x, baseline_model_y, where='mid', color='C0', lw=2.5,
         zorder=10, label=f'Baseline (χ²={baseline_result["stat"]:.1f}){baseline_label_suffix}')

zxipcf_label_suffix = " (Selected)" if preferred_bic == "zxipcf" else ""
ax1.step(energy_x, zxipcf_model_y, where='mid', color='C1', lw=5,
         linestyle='--', zorder=9, label=f'zxipcf (χ²={zxipcf_result["stat"]:.1f}){zxipcf_label_suffix}')

ax1.set_yscale("log")
ax1.set_ylabel(y_units, fontsize=14)
#ax1.set_title(f"PN Spectrum Comparison: {selected_interval} - Selected Model: {preferred_bic}", fontsize=14, fontweight='bold')
ax1.set_ylim(3.5e-2,)
ax1.legend(fontsize=20, loc='best')
ax1.grid(True, alpha=0.3)
# Bottom panel: Residuals for both models
ax2 = plt.subplot(gs[1], sharex=ax1)
ax2.step(energy_x, baseline_residuals, where='mid', color='C0', lw=1.5, label='Baseline residuals')
ax2.step(energy_x, zxipcf_residuals, where='mid', color='C1', lw=1.5, linestyle='--',
         label='zxipcf residuals')
ax2.axhline(0, color='red', linestyle='--', lw=1)
ax2.fill_between(energy_x, -3, 3, alpha=0.1, color='gray')
ax2.set_xlabel("Energy (keV)", fontsize=14)
ax2.set_ylabel(r"Residuals ($\chi$)", fontsize=14)
ax2.set_ylim(-5, 5)
ax2.legend(fontsize=16, loc='best')
ax2.grid(True, alpha=0.3)
plt.tight_layout()
comparison_plot_path = os.path.join(plot_dir, f"pn_{selected_interval}_comparison.png")
plt.savefig(comparison_plot_path,
            dpi=300, bbox_inches='tight')
plt.show()
print("\nComparison plot saved to:")
print(f"  {comparison_plot_path}")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Comparison plot saved to:
#   ../products/0865600201/pn/spec/plots/Full_grp/pn_Full_grp_comparison.png

# %%
# --- 8. PYXSPEC NATIVE BLIND LINE SEARCH ---
if run_line_search:
    from pathlib import Path
    import importlib.util
    from IPython.display import Image, display
    def _load_blind_search_module():
        here = Path.cwd().resolve()
        for root in [here, *here.parents]:
            script_path = root / 'scripts' / 'xspec_blind_search' / 'run_blind_search.py'
            if script_path.is_file():
                spec = importlib.util.spec_from_file_location('run_blind_search', script_path)
                if spec is None or spec.loader is None:
                    raise RuntimeError(f'Could not import blind-search script from {script_path}')
                module = importlib.util.module_from_spec(spec)
                spec.loader.exec_module(module)
                return module, root
        raise FileNotFoundError('Could not locate scripts/xspec_blind_search/run_blind_search.py')
    blind_search, repo_root = _load_blind_search_module()
    pn_out_dir = str(Path(plot_dir))
    pn_argv = [
        'pn',
        '--products-root', str(repo_root / 'products'),
        '--obsid', '0865600201',
        '--interval', base_interval,
        '--model-expr', preferred_expression,
        '--fit-stat', 'cstat',
        '--dlambda', '0.01',
        '--energy-min', '0.7',
        '--energy-max', '7.0',
        '--norm-guess', '1e-4',
        '--norm-min', '-1.0',
        '--norm-max', '1.0',
        '--progress-every', '10',
        '--out-dir', pn_out_dir,
        '--overwrite',
    ]
    if use_grouped:
        pn_argv.append('--grouped')
    if use_background:
        pn_argv.append('--use-background')
     # NOTE: Use --use-current-state to avoid hanging on Model() creation and use existing fit
     # The continuum parameters are already set from the notebook fit above
    pn_argv.append('--use-current-state')
    status = blind_search.main(pn_argv)
    pn_plot_path = Path(pn_out_dir) / f'blind_search_{selected_interval}_native.png'
    print(f'PN blind-search script exit status: {status}')
    print(f'PN blind-search plot: {pn_plot_path}')
    display(Image(filename=str(pn_plot_path)))
else:
    print("Line search skipped (run_line_search=False)")
# Out:
# Line search skipped (run_line_search=False)
