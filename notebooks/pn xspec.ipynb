# %%
import xspec as x
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np
from astropy.io import fits
# %matplotlib widget

# %%
#Load relxill and test it

# --- STEP 1: DEFINE PATHS ---
# Path to the folder where you compiled relxill (contains lmodel.dat)
# relxill_dir = "/home/kyle/software/relxill"

# Path to the folder containing the heavy FITS tables (often the same dir)
# relxill_tables = "/home/kyle/software/relxill"

# --- STEP 2: SET ENVIRONMENT VARIABLE ---
# This tells relxill where to look for the tables so you don't have to copy them
# os.environ["RELXILL_TABLE_PATH"] = relxill_tables

# --- STEP 3: LOAD THE MODEL ---
# This mimics the "lmod relxill /path" command
# print("Loading Relxill...")
# x.AllModels.lmod("relxill", relxill_dir)

# --- STEP 4: USE IT ---
# Now you can use 'relxill', 'relxillCp', 'relxilllp', etc.
# Example: simple relativistic reflection
# m = x.Model("tbabs * relxillns")

# Verify it loaded
# print(m.componentNames)

# %%
# --- 1. SETUP & DATA LOADING ---
x.AllData.clear()
x.AllModels.clear()

# --- PN: interval + full-spectrum options ---
time_intervals_pn = {
    "Full": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_spectrum.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_spectrum.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf.arf",
    },
    "Full_grp": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_spectrum_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_spectrum.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf.arf",
    },
    "Dipping": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Dipping.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Dipping.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Dipping.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Dipping.arf",
    },
    "Dipping_grp": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Dipping_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Dipping.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Dipping.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Dipping.arf",
    },
    "Persistent": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Persistent.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Persistent.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Persistent.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Persistent.arf",
    },
    "Persistent_grp": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Persistent_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Persistent.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Persistent.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Persistent.arf",
    },
    "Shallow": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Shallow.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Shallow.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Shallow.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Shallow.arf",
    },
    "Shallow_grp": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Shallow_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Shallow.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Shallow.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Shallow.arf",
    },
    "Dipping_LowFlux": {
        "pn_spec": "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_LowFlux.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/flux_resolved/pn_bkg_Dipping_LowFlux.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_LowFlux.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_LowFlux.arf",
    },
    "Dipping_LowFlux_grp": {
        "pn_spec": "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_LowFlux_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/flux_resolved/pn_bkg_Dipping_LowFlux.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_LowFlux.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_LowFlux.arf",
    },
    "Dipping_HighFlux": {
        "pn_spec": "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_HighFlux.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/flux_resolved/pn_bkg_Dipping_HighFlux.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_HighFlux.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_HighFlux.arf",
    },
    "Dipping_HighFlux_grp": {
        "pn_spec": "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_HighFlux_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/flux_resolved/pn_bkg_Dipping_HighFlux.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_HighFlux.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/flux_resolved/pn_Dipping_HighFlux.arf",
    },
}

# %%
# Choose: "Full", "Dipping", "Persistent", "Shallow", "Dipping_LowFlux", "Dipping_HighFlux"
def interval_key(interval, grouped=False):
    return f"{interval}_grp" if grouped else interval

base_interval = "Full"
use_grouped = True
use_background = True
run_line_search = True

selected_interval = interval_key(base_interval, use_grouped)
pn_data = time_intervals_pn[selected_interval]

plot_dir = os.path.join("..", "products", "0865600201", "pn", "spec", "plots", selected_interval)
os.makedirs(plot_dir, exist_ok=True)

pn_spec = pn_data["pn_spec"]
pn_bkg  = pn_data["pn_bkg"]
pn_rmf  = pn_data["pn_rmf"]
pn_arf  = pn_data["pn_arf"]

# Load PN (once)the
x.AllData(pn_spec)
s = x.AllData(1)
if use_background:
    s.background = pn_bkg
s.response = pn_rmf
s.response.arf = pn_arf

x.AllData.ignore("bad")
s.ignore("**-0.7 7.0-**")  # Ignore outside 0.8-10 keV

# Global XSPEC settings
x.Plot.device = "/null"
x.Plot.xAxis = "keV"
x.Xset.xsect = "vern"
x.Xset.abund = "wilm"


# --- 2. MODEL DEFINITION ---
# Defining the model for the loaded PN data
m1 = x.Model("tbabs * (nthcomp + diskbb)")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: ../products/0865600201/pn/spec/pn_source_spectrum_grp.pha  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  8.183e+00 +/- 1.003e-02
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-3303
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 8.128e+04 sec
#  Using fit statistic: chi
#  No response loaded.
#
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Net count rate (cts/s) for Spectrum:1  5.910e+00 +/- 1.986e-02 (72.2 % total)
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Response successfully loaded.
# Arf successfully loaded.
#
# ignore:  1099 channels ignored from  source number 1
#     95 channels (1-95) ignored in spectrum #     1
#   1944 channels (1360-3303) ignored in spectrum #     1
#
#  Cross Section Table set to vern:  Verner, Ferland, Korista, and Yakovlev 1996
#  Solar Abundance Vector set to wilm:  Wilms, J., Allen, A. & McCray, R. ApJ 542 914 (2000) (abundances are set to zero for those elements not included in the paper).
#
# ========================================================================
# Model TBabs<1>(nthComp<2> + diskbb<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   nthComp    Gamma               1.70000      +/-  0.0
#    3    2   nthComp    kT_e       keV      100.000      +/-  0.0
#    4    2   nthComp    kT_bb      keV      0.100000     frozen
#    5    2   nthComp    inp_type   0/1      0.0          frozen
#    6    2   nthComp    Redshift            0.0          frozen
#    7    2   nthComp    norm                1.00000      +/-  0.0
#    8    3   diskbb     Tin        keV      1.00000      +/-  0.0
#    9    3   diskbb     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              5.802905e+09     using 1264 bins.
#
# Test statistic : Chi-Squared              5.802905e+09     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.

# %%
# --- 4. FITTING ---



m1(1).values = 0.25
m1(1).frozen = False
m1(2).values = 1.8
m1(3).values = 50
m1(3).frozen = False
m1(4).link = "p8"

m1(5).values = 1
m1(5).frozen = True
m1(7).values = 0.005
m1(8).values = 0.8
m1(9).values = 0.002

# m1(10).values = 10
# m1(11).values = 0.5
# Out:
# Fit statistic  : Chi-Squared              1.268909e+10     using 1264 bins.
#
# Test statistic : Chi-Squared              1.268909e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#   parameter 1 is not frozen.
#
# Fit statistic  : Chi-Squared              1.141428e+10     using 1264 bins.
#
# Test statistic : Chi-Squared              1.141428e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.142565e+10     using 1264 bins.
#
# Test statistic : Chi-Squared              1.142565e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#   parameter 3 is not frozen.
#
# Fit statistic  : Chi-Squared              2.163709e+11     using 1264 bins.
#
# Test statistic : Chi-Squared              2.163709e+11     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              2.676352e+10     using 1264 bins.
#
# Test statistic : Chi-Squared              2.676352e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#   parameter 5 is already frozen.
#
# Fit statistic  : Chi-Squared                515688.9     using 1264 bins.
#
# Test statistic : Chi-Squared                515688.9     using 1264 bins.
#  Null hypothesis probability of 0.0e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                148863.3     using 1264 bins.
#
# Test statistic : Chi-Squared                148863.3     using 1264 bins.
#  Null hypothesis probability of 0.0e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                30409.51     using 1264 bins.
#
# Test statistic : Chi-Squared                30409.51     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.

# %%
x.Fit.statMethod = "cstat"
x.Fit.query = "yes"
x.Fit.perform()
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
#
# Fit statistic  : C-Statistic                30162.04     using 1264 bins.
#
# Test statistic : Chi-Squared                30409.51     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH       2:Gamma        3:kT_e        7:norm         8:Tin        9:norm
# 5116.88      4.00015e+06  -3      0.202501       1.92828       14.6796    0.00410136      0.846887   0.000244113
# 2351.19      1.30861e+06  -3      0.203883       1.89787       2.33188    0.00375188      0.862356   3.50201e-05
# 1774.26      507309       -3      0.215753       2.19824       5.73004    0.00365898       1.12778   9.40392e-06
# 1714.4       448909       -4      0.220306       2.13908       19.7674    0.00320885       1.19116     0.0658963
# 1563.81      433601       -3      0.219987       1.93281       151.359    0.00315954       1.15915     0.0677106
# 1332.19      382508       -3      0.214845       1.83236       966.676    0.00312307       1.08145     0.0815433
# 1330.1       48787.7      -2      0.212711       1.84917       230.040    0.00311512       1.06710     0.0862498
# 1322.51      69561.4      -2      0.214175       1.83878       78.1398    0.00311343       1.06201     0.0894426
# 1320.11      36125.1      -1      0.214770       1.83569       46.2166    0.00311468       1.06267     0.0899149
# 1319.98      7963.15      -1      0.214816       1.83615       46.8489    0.00311396       1.06206     0.0901770
# 1319.97      361.026      -1      0.214856       1.83594       44.8979    0.00311347       1.06162     0.0904340
# 1319.95      338.373      -1      0.214887       1.83565       43.4004    0.00311297       1.06122     0.0906724
# 1319.94      322.784      -1      0.214913       1.83533       42.1790    0.00311248       1.06084     0.0909032
# 1319.93      244.588      -1      0.214900       1.83530       39.1789    0.00311185       1.06038     0.0911243
# 1319.89      534.196      -2      0.214987       1.83322       28.4436    0.00310646       1.05758     0.0930547
# 1319.82      5756.78      -1      0.214901       1.83372       27.8813    0.00310560       1.05708     0.0932442
# 1319.79      441.545      -2      0.214857       1.83271       21.1290    0.00309980       1.05466     0.0950237
# 1319.67      5953.35      -2      0.214695       1.83257       17.3534    0.00309361       1.05224     0.0967389
# 1319.63      3886.01      -1      0.214621       1.83294       17.0997    0.00309281       1.05187     0.0969126
# 1319.62      331.43       -1      0.214594       1.83299       16.7225    0.00309216       1.05161     0.0970925
# ======================================================================
#  Variances and Principal Axes
#                  1        2        3        7        8        9
#  3.6790E-11| -0.0019  -0.0008  -0.0000   1.0000   0.0023   0.0034
#  5.2578E-06|  0.8620  -0.2262  -0.0004   0.0023   0.2206  -0.3963
#  3.5190E-05| -0.4961  -0.4677  -0.0005   0.0007   0.1898  -0.7064
#  1.4293E-03|  0.1012  -0.5214   0.0005   0.0016  -0.8460   0.0469
#  5.6168E-02|  0.0232   0.6769   0.0013   0.0036  -0.4468  -0.5845
#  2.3945E+05| -0.0000   0.0009  -1.0000   0.0000  -0.0012  -0.0003
# ----------------------------------------------------------------------
#
# ========================================================================
#   Covariance Matrix
#         1           2           3           4           5           6
#    3.538e-04  -7.101e-03   8.422e+00  -1.854e-05   9.676e-03   1.591e-03
#   -7.101e-03   2.377e-01  -2.251e+02   7.618e-04  -2.939e-01  -8.471e-02
#    8.422e+00  -2.251e+02   2.395e+05  -6.667e-01   2.952e+02   6.645e+01
#   -1.854e-05   7.618e-04  -6.667e-01   2.582e-06  -9.138e-04  -3.027e-04
#    9.676e-03  -2.939e-01   2.952e+02  -9.138e-04   3.762e-01   9.653e-02
#    1.591e-03  -8.471e-02   6.645e+01  -3.027e-04   9.653e-02   3.765e-02
# ------------------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(nthComp<2> + diskbb<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.214594     +/-  1.88092E-02
#    2    2   nthComp    Gamma               1.83299      +/-  0.487549
#    3    2   nthComp    kT_e       keV      16.7225      +/-  489.336
#    4    2   nthComp    kT_bb      keV      1.05161      = p8
#    5    2   nthComp    inp_type   0/1      1.00000      frozen
#    6    2   nthComp    Redshift            0.0          frozen
#    7    2   nthComp    norm                3.09216E-03  +/-  1.60696E-03
#    8    3   diskbb     Tin        keV      1.05161      +/-  0.613366
#    9    3   diskbb     norm                9.70925E-02  +/-  0.194045
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 1319.62     using 1264 bins.
#
# Test statistic : Chi-Squared                 1324.55     using 1264 bins.
#  Null hypothesis probability of 9.39e-02 with 1258 degrees of freedom

# %%
print("\n" + "="*110)
print(f"{'GROUP':<5} | {'C#':<3} | {'P#':<3} | {'COMPONENT':<12} | {'PARAMETER':<12} | {'UNIT':<12} | {'VALUE':<12} | {'ERROR'}")
print("-" * 110)

global_par_idx = 1

for comp_idx, comp_name in enumerate(m1.componentNames, start=1):
    comp = getattr(m1, comp_name)
    for par_name in comp.parameterNames:
        par = getattr(comp, par_name)

        # 5 significant figures for numeric values
        val = par.values[0]
        val_str = f"{val:.5g}" if isinstance(val, (int, float, np.floating)) else str(val)

        # Unit column
        unit = getattr(par, "unit", "")
        unit_str = unit if unit not in ("", None) else "-"

        if par.link != "":
            err_str = f"LINKED ({par.link})"
        elif par.frozen:
            err_str = "FROZEN"
        else:
            err_str = f"+/- {par.sigma:.5g}" if par.sigma > 0 else "N/A"

        print(
            f"{'1':<5} | {comp_idx:<3} | {global_par_idx:<3} | "
            f"{comp_name:<12} | {par_name:<12} | {unit_str:<12} | {val_str:<12} | {err_str}"
        )

        global_par_idx += 1

print("-" * 110)
print(f"Final {x.Fit.statMethod.upper()}: {x.Fit.statistic:.5g}")
print(f"Degrees of Freedom: {x.Fit.dof}")
print(f"Reduced Statistic: {(x.Fit.statistic / x.Fit.dof):.5g}")
print("="*110 + "\n")
# Out:
# ==============================================================================================================
# GROUP | C#  | P#  | COMPONENT    | PARAMETER    | UNIT         | VALUE        | ERROR
# --------------------------------------------------------------------------------------------------------------
# 1     | 1   | 1   | TBabs        | nH           | 10^22        | 0.21459      | +/- 0.018809
# 1     | 2   | 2   | nthComp      | Gamma        | -            | 1.833        | +/- 0.48755
# 1     | 2   | 3   | nthComp      | kT_e         | keV          | 16.722       | +/- 489.34
# 1     | 2   | 4   | nthComp      | kT_bb        | keV          | 1.0516       | LINKED (= p8)
# 1     | 2   | 5   | nthComp      | inp_type     | 0/1          | 1            | FROZEN
# 1     | 2   | 6   | nthComp      | Redshift     | -            | 0            | FROZEN
# 1     | 2   | 7   | nthComp      | norm         | -            | 0.0030922    | +/- 0.001607
# 1     | 3   | 8   | diskbb       | Tin          | keV          | 1.0516       | +/- 0.61337
# 1     | 3   | 9   | diskbb       | norm         | -            | 0.097092     | +/- 0.19405
# --------------------------------------------------------------------------------------------------------------
# Final CSTAT: 1319.6
# Degrees of Freedom: 1258
# Reduced Statistic: 1.049
# ==============================================================================================================

# %%
# --- 5. PLOTTING ---

# Set rebinning for the plot only (e.g., min significance 7, max 10 bins)
# x.Plot.setRebin(1,1)
x.Plot.device = "/null"
x.Plot.xAxis = "keV"
x.Plot.add = True

# Extract Data
x.Plot("data")
energy_x   = x.Plot.x(1)
energy_err = x.Plot.xErr(1)
data_y     = x.Plot.y(1)
data_err   = x.Plot.yErr(1)
model_y    = x.Plot.model(1)


y_units = x.Plot.labels()[1]
print(y_units)
# Extract Residuals
x.Plot("delchi")
residuals  = x.Plot.y(1)


e  = np.array(energy_x)
ee = np.array(energy_err)
dy = np.array(data_y)
de = np.array(data_err)
my = np.array(model_y)
res = np.array(residuals)

#background

if use_background:
    x.Plot("background")
    bkg = x.Plot.y(1)
    bkg_err = x.Plot.yErr(1)
# Out:
# counts s$^{-1}$ keV$^{-1}$

# %%
# Plotting


plt.style.use('default')


plt.figure(figsize=(16, 9), dpi=75)
gs = plt.GridSpec(2, 1, height_ratios=[3, 1], hspace=0)

# Top panel: Data and Model
ax1 = plt.subplot(gs[0])
ax1.errorbar(e, dy, xerr=ee, yerr=de, fmt='o', ms=2, elinewidth=0.8, label='PN Data')
ax1.step(e, my, where='mid', color='C1', lw=1.5, zorder=10, label='Model')
ax1.set_yscale("log")
ax1.set_ylabel(fr"{y_units}", fontsize=16)
#ax1.set_title(f"PN Spectrum for {selected_interval}: {m1.expression}")
#background
if use_background:
    ax1.errorbar(e, bkg, yerr=bkg_err, color='black', fmt='o',ms=2, elinewidth=0.8, label='Background')
ax1.set_ylim(1e-2,)

# Bottom panel: Residuals
ax2 = plt.subplot(gs[1], sharex=ax1)
ax2.step(e, res, where='mid', color='black', lw=1.2)
# ax2.errorbar(e, res, xerr=ee, fmt='none', ecolor='black', elinewidth=0.8, capsize=2)
ax2.axhline(0, color='red', linestyle='--')
# ax2.set_ylim(-4,4)

ax2.set_xlabel("Energy (keV)",fontsize=16)
ax2.set_ylabel(r"Residuals ($\chi$)", fontsize=16)
ax1.legend(fontsize=14, loc='best')
plt.tight_layout()
plt.savefig(os.path.join(plot_dir, f"pn_{selected_interval}_fit.png"), dpi=300, bbox_inches='tight')

# %%
# Quick check: Calculate counts from rates to decide on statistic
exposure = s.exposure
counts = np.array([r * exposure for r in s.values if r > 0])
min_counts = np.min(counts)
median_counts = np.median(counts)

print(f"Exposure: {exposure:.1f} s")
print(f"Min counts/bin: {min_counts:.1f}")
print(f"Median counts/bin: {median_counts:.1f}")

if min_counts < 20:
    print("\n--- RECOMMENDATION ---")
    print(f"Minimum counts ({min_counts:.1f}) is below 20.")
    print("Gaussian statistics (Chi-Squared) are invalid for low-count bins.")
    print("Use 'cstat' for the most reliable results.")
else:
    print("\n--- RECOMMENDATION ---")
    print(f"All bins have >= 20 counts (Min: {min_counts:.1f}).")
    print("You can safely use 'chi' (Chi-Squared) or 'cstat'.")
# Out:
# Exposure: 81275.1 s
# Min counts/bin: 54.0
# Median counts/bin: 235.0
#
# --- RECOMMENDATION ---
# All bins have >= 20 counts (Min: 54.0).
# You can safely use 'chi' (Chi-Squared) or 'cstat'.

# %%
# import os
# import re
# import numpy as np
# from astropy.io import fits
#
# # -----------------------------
# # 1) Configure and run chain
# # -----------------------------
# x.AllChains.clear()
#
# chain_len = 5000
# burn_len = 500
# chain_file = f"../products/0865600201/pn/spec/pn_{selected_interval}_mcmc_chain.fits"
#
# if os.path.exists(chain_file):
#     os.remove(chain_file)
#
# x.AllChains.defLength = chain_len
# x.AllChains.defBurn = burn_len
# x.AllChains.defRand = True
#
# # Some builds support this, some may not
# try:
#     x.AllChains.defProposal = "gaussian fit"
# except Exception:
#     pass
#
# print("AllChains defaults:")
# print("  defLength :", x.AllChains.defLength)
# print("  defBurn   :", x.AllChains.defBurn)
# try:
#     print("  defProposal:", x.AllChains.defProposal)
# except Exception:
#     print("  defProposal: <not available in this PyXspec build>")
# print("  defRand   :", x.AllChains.defRand)
#
# print(f"\nRunning chain: {chain_file}")
# ch = x.Chain(chain_file)
#
#
# # Optional XSPEC-side chain info (works in most builds)
# try:
#     x.AllChains.show()
# except Exception:
#     pass
#
# # Version-safe chain length check: count FITS table rows
# with fits.open(chain_file) as hdul:
#     data = hdul[1].data
#     colnames = list(hdul[1].columns.names)
#     nrows = len(data)
#
# print(f"\nactual chain rows in FITS: {nrows}")
#
# # -----------------------------
# # 2) Build model parameter map
# # -----------------------------
# all_params = []
# global_idx = 1
# for comp_name in m1.componentNames:
#     comp = getattr(m1, comp_name)
#     for par_name in comp.parameterNames:
#         par = getattr(comp, par_name)
#         all_params.append({
#             "idx": global_idx,
#             "name": f"{comp_name}.{par_name}",
#             "frozen": par.frozen,
#             "linked": (par.link != ""),
#             "value": par.values[0],
#             "status": "LINKED" if par.link != "" else ("FROZEN" if par.frozen else "FREE"),
#             "link": par.link
#         })
#         global_idx += 1
#
# free_params = [p for p in all_params if (not p["frozen"] and not p["linked"])]
#
# # -----------------------------
# # 3) Identify chain parameter columns
# # -----------------------------
# exclude = {"FIT_STATISTIC", "STATISTIC", "CHI2", "CHAIN", "ACCEPT", "ACCEPTANCE"}
# par_cols = []
# for c in colnames:
#     if c.upper() in exclude:
#         continue
#     arr = np.asarray(data[c])
#     if np.issubdtype(arr.dtype, np.number):
#         par_cols.append(c)
#
#
# def parse_idx(col):
#     # XSPEC-style names often end with "__<global_index>", e.g. "Gamma__2"
#     m = re.search(r"__(\d+)$", col)
#     return int(m.group(1)) if m else None
#
#
# col_idx = {c: parse_idx(c) for c in par_cols}
# have_explicit_idx = all(v is not None for v in col_idx.values())
#
# if have_explicit_idx:
#     par_cols = sorted(par_cols, key=lambda c: col_idx[c])
#     free_by_idx = {p["idx"]: p for p in free_params}
#     mapped = []
#     for c in par_cols:
#         idx = col_idx[c]
#         if idx in free_by_idx:
#             mapped.append((c, free_by_idx[idx]))
#         else:
#             # Rare fallback if model state changed
#             mapped.append((c, {"idx": idx, "name": c, "status": "FREE"}))
# else:
#     # Fallback by order if no explicit index suffixes are present
#     if len(par_cols) != len(free_params):
#         raise RuntimeError(
#             "Could not map chain columns reliably by order. "
#             f"Columns={par_cols}, free_params={len(free_params)}"
#         )
#     mapped = list(zip(par_cols, free_params))
#
# # -----------------------------
# # 4) Posterior interval table (sampled params)
# # -----------------------------
# print("\n" + "=" * 130)
# print(f"{'P#':<4} {'PARAMETER':<34} {'MEDIAN':>12} {'68% CI':>30} {'90% CI':>30}")
# print("-" * 130)
#
# for col, p in mapped:
#     samples = np.asarray(data[col], dtype=float)
#
#     q16, q50, q84 = np.percentile(samples, [16, 50, 84])  # ~68%
#     q05, q95 = np.percentile(samples, [5, 95])  # 90%
#
#     lo68, hi68 = q50 - q16, q84 - q50
#     lo90, hi90 = q50 - q05, q95 - q50
#
#     print(
#         f"{p['idx']:<4} {p['name']:<34} "
#         f"{q50:>12.5g} "
#         f"[-{lo68:.5g}, +{hi68:.5g}]".rjust(30) + " "
#                                                   f"[-{lo90:.5g}, +{hi90:.5g}]".rjust(30)
#     )
#
# print("=" * 130)
#
# # -----------------------------
# # 5) Non-sampled params table (linked/frozen)
# # -----------------------------
# nonsampled = [p for p in all_params if p["status"] != "FREE"]
# if nonsampled:
#     print("\nNon-sampled model parameters:")
#     print("-" * 90)
#     print(f"{'P#':<4} {'PARAMETER':<34} {'VALUE':>12} {'STATUS':>12} {'LINK':>20}")
#     print("-" * 90)
#     for p in nonsampled:
#         link_txt = p["link"] if p["status"] == "LINKED" else "-"
#         print(f"{p['idx']:<4} {p['name']:<34} {p['value']:>12.5g} {p['status']:>12} {link_txt:>20}")
#     print("-" * 90)

# %%
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Optional extra visual burn-in cut (for plotting only)
# plot_burn_frac = 0.1  # set 0.0 to disable
# nrows = len(data)
# i0 = int(plot_burn_frac * nrows)
#
# n = len(mapped)
# ncols = 3
# nrows_grid = int(np.ceil(n / ncols))
#
# fig, axes = plt.subplots(nrows_grid, ncols, figsize=(5 * ncols, 3.5 * nrows_grid))
# axes = np.atleast_1d(axes).ravel()
#
# for k, (col, p) in enumerate(mapped):
#     s = np.asarray(data[col], dtype=float)[i0:]
#
#     q16, q50, q84 = np.percentile(s, [16, 50, 84])
#
#     ax = axes[k]
#     ax.hist(s, bins=60, density=True, alpha=0.75)
#     ax.axvline(q50, ls='-', lw=1.5, color='k', label='median')
#     ax.axvline(q16, ls='--', lw=1.2, color='k', alpha=0.8)
#     ax.axvline(q84, ls='--', lw=1.2, color='k', alpha=0.8)
#
#     ax.set_title(f"P{p['idx']}: {p['name']}")
#     ax.set_xlabel("value")
#     ax.set_ylabel("density")
#     ax.legend(fontsize=8)
#
# # Hide unused panels
# for j in range(n, len(axes)):
#     axes[j].axis("off")
#
# plt.tight_layout()
# plt.show()

# %%
# import numpy as np
# import corner
# import matplotlib.pyplot as plt
#
# plot_burn_frac = 0.1
# i0 = int(plot_burn_frac * len(data))
#
# samples = np.column_stack([np.asarray(data[col], dtype=float)[i0:] for col, _ in mapped])
# labels = [f"P{p['idx']} {p['name']}" for _, p in mapped]
#
# fig = corner.corner(
#     samples,
#     labels=labels,
#     quantiles=[0.16, 0.5, 0.84],
#     show_titles=True,
#     title_fmt=".4g",
#     bins=40
# )
# plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
#
# # burn-in cut for diagnostics
# i0 = int(0.1 * len(data))
#
# # find chain columns by XSPEC global index
# idx_to_col = {}
# for col, p in mapped:
#     idx_to_col[p["idx"]] = col
#
# if 7 not in idx_to_col or 8 not in idx_to_col:
#     raise RuntimeError("Could not find P7 (nthcomp.norm) and/or P8 (diskbb.Tin) in mapped chain columns.")
#
# n7 = np.asarray(data[idx_to_col[7]], dtype=float)[i0:]  # nthcomp.norm
# t8 = np.asarray(data[idx_to_col[8]], dtype=float)[i0:]  # diskbb.Tin
#
# r = np.corrcoef(n7, t8)[0, 1]
# print(f"Pearson r(P7 nthcomp.norm, P8 diskbb.Tin) = {r:.3f}")
#
# plt.figure(figsize=(6, 5))
# plt.scatter(t8, n7, s=3, alpha=0.2)
# plt.xlabel("P8 diskbb.Tin")
# plt.ylabel("P7 nthcomp.norm")
# plt.title(f"Degeneracy check: r = {r:.3f}")
# plt.tight_layout()
# plt.show()

# %%
# --- 6. MODEL COMPARISON: baseline vs zxipcf ---
def _set_par(model, comp_name, par_name, values=None, frozen=None, link=None):
    """Safely set a parameter only if component/parameter exists in the model."""
    cname_match = next((c for c in model.componentNames if c.lower() == comp_name.lower()), None)
    if not cname_match:
        return False
    comp = getattr(model, cname_match)
    pname_match = next((p for p in comp.parameterNames if p.lower() == par_name.lower()), None)
    if not pname_match:
        return False
    par = getattr(comp, pname_match)
    if values is not None:
        par.values = values
    if frozen is not None:
        par.frozen = frozen
    if link is not None:
        par.link = link
    return True
def _global_par_index(model, target_comp, target_par):
    """Return XSPEC global parameter index for link expressions (p#)."""
    idx = 1
    for comp_name in model.componentNames:
        comp = getattr(model, comp_name)
        for par_name in comp.parameterNames:
            if comp_name.lower() == target_comp.lower() and par_name.lower() == target_par.lower():
                return idx
            idx += 1
    return None
def _n_free_params(model):
    n_free = 0
    for comp_name in model.componentNames:
        comp = getattr(model, comp_name)
        for par_name in comp.parameterNames:
            p = getattr(comp, par_name)
            if (not p.frozen) and (p.link == ""):
                n_free += 1
    return n_free
def _safe_sigma(par):
    """Return finite positive sigma when XSPEC provides one."""
    try:
        sigma = float(par.sigma)
    except Exception:
        return np.nan
    return sigma if np.isfinite(sigma) and sigma > 0 else np.nan
def _apply_continuum_start_values(model):
    # Use bounded starts for continuum parameters to match the zxipcf setup style.
    _set_par(model, "tbabs", "nH", values=[0.2, 0.01, 0.01, 0.01, 5.0, 10.0], frozen=False)
    _set_par(model, "nthcomp", "Gamma", values=[1.8, 0.01, 1.0, 1.0, 3.5, 5.0])
    _set_par(model, "nthcomp", "kT_e", values=[50.0, 0.1, 1.0, 1.0, 200.0, 300.0], frozen=False)
    _set_par(model, "nthcomp", "inp_type", values=1.0, frozen=True)
    _set_par(model, "nthcomp", "Redshift", values=[0.0, 0.001, -0.01, -0.01, 0.01, 0.01], frozen=True)
    _set_par(model, "nthcomp", "norm", values=[0.003, 0.01, 1.0e-6, 1.0e-6, 1.0e3, 1.0e6])
    _set_par(model, "diskbb", "Tin", values=[0.8, 0.01, 0.05, 0.05, 3.0, 5.0])
    _set_par(model, "diskbb", "norm", values=[0.001, 0.01, 1.0e-4, 1.0e-4, 1.0e5, 1.0e6])
    # Keep kTbb tied to diskbb Tin as in the original setup.
    tin_idx = _global_par_index(model, "diskbb", "Tin")
    if tin_idx is not None:
        _set_par(model, "nthcomp", "kT_bb", link=f"p{tin_idx}")
def _apply_zxipcf_start_values(model, freeze_map=None):
    # zxipcf fits are much more stable if Redshift stays frozen at 0.
    # You can override each freeze flag independently via freeze_map.
    log_xi_lower_bound = 0.0
    candidates = {
        # XSPEC 6-value format: [val, delta, min, bottom, top, max]
        "Nh": [0.3, 0.01, 0.001, 0.001, 100.0, 100.0],
        # Set an explicit lower bound for log_xi to avoid unphysical low-ionization drifts.
        "log_xi": [3.0, 0.01, log_xi_lower_bound, log_xi_lower_bound, 6.0, 6.0],
        "CvrFract": [0.8, 0.01, 0.0, 0.0, 1.0, 1.0],
        "Redshift": [0.0, 0.001, -0.01, -0.01, 0.01, 0.01],
    }
    default_freeze = {
        "Nh": False,
        "log_xi": False,
        "CvrFract": False,
        "Redshift": True,
    }

    # Accept either exact keys or case-insensitive keys.
    user_freeze = {}
    if isinstance(freeze_map, dict):
        for k, v in freeze_map.items():
            user_freeze[str(k).lower()] = bool(v)

    if not any(c.lower() == "zxipcf" for c in model.componentNames):
        return

    for name, value in candidates.items():
        _set_par(model, "zxipcf", name, values=value)
        freeze_flag = default_freeze[name]
        if name.lower() in user_freeze:
            freeze_flag = user_freeze[name.lower()]
        _set_par(model, "zxipcf", name, frozen=freeze_flag)


def fit_model(label, expression, add_zxipcf=False, freeze_zxipcf_params=None):
    x.AllModels.clear()
    model = x.Model(expression)
    _apply_continuum_start_values(model)
    if add_zxipcf:
        _apply_zxipcf_start_values(model, freeze_map=freeze_zxipcf_params)
    try:
        x.Fit.perform()
    except Exception:
        print(f"Fit failed for {label}: {expression}")
        print(f"zxipcf enabled: {add_zxipcf}, freeze_zxipcf_params: {freeze_zxipcf_params}")
        raise
    stat = float(x.Fit.statistic)
    dof = int(x.Fit.dof)
    red_stat = stat / dof if dof > 0 else np.nan
    k_free = _n_free_params(model)
    n_bins = dof + k_free
    aic = stat + 2 * k_free
    bic = stat + k_free * np.log(n_bins) if n_bins > 0 else np.nan
    return {
        "model": label,
        "expression": expression,
        "stat": stat,
        "dof": dof,
        "red_stat": red_stat,
        "k_free": k_free,
        "n_bins": n_bins,
        "AIC": aic,
        "BIC": bic,
    }, model
# Use the same fit statistic as above
x.Fit.statMethod = "cstat"
x.Fit.query = "yes"
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
#
# Fit statistic  : C-Statistic                 1319.62     using 1264 bins.
#
# Test statistic : Chi-Squared                 1324.55     using 1264 bins.
#  Null hypothesis probability of 9.39e-02 with 1258 degrees of freedom
#  Current data and model not fit yet.

# %%
baseline_result, baseline_model = fit_model(
    "baseline",
    "tbabs * (nthcomp + diskbb)",
    add_zxipcf=False,
)

# IMPORTANT: Extract model data immediately while model is active
def _save_model_and_flux(model_obj):
    """Save parameters and extract folded model flux immediately."""
    params = {}
    for comp_name in model_obj.componentNames:
        comp = getattr(model_obj, comp_name)
        for par_name in comp.parameterNames:
            par = getattr(comp, par_name)
            params[f"{comp_name}.{par_name}"] = {
                "value": par.values[0],
                "frozen": par.frozen,
                "link": par.link,
                "sigma": _safe_sigma(par),
            }

    # Extract folded model data while active
    x.Plot("data")
    energy = np.array(x.Plot.x(1))
    energy_err = np.array(x.Plot.xErr(1))
    data_y = np.array(x.Plot.y(1))
    data_err = np.array(x.Plot.yErr(1))
    model_y = np.array(x.Plot.model(1))

    # Extract residuals
    x.Plot("delchi")
    residuals = np.array(x.Plot.y(1))

    return params, energy, energy_err, data_y, data_err, model_y, residuals


def _restore_model_from_snapshot(expression, snapshot):
    """Rebuild a live XSPEC model and restore saved parameter values/frozen/link states."""
    x.AllModels.clear()
    model_obj = x.Model(expression)

    # First pass: restore numeric values and frozen flags with links cleared.
    for comp_name in model_obj.componentNames:
        comp = getattr(model_obj, comp_name)
        for par_name in comp.parameterNames:
            key = f"{comp_name}.{par_name}"
            if key not in snapshot:
                continue
            p = getattr(comp, par_name)
            p.link = ""
            p.values = snapshot[key]["value"]
            p.frozen = snapshot[key]["frozen"]

    # Second pass: re-apply links after all parameter values are set.
    for comp_name in model_obj.componentNames:
        comp = getattr(model_obj, comp_name)
        for par_name in comp.parameterNames:
            key = f"{comp_name}.{par_name}"
            if key not in snapshot:
                continue
            link_expr = snapshot[key]["link"]
            if isinstance(link_expr, str):
                # Stored links may appear as "= p8"; XSPEC expects "p8".
                cleaned_link = link_expr.strip()
                if cleaned_link.startswith("="):
                    cleaned_link = cleaned_link[1:].strip()
            else:
                cleaned_link = ""

            if cleaned_link != "":
                try:
                    getattr(comp, par_name).link = cleaned_link
                except Exception:
                    # Skip malformed legacy link strings and continue restoring.
                    pass

    return model_obj

baseline_params, energy_x, energy_err, data_y, data_err, baseline_model_y, baseline_residuals = _save_model_and_flux(baseline_model)
# Out:
# ========================================================================
# Model TBabs<1>(nthComp<2> + diskbb<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   nthComp    Gamma               1.70000      +/-  0.0
#    3    2   nthComp    kT_e       keV      100.000      +/-  0.0
#    4    2   nthComp    kT_bb      keV      0.100000     frozen
#    5    2   nthComp    inp_type   0/1      0.0          frozen
#    6    2   nthComp    Redshift            0.0          frozen
#    7    2   nthComp    norm                1.00000      +/-  0.0
#    8    3   diskbb     Tin        keV      1.00000      +/-  0.0
#    9    3   diskbb     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.075890e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              5.802905e+09     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.738039e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              1.388620e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#   parameter 1 is not frozen.
#
# Fit statistic  : C-Statistic              1.633917e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              1.259598e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.634931e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              1.260749e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#   parameter 3 is not frozen.
#
# Fit statistic  : C-Statistic              1.634093e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              1.260440e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#   parameter 5 is already frozen.
#
# Fit statistic  : C-Statistic              1.634093e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              1.260440e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1257 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.634093e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              1.260440e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                106806.3     using 1264 bins.
#
# Test statistic : Chi-Squared                127968.2     using 1264 bins.
#  Null hypothesis probability of 0.0e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                28282.60     using 1264 bins.
#
# Test statistic : Chi-Squared                46517.27     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                28549.94     using 1264 bins.
#
# Test statistic : Chi-Squared                80401.88     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                10072.37     using 1264 bins.
#
# Test statistic : Chi-Squared                15881.48     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH       2:Gamma        3:kT_e        7:norm         8:Tin        9:norm
# 1700.45      1.45848e+06   0      0.187057       1.65286       18.3185    0.00315852      0.931490     0.0703683
# 1550.07      164913        0      0.190101       1.66787       23.2110    0.00317456      0.936761     0.0835230
# 1369.79      55047        -1      0.214294       1.71334       39.6533    0.00320514      0.958174      0.107261
# 1325.44      65094.4      -2      0.222320       1.78186       26.9317    0.00319606      0.994444      0.102240
# 1323.47      21591.5      -1      0.222425       1.79042       25.9509    0.00319396      0.996777      0.101823
# 1320.87      1295.77      -2      0.218975       1.81997       13.2697    0.00317710       1.01075     0.0959823
# 1320.6       6420.32      -1      0.218572       1.82223       12.2700    0.00317568       1.01198     0.0955174
# 1320.44      1564.93      -1      0.218172       1.82477       11.5689    0.00317396       1.01287     0.0950636
# 1320.31      1219.73      -1      0.217805       1.82708       10.9777    0.00317235       1.01367     0.0946698
# 1320.2       1152.8       -1      0.217464       1.82914       10.4757    0.00317082       1.01437     0.0943250
# 1320.1       1075.47      -1      0.217149       1.83101       10.0427    0.00316936       1.01499     0.0940239
# 1320.02      1059.8       -1      0.216854       1.83269       9.66619    0.00316795       1.01553     0.0937634
# 1319.93      947.601      -2      0.215398       1.84012       7.70304    0.00315787       1.01768     0.0933557
# 1319.45      10633.5      -3      0.214234       1.83504       7.53815    0.00309696       1.02715      0.102930
# 1319.18      4062.63      -3      0.213765       1.82633       7.26004    0.00303969       1.03341      0.112779
# 1318.93      3096.36      -3      0.213358       1.81760       6.98113    0.00298458       1.03897      0.122187
# 1318.71      2917.39      -3      0.213212       1.80866       7.47337    0.00293326       1.04846      0.129441
#  thcomp:          284         283
# 1318.5       4063.85      -3      0.212729       1.80054       7.00641    0.00288252       1.05262      0.137592
# 1318.31      3220.48      -3      0.212604       1.79157       7.40122    0.00283602       1.06049      0.143778
# 1318.24      3140.16      -3      0.212023       1.78535       6.41004    0.00278911       1.06159      0.151864
# 1318.01      7725.16      -3      0.212083       1.77623       7.12192    0.00274833       1.07051      0.156233
# 1317.86      5409.15      -3      0.211565       1.77008       6.45339    0.00270570       1.07196      0.163159
# 1317.7       4151.79      -3      0.211547       1.76138       6.90445    0.00266777       1.07907      0.167231
# 1317.57      2787.53      -3      0.211257       1.75432       6.82970    0.00262989       1.08341      0.171992
# 1317.46      1200.18      -3      0.210940       1.74846       6.48778    0.00259276       1.08619      0.177227
# 1317.35      1936.56      -3      0.210822       1.74113       6.60155    0.00255866       1.09093      0.181101
# 1317.26      1085.07      -3      0.210595       1.73485       6.51769    0.00252526       1.09471      0.185061
# 1317.17      898.728      -3      0.210431       1.72840       6.53007    0.00249390       1.09874      0.188515
# 1317.09      820.921      -3      0.210196       1.72313       6.34596    0.00246317       1.10157      0.192303
# 1317.01      1184.39      -3      0.210018       1.71768       6.22639    0.00243387       1.10434      0.195875
# 1316.94      863.58       -3      0.209861       1.71224       6.15963    0.00240607       1.10731      0.199038
# 1316.88      645.566      -3      0.209698       1.70719       6.06538    0.00237934       1.11000      0.202102
# 1316.82      710          -3      0.209551       1.70225       5.99361    0.00235387       1.11263      0.204940
# 1316.76      637.42       -3      0.209389       1.69776       5.87797    0.00232909       1.11487      0.207823
# 1316.71      661.446      -3      0.209263       1.69311       5.81812    0.00230561       1.11728      0.210384
# 1316.67      454.1        -3      0.209147       1.68852       5.78382    0.00228323       1.11981      0.212660
# 1316.63      434.798      -3      0.209018       1.68424       5.73402    0.00226161       1.12218      0.214853
# 1316.59      480.701      -3      0.208886       1.68026       5.65902    0.00224056       1.12423      0.217095
# 1316.55      418.261      -3      0.208782       1.67619       5.61886    0.00222060       1.12638      0.219097
# 1316.51      397.638      -3      0.208663       1.67242       5.55671    0.00220110       1.12832      0.221103
# 1316.48      400.474      -3      0.208567       1.66860       5.52072    0.00218249       1.13034      0.222915
# 1316.45      331.957      -3      0.208452       1.66517       5.44704    0.00216409       1.13201      0.224855
# 1316.42      405.101      -3      0.208348       1.66180       5.37258    0.00214613       1.13353      0.226807
# 1316.39      394.496      -3      0.208270       1.65830       5.33361    0.00212913       1.13523      0.228500
# 1316.37      271.322      -3      0.208179       1.65502       5.28524    0.00211256       1.13684      0.230148
# 1316.34      276.255      -3      0.208086       1.65191       5.22558    0.00209630       1.13828      0.231833
# 1316.32      284.737      -3      0.208013       1.64872       5.18765    0.00208077       1.13980      0.233352
# 1316.3       275.222      -3      0.207928       1.64581       5.12765    0.00206547       1.14106      0.234969
# 1316.27      300.66       -3      0.207855       1.64290       5.07455    0.00205062       1.14229      0.236534
# 1316.25      288.58       -3      0.207791       1.63996       5.03623    0.00203627       1.14360      0.237960
# 1316.23      215.807      -3      0.207725       1.63711       5.00015    0.00202233       1.14492      0.239308
# 1316.22      222.072      -3      0.207651       1.63447       4.94319    0.00200848       1.14595      0.240801
# 1316.2       206.638      -3      0.207598       1.63174       4.90549    0.00199524       1.14709      0.242144
# 1316.18      268.736      -3      0.207535       1.62914       4.86260    0.00198217       1.14815      0.243483
# 1316.17      216.108      -3      0.207477       1.62662       4.81449    0.00196933       1.14909      0.244869
# 1316.15      129.486      -3      0.207429       1.62407       4.77884    0.00195702       1.15010      0.246124
# 1316.14      183.098      -3      0.207378       1.62160       4.74076    0.00194491       1.15105      0.247373
# 1316.12      201.191      -3      0.207333       1.61914       4.71006    0.00193317       1.15205      0.248536
# 1316.11      127.416      -3      0.207286       1.61677       4.67598    0.00192167       1.15297      0.249698
# 1316.1       180.67       -3      0.207242       1.61444       4.64435    0.00191047       1.15387      0.250826
# 1316.09      122.538      -3      0.207195       1.61218       4.60600    0.00189928       1.15467      0.252011
# 1316.08      148.202      -4      0.206828       1.59122       4.23324    0.00179634       1.16113      0.263508
# ======================================================================
#  Variances and Principal Axes
#                  1        2        3        7        8        9
#  2.7188E-11|  0.0014   0.0009   0.0000  -1.0000  -0.0039  -0.0040
#  3.6942E-06|  0.7254  -0.2696  -0.0071   0.0038  -0.1429  -0.6169
#  1.8169E-05|  0.6761   0.3329   0.0039  -0.0023   0.3166   0.5761
#  7.1510E-04|  0.1278  -0.3582   0.0215   0.0009  -0.7851   0.4884
#  4.3994E-02| -0.0196  -0.8285   0.0441  -0.0037   0.5127   0.2197
#  2.0573E+02|  0.0006   0.0411   0.9988   0.0002  -0.0079  -0.0268
# ----------------------------------------------------------------------
#
# ========================================================================
#   Covariance Matrix
#         1           2           3           4           5           6
#    1.163e-04   5.869e-03   1.260e-01   2.959e-05  -1.513e-03  -3.525e-03
#    5.869e-03   3.772e-01   8.436e+00   1.897e-03  -8.552e-02  -2.347e-01
#    1.260e-01   8.436e+00   2.052e+02   4.288e-02  -1.629e+00  -5.511e+00
#    2.959e-05   1.897e-03   4.288e-02   9.558e-06  -4.241e-04  -1.187e-03
#   -1.513e-03  -8.552e-02  -1.629e+00  -4.241e-04   2.496e-02   4.847e-02
#   -3.525e-03  -2.347e-01  -5.511e+00  -1.187e-03   4.847e-02   1.503e-01
# ------------------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(nthComp<2> + diskbb<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.206828     +/-  1.07851E-02
#    2    2   nthComp    Gamma               1.59122      +/-  0.614169
#    3    2   nthComp    kT_e       keV      4.23324      +/-  14.3254
#    4    2   nthComp    kT_bb      keV      1.16113      = p8
#    5    2   nthComp    inp_type   0/1      1.00000      frozen
#    6    2   nthComp    Redshift            0.0          frozen
#    7    2   nthComp    norm                1.79634E-03  +/-  3.09158E-03
#    8    3   diskbb     Tin        keV      1.16113      +/-  0.157990
#    9    3   diskbb     norm                0.263508     +/-  0.387709
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 1316.08     using 1264 bins.
#
# Test statistic : Chi-Squared                 1317.25     using 1264 bins.
#  Null hypothesis probability of 1.20e-01 with 1258 degrees of freedom

# %%
zxipcf_freeze = {
    "Nh": False,
    "log_xi": False,
    "CvrFract": False,
    "Redshift": True,
}

zxipcf_result, zxipcf_model = fit_model(
    "zxipcf",
    "tbabs * zxipcf * (nthcomp + diskbb)",
    add_zxipcf=True,
    freeze_zxipcf_params=zxipcf_freeze,
)
# Out:
# ========================================================================
# Model TBabs<1>*zxipcf<2>(nthComp<3> + diskbb<4>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   zxipcf     Nh         10^22    10.0000      +/-  0.0
#    3    2   zxipcf     log_xi              3.00000      +/-  0.0
#    4    2   zxipcf     CvrFract            0.500000     +/-  0.0
#    5    2   zxipcf     Redshift            0.0          frozen
#    6    3   nthComp    Gamma               1.70000      +/-  0.0
#    7    3   nthComp    kT_e       keV      100.000      +/-  0.0
#    8    3   nthComp    kT_bb      keV      0.100000     frozen
#    9    3   nthComp    inp_type   0/1      0.0          frozen
#   10    3   nthComp    Redshift            0.0          frozen
#   11    3   nthComp    norm                1.00000      +/-  0.0
#   12    4   diskbb     Tin        keV      1.00000      +/-  0.0
#   13    4   diskbb     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              9.509696e+07     using 1264 bins.
#
# Test statistic : Chi-Squared              4.619809e+09     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1255 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.519225e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              1.057783e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1255 degrees of freedom
#  Current data and model not fit yet.
#   parameter 1 is not frozen.
#
# Fit statistic  : C-Statistic              1.424888e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              9.530368e+09     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1255 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.425816e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              9.539863e+09     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1255 degrees of freedom
#  Current data and model not fit yet.
#   parameter 7 is not frozen.
#
# Fit statistic  : C-Statistic              1.425151e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              9.539654e+09     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1255 degrees of freedom
#  Current data and model not fit yet.
#   parameter 9 is already frozen.
#
# Fit statistic  : C-Statistic              1.425151e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              9.539654e+09     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1254 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.425151e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              9.539654e+09     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1255 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                57135.40     using 1264 bins.
#
# Test statistic : Chi-Squared                66070.85     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1255 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                21305.25     using 1264 bins.
#
# Test statistic : Chi-Squared                44925.42     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1255 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                33412.74     using 1264 bins.
#
# Test statistic : Chi-Squared                99207.72     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1255 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                16659.15     using 1264 bins.
#
# Test statistic : Chi-Squared                31483.22     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1255 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                10604.32     using 1264 bins.
#
# Test statistic : Chi-Squared                16885.11     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1255 degrees of freedom
#  Current data and model not fit yet.
#   parameter 2 is not frozen.
#
# Fit statistic  : C-Statistic                10604.32     using 1264 bins.
#
# Test statistic : Chi-Squared                16885.11     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1255 degrees of freedom
#  Current data and model not fit yet.
#   parameter 3 is not frozen.
#
# Fit statistic  : C-Statistic                10934.32     using 1264 bins.
#
# Test statistic : Chi-Squared                17532.18     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1255 degrees of freedom
#  Current data and model not fit yet.
#   parameter 4 is not frozen.
#
# Fit statistic  : C-Statistic                10934.32     using 1264 bins.
#
# Test statistic : Chi-Squared                17532.18     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1254 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                10934.32     using 1264 bins.
#
# Test statistic : Chi-Squared                17532.18     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1255 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:Nh      3:log_xi    4:CvrFract       6:Gamma        7:kT_e       11:norm        12:Tin       13:norm
# TableParamValueOutsideRange: Requested parameter value 1.43934e+20 outside tabulated range (5e+20, 5e+24)
#
# 1666.13      983022        0      0.185350      0.148709       3.57266      0.360191       1.65161       17.5642    0.00318570      0.935506     0.0856838
# 1616.18      117265        0      0.186230      0.248729       3.23911      0.715822       1.65514       18.9816    0.00318379      0.934330     0.0857956
# 1504.21      682.127       0      0.190996      0.200451       3.29034      0.660236       1.67133       25.1067    0.00318929      0.935770     0.0935726
# 1361.47      6994.54      -1      0.213323      0.229732       3.42726      0.801395       1.71245       43.0273    0.00321329      0.953927      0.113185
# 1330.72      43096.7      -2      0.222411      0.568304       3.53886      0.360068       1.77154       24.4418    0.00320241      0.985480      0.109903
# 1322.81      48235        -1      0.222931      0.831411       3.48786      0.485625       1.77915       24.3801    0.00319915      0.987125      0.109121
# 1321.72      10187.9      -1      0.222479      0.839885       3.50737      0.480806       1.78409       21.8364    0.00319762      0.989349      0.108668
# 1321.36      1073.77      -1      0.222193      0.857226       3.51244      0.475362       1.78801       19.7100    0.00319538      0.991225      0.107807
# 1321.03      1379.96      -1      0.221813      0.862846       3.51487      0.464823       1.79172       17.8138    0.00319305      0.992866      0.106962
# 1320.75      1442.66      -1      0.221403      0.865649       3.51631      0.453223       1.79517       16.3382    0.00319076      0.994363      0.106173
# 1320.49      1115.25      -1      0.221004      0.868099       3.51726      0.441800       1.79834       15.1217    0.00318860      0.995764      0.105451
# 1320.27      1209.4       -1      0.220620      0.870996       3.51799      0.430697       1.80126       14.1737    0.00318653      0.997074      0.104786
# 1320.07      952.207      -1      0.220250      0.874494       3.51868      0.420064       1.80400       13.3391    0.00318453      0.998277      0.104180
# 1319.9       868.969      -1      0.219903      0.878522       3.51932      0.409882       1.80654       12.6243    0.00318261      0.999391      0.103629
# 1319.74      896.581      -1      0.219571      0.883105       3.51997      0.400021       1.80892       11.9987    0.00318075       1.00041      0.103126
# 1319.61      864.484      -1      0.219265      0.888369       3.52055      0.390434       1.81105       11.5051    0.00317899       1.00137      0.102669
# 1319.5       737.115      -1      0.218975      0.894638       3.52117      0.381244       1.81306       11.0440    0.00317727       1.00224      0.102257
# 1319.41      711.411      -2      0.217284      0.965911       3.52526      0.320127       1.82408       8.31831    0.00316414       1.00717      0.100676
# 1318.57      10814.3      -3      0.215309       1.59557       3.52933      0.171137       1.82249       7.74395    0.00308787       1.02114      0.110983
# 1318.44      7743.48      -2      0.215612       3.27511       3.57223      0.110677       1.82183       7.75641    0.00308091       1.02263      0.111789
# 1318.1       7398.29      -1      0.215536       5.79795       3.68926      0.121166       1.82170       7.72382    0.00308040       1.02289      0.111900
# 1317.99      1830.56      -1      0.215395       8.09023       3.57951      0.109397       1.82185       7.72284    0.00308035       1.02323      0.112256
# 1317.98      1285.06       0      0.215400       8.50900       3.58163      0.109954       1.82187       7.72578    0.00308029       1.02325      0.112270
# ==========================================================================================
#  Variances and Principal Axes
#                  1        2        3        4        6        7       11       12       13
#  3.6722E-11|  0.0018   0.0000  -0.0000   0.0001   0.0009   0.0000  -1.0000  -0.0024  -0.0031
#  5.2100E-06|  0.8606   0.0000  -0.0011   0.0043  -0.2626  -0.0020   0.0020   0.2185  -0.3776
#  3.5009E-05|  0.4964  -0.0001   0.0023  -0.0087   0.5464   0.0021  -0.0002  -0.1708   0.6525
#  1.1409E-03|  0.1099  -0.0003   0.0106  -0.1080  -0.5406   0.0040   0.0012  -0.8123   0.1550
#  9.3706E-03| -0.0155  -0.0052   0.1062  -0.9817  -0.0139   0.0005  -0.0007   0.1485   0.0489
#  4.8886E-02|  0.0239  -0.0021   0.0458  -0.1096   0.5828  -0.0000   0.0037  -0.4908  -0.6362
#  1.2709E+01| -0.0008  -0.0235   0.9929   0.1113  -0.0212  -0.0126  -0.0001   0.0160   0.0206
#  4.2642E+03| -0.0002   0.6674   0.0067  -0.0036   0.0001  -0.7447  -0.0000  -0.0032   0.0015
#  9.5428E+03|  0.0002   0.7443   0.0261  -0.0005   0.0006   0.6673   0.0000   0.0027  -0.0020
# ------------------------------------------------------------------------------------------
#
# ============================================================================================================
#   Covariance Matrix
#         1           2           3           4           5           6           7           8           9
#    4.006e-04   5.941e-01   2.242e-02   7.008e-04   1.598e-03   1.490e+00   1.682e-05   5.270e-03  -4.933e-03
#    5.941e-01   7.186e+03   2.045e+02  -1.344e+01   4.419e+00   2.621e+03   3.414e-02   9.722e+00  -1.005e+01
#    2.242e-02   2.045e+02   1.924e+01   1.186e+00  -1.184e-01   1.451e+02  -1.702e-04   7.740e-01  -2.037e-01
#    7.008e-04  -1.344e+01   1.186e+00   2.230e-01  -3.705e-02   8.319e+00  -1.726e-04   6.130e-02   1.784e-02
#    1.598e-03   4.419e+00  -1.184e-01  -3.705e-02   2.587e-02   3.335e+00   1.709e-04  -4.622e-03  -3.419e-02
#    1.490e+00   2.621e+03   1.451e+02   8.319e+00   3.335e+00   6.614e+03   4.843e-02   2.725e+01  -1.774e+01
#    1.682e-05   3.414e-02  -1.702e-04  -1.726e-04   1.709e-04   4.843e-02   1.272e-06   8.013e-05  -2.856e-04
#    5.270e-03   9.722e+00   7.740e-01   6.130e-02  -4.622e-03   2.725e+01   8.013e-05   1.285e-01  -5.319e-02
#   -4.933e-03  -1.005e+01  -2.037e-01   1.784e-02  -3.419e-02  -1.774e+01  -2.856e-04  -5.319e-02   7.426e-02
# ------------------------------------------------------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>*zxipcf<2>(nthComp<3> + diskbb<4>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.215400     +/-  2.00145E-02
#    2    2   zxipcf     Nh         10^22    8.50900      +/-  84.7708
#    3    2   zxipcf     log_xi              3.58163      +/-  4.38690
#    4    2   zxipcf     CvrFract            0.109954     +/-  0.472182
#    5    2   zxipcf     Redshift            0.0          frozen
#    6    3   nthComp    Gamma               1.82187      +/-  0.160839
#    7    3   nthComp    kT_e       keV      7.72578      +/-  81.3263
#    8    3   nthComp    kT_bb      keV      1.02325      = p12
#    9    3   nthComp    inp_type   0/1      1.00000      frozen
#   10    3   nthComp    Redshift            0.0          frozen
#   11    3   nthComp    norm                3.08029E-03  +/-  1.12770E-03
#   12    4   diskbb     Tin        keV      1.02325      +/-  0.358476
#   13    4   diskbb     norm                0.112270     +/-  0.272509
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 1317.98     using 1264 bins.
#
# Test statistic : Chi-Squared                 1321.75     using 1264 bins.
#  Null hypothesis probability of 9.30e-02 with 1255 degrees of freedom

# %%
# Save zxipcf parameters and flux immediately
zxipcf_params, _, _, _, _, zxipcf_model_y, zxipcf_residuals = _save_model_and_flux(zxipcf_model)
fit_compare = pd.DataFrame([baseline_result, zxipcf_result]).set_index("model")
fit_compare["delta_stat_vs_baseline"] = fit_compare["stat"] - fit_compare.loc["baseline", "stat"]
fit_compare["delta_dof_vs_baseline"] = fit_compare["dof"] - fit_compare.loc["baseline", "dof"]
fit_compare["delta_AIC_vs_baseline"] = fit_compare["AIC"] - fit_compare.loc["baseline", "AIC"]
fit_compare["delta_BIC_vs_baseline"] = fit_compare["BIC"] - fit_compare.loc["baseline", "BIC"]

preferred = "zxipcf" if fit_compare.loc["zxipcf", "delta_AIC_vs_baseline"] < 2 else "baseline"
preferred_bic = "zxipcf" if fit_compare.loc["zxipcf", "delta_BIC_vs_baseline"] < 2 else "baseline"

preferred_result = zxipcf_result if preferred_bic == "zxipcf" else baseline_result
preferred_expression = preferred_result["expression"]
preferred_snapshot = zxipcf_params if preferred_bic == "zxipcf" else baseline_params

# %%
from IPython.display import display, Markdown

def _format_param_with_error(param_dict):
    val = float(param_dict["value"])
    if param_dict["link"] != "":
        return f"{val:.5g} (linked)"
    if param_dict["frozen"]:
        return f"{val:.5g} (frozen)"
    sigma = float(param_dict.get("sigma", np.nan))
    if np.isfinite(sigma) and sigma > 0:
        return f"{val:.5g} +/- {sigma:.2g}"
    return f"{val:.5g} (err N/A)"

all_keys = list(baseline_params.keys()) + [k for k in zxipcf_params.keys() if k not in baseline_params]

table_rows = []
for k in all_keys:
    b_str = _format_param_with_error(baseline_params[k]) if k in baseline_params else "-"
    z_str = _format_param_with_error(zxipcf_params[k]) if k in zxipcf_params else "-"
    table_rows.append({"Metric / Parameter": k, "Baseline": b_str, "zxipcf": z_str})

table_rows.append({"Metric / Parameter": "--- Fit Statistics ---", "Baseline": "", "zxipcf": ""})
table_rows.append({"Metric / Parameter": "C-stat / DoF",
                   "Baseline": f"{baseline_result['stat']:.2f} / {baseline_result['dof']}",
                   "zxipcf": f"{zxipcf_result['stat']:.2f} / {zxipcf_result['dof']}"})
table_rows.append({"Metric / Parameter": "AIC",
                   "Baseline": f"{baseline_result['AIC']:.2f}",
                   "zxipcf": f"{zxipcf_result['AIC']:.2f}"})
table_rows.append({"Metric / Parameter": "BIC",
                   "Baseline": f"{baseline_result['BIC']:.2f}",
                   "zxipcf": f"{zxipcf_result['BIC']:.2f}"})
table_rows.append({"Metric / Parameter": "Delta AIC (from baseline)",
                   "Baseline": "-",
                   "zxipcf": f"{fit_compare.loc['zxipcf', 'delta_AIC_vs_baseline']:.2f}"})
table_append = table_rows.append({"Metric / Parameter": "Delta BIC (from baseline)",
                   "Baseline": "-",
                   "zxipcf": f"{fit_compare.loc['zxipcf', 'delta_BIC_vs_baseline']:.2f}"})

unified_df = pd.DataFrame(table_rows)

table_md = f"""### Unified Parameter and Fit Comparison (PN)
**Preferred by AIC:** {preferred} | **Preferred by BIC:** {preferred_bic}

{unified_df.to_markdown(index=False)}
"""

display(Markdown(table_md))

unified_csv_path = os.path.join(plot_dir, f"pn_{selected_interval}_comparison.csv")
try:
    unified_df.to_csv(unified_csv_path, index=False)
except Exception:
    pass
# Out:
# ### Unified Parameter and Fit Comparison (PN)
# **Preferred by AIC:** baseline | **Preferred by BIC:** baseline
#
# | Metric / Parameter        | Baseline             | zxipcf               |
# |:--------------------------|:---------------------|:---------------------|
# | TBabs.nH                  | 0.20683 +/- 0.011    | 0.2154 +/- 0.02      |
# | nthComp.Gamma             | 1.5912 +/- 0.61      | 1.8219 +/- 0.16      |
# | nthComp.kT_e              | 4.2332 +/- 14        | 7.7258 +/- 81        |
# | nthComp.kT_bb             | 1.1611 (linked)      | 1.0232 (linked)      |
# | nthComp.inp_type          | 1 (frozen)           | 1 (frozen)           |
# | nthComp.Redshift          | 0 (frozen)           | 0 (frozen)           |
# | nthComp.norm              | 0.0017963 +/- 0.0031 | 0.0030803 +/- 0.0011 |
# | diskbb.Tin                | 1.1611 +/- 0.16      | 1.0232 +/- 0.36      |
# | diskbb.norm               | 0.26351 +/- 0.39     | 0.11227 +/- 0.27     |
# | zxipcf.Nh                 | -                    | 8.509 +/- 85         |
# | zxipcf.log_xi             | -                    | 3.5816 +/- 4.4       |
# | zxipcf.CvrFract           | -                    | 0.10995 +/- 0.47     |
# | zxipcf.Redshift           | -                    | 0 (frozen)           |
# | --- Fit Statistics ---    |                      |                      |
# | C-stat / DoF              | 1316.08 / 1258       | 1317.98 / 1255       |
# | AIC                       | 1328.08              | 1335.98              |
# | BIC                       | 1358.93              | 1382.26              |
# | Delta AIC (from baseline) | -                    | 7.90                 |
# | Delta BIC (from baseline) | -                    | 23.33                |

# %%
# Keep the best model object in m1 for any follow-up cells.
m1 = _restore_model_from_snapshot(preferred_expression, preferred_snapshot)
# Out:
# ========================================================================
# Model TBabs<1>(nthComp<2> + diskbb<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   nthComp    Gamma               1.70000      +/-  0.0
#    3    2   nthComp    kT_e       keV      100.000      +/-  0.0
#    4    2   nthComp    kT_bb      keV      0.100000     frozen
#    5    2   nthComp    inp_type   0/1      0.0          frozen
#    6    2   nthComp    Redshift            0.0          frozen
#    7    2   nthComp    norm                1.00000      +/-  0.0
#    8    3   diskbb     Tin        keV      1.00000      +/-  0.0
#    9    3   diskbb     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.075890e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              5.802905e+09     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.075890e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              5.802905e+09     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.728120e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              1.370987e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#   parameter 1 is not frozen.
#
# Fit statistic  : C-Statistic              1.728120e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              1.370987e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.857237e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              1.550063e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#   parameter 2 is not frozen.
#
# Fit statistic  : C-Statistic              1.857237e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              1.550063e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.946773e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              1.686287e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#   parameter 3 is not frozen.
#
# Fit statistic  : C-Statistic              1.946773e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              1.686287e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              8.396836e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              4.513909e+11     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1258 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              8.396836e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              4.513909e+11     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1257 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              8.396836e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              4.513909e+11     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1257 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              3.001010e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              4.117700e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1257 degrees of freedom
#  Current data and model not fit yet.
#   parameter 5 is already frozen.
#
# Fit statistic  : C-Statistic              3.001010e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              4.117700e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1257 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              3.001010e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              4.117700e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1257 degrees of freedom
#  Current data and model not fit yet.
#   parameter 6 is already frozen.
#
# Fit statistic  : C-Statistic              3.001010e+08     using 1264 bins.
#
# Test statistic : Chi-Squared              4.117700e+10     using 1264 bins.
#  Null hypothesis probability of 0.000000e+00 with 1257 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                76311.07     using 1264 bins.
#
# Test statistic : Chi-Squared                83601.27     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1257 degrees of freedom
#  Current data and model not fit yet.
#   parameter 7 is not frozen.
#
# Fit statistic  : C-Statistic                76311.07     using 1264 bins.
#
# Test statistic : Chi-Squared                83601.27     using 1264 bins.
#  Null hypothesis probability of 0.00e+00 with 1257 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                303278.4     using 1264 bins.
#
# Test statistic : Chi-Squared                414945.4     using 1264 bins.
#  Null hypothesis probability of 0.0e+00 with 1257 degrees of freedom
#  Current data and model not fit yet.
#   parameter 8 is not frozen.
#
# Fit statistic  : C-Statistic                303278.4     using 1264 bins.
#
# Test statistic : Chi-Squared                414945.4     using 1264 bins.
#  Null hypothesis probability of 0.0e+00 with 1257 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                 1316.08     using 1264 bins.
#
# Test statistic : Chi-Squared                 1317.25     using 1264 bins.
#  Null hypothesis probability of 1.16e-01 with 1257 degrees of freedom
#  Current data and model not fit yet.
#   parameter 9 is not frozen.
#
# Fit statistic  : C-Statistic                 1316.08     using 1264 bins.
#
# Test statistic : Chi-Squared                 1317.25     using 1264 bins.
#  Null hypothesis probability of 1.20e-01 with 1258 degrees of freedom
#  Current data and model not fit yet.

# %%
# --- 7. PLOT COMPARISON: baseline vs zxipcf ---
# Create comparison plot
plt.figure(figsize=(16, 10), dpi=75)
gs = plt.GridSpec(2, 1, height_ratios=[3, 1], hspace=0)
# Top panel: Data and both models as overlays
ax1 = plt.subplot(gs[0])
ax1.errorbar(energy_x, data_y, xerr=energy_err, yerr=data_err, fmt='o', ms=2,
             elinewidth=0.8, label='PN Data', color='black', alpha=0.7, zorder=20)

baseline_label_suffix = " (Selected)" if preferred_bic == "baseline" else ""
ax1.step(energy_x, baseline_model_y, where='mid', color='C0', lw=2.5,
         zorder=10, label=f'Baseline (χ²={baseline_result["stat"]:.1f}){baseline_label_suffix}')

zxipcf_label_suffix = " (Selected)" if preferred_bic == "zxipcf" else ""
ax1.step(energy_x, zxipcf_model_y, where='mid', color='C1', lw=5,
         linestyle='--', zorder=9, label=f'zxipcf (χ²={zxipcf_result["stat"]:.1f}){zxipcf_label_suffix}')

ax1.set_yscale("log")
ax1.set_ylabel(y_units, fontsize=14)
#ax1.set_title(f"PN Spectrum Comparison: {selected_interval} - Selected Model: {preferred_bic}", fontsize=14, fontweight='bold')
ax1.set_ylim(3.5e-2,)
ax1.legend(fontsize=20, loc='best')
ax1.grid(True, alpha=0.3)
# Bottom panel: Residuals for both models
ax2 = plt.subplot(gs[1], sharex=ax1)
ax2.step(energy_x, baseline_residuals, where='mid', color='C0', lw=1.5, label='Baseline residuals')
ax2.step(energy_x, zxipcf_residuals, where='mid', color='C1', lw=1.5, linestyle='--',
         label='zxipcf residuals')
ax2.axhline(0, color='red', linestyle='--', lw=1)
ax2.fill_between(energy_x, -3, 3, alpha=0.1, color='gray')
ax2.set_xlabel("Energy (keV)", fontsize=14)
ax2.set_ylabel(r"Residuals ($\chi$)", fontsize=14)
ax2.set_ylim(-5, 5)
ax2.legend(fontsize=16, loc='best')
ax2.grid(True, alpha=0.3)
plt.tight_layout()
comparison_plot_path = os.path.join(plot_dir, f"pn_{selected_interval}_comparison.png")
plt.savefig(comparison_plot_path,
            dpi=300, bbox_inches='tight')
plt.show()
print("\nComparison plot saved to:")
print(f"  {comparison_plot_path}")
# Out:
# Comparison plot saved to:
#   ../products/0865600201/pn/spec/plots/Full_grp/pn_Full_grp_comparison.png

# %%
# --- 8. PYXSPEC NATIVE BLIND LINE SEARCH ---
if run_line_search:
    from pathlib import Path
    import importlib.util
    from IPython.display import Image, display
    def _load_blind_search_module():
        here = Path.cwd().resolve()
        for root in [here, *here.parents]:
            script_path = root / 'scripts' / 'xspec_blind_search' / 'run_blind_search.py'
            if script_path.is_file():
                spec = importlib.util.spec_from_file_location('run_blind_search', script_path)
                if spec is None or spec.loader is None:
                    raise RuntimeError(f'Could not import blind-search script from {script_path}')
                module = importlib.util.module_from_spec(spec)
                spec.loader.exec_module(module)
                return module, root
        raise FileNotFoundError('Could not locate scripts/xspec_blind_search/run_blind_search.py')
    blind_search, repo_root = _load_blind_search_module()
    pn_out_dir = str(Path(plot_dir))
    pn_argv = [
        'pn',
        '--products-root', str(repo_root / 'products'),
        '--obsid', '0865600201',
        '--interval', base_interval,
        '--model-expr', preferred_expression,
        '--fit-stat', 'cstat',
        '--dlambda', '0.01',
        '--energy-min', '0.7',
        '--energy-max', '7.0',
        '--norm-guess', '1e-4',
        '--norm-min', '-1.0',
        '--norm-max', '1.0',
        '--progress-every', '10',
        '--out-dir', pn_out_dir,
        '--overwrite',
    ]
    if use_grouped:
        pn_argv.append('--grouped')
    if use_background:
        pn_argv.append('--use-background')
     # NOTE: Use --use-current-state to avoid hanging on Model() creation and use existing fit
     # The continuum parameters are already set from the notebook fit above
    pn_argv.append('--use-current-state')
    status = blind_search.main(pn_argv)
    pn_plot_path = Path(pn_out_dir) / f'blind_search_{selected_interval}_native.png'
    print(f'PN blind-search script exit status: {status}')
    print(f'PN blind-search plot: {pn_plot_path}')
    display(Image(filename=str(pn_plot_path)))
else:
    print("Line search skipped (run_line_search=False)")
# Out:
# Starting PN blind search... obsid=0865600201, interval=Full
# Using current XSPEC data and model state...
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
#
# Fit statistic  : C-Statistic                 1316.08     using 1264 bins.
#
# Test statistic : Chi-Squared                 1317.25     using 1264 bins.
#  Null hypothesis probability of 1.20e-01 with 1258 degrees of freedom
#  Current data and model not fit yet.
#  Cross Section Table set to vern:  Verner, Ferland, Korista, and Yakovlev 1996
#
# Fit statistic  : C-Statistic                 1316.08     using 1264 bins.
#
# Test statistic : Chi-Squared                 1317.25     using 1264 bins.
#  Null hypothesis probability of 1.20e-01 with 1258 degrees of freedom
#  Current data and model not fit yet.
#  Solar Abundance Vector set to wilm:  Wilms, J., Allen, A. & McCray, R. ApJ 542 914 (2000) (abundances are set to zero for those elements not included in the paper).
#
# Fit statistic  : C-Statistic                 1316.08     using 1264 bins.
#
# Test statistic : Chi-Squared                 1317.25     using 1264 bins.
#  Null hypothesis probability of 1.20e-01 with 1258 degrees of freedom
#  Current data and model not fit yet.
# Enabled parallel XSPEC fitting (leven=8 cores)
# Extracting baseline spectrum data for plots...
# ***Warning: Fit is not current.
# Extracting effective-area curves for the diagnostic plot...
# Calculating final baseline fit statistics...
# Baseline fit complete: cstat=1315.98 dof=1258
# Appending gaussian line to model...
# Starting grid scan with 1595 points...
#   Step 10/1595 at E=0.704 keV (lambda=17.62 A)... Done. DeltaStat=0.04
#   Step 20/1595 at E=0.708 keV (lambda=17.52 A)... Done. DeltaStat=0.04
#   Step 30/1595 at E=0.712 keV (lambda=17.42 A)... Done. DeltaStat=0.03
#   Step 40/1595 at E=0.716 keV (lambda=17.32 A)... Done. DeltaStat=0.03
#   Step 50/1595 at E=0.720 keV (lambda=17.22 A)... Done. DeltaStat=0.03
#   Step 60/1595 at E=0.724 keV (lambda=17.12 A)... Done. DeltaStat=0.02
#   Step 70/1595 at E=0.728 keV (lambda=17.02 A)... Done. DeltaStat=0.02
#   Step 80/1595 at E=0.733 keV (lambda=16.92 A)... Done. DeltaStat=0.02
#   Step 90/1595 at E=0.737 keV (lambda=16.82 A)... Done. DeltaStat=0.02
#   Step 100/1595 at E=0.741 keV (lambda=16.72 A)... Done. DeltaStat=0.03
#   Step 110/1595 at E=0.746 keV (lambda=16.62 A)... Done. DeltaStat=0.03
#   Step 120/1595 at E=0.750 keV (lambda=16.52 A)... Done. DeltaStat=0.04
#   Step 130/1595 at E=0.755 keV (lambda=16.42 A)... Done. DeltaStat=0.05
#   Step 140/1595 at E=0.760 keV (lambda=16.32 A)... Done. DeltaStat=0.07
#   Step 150/1595 at E=0.764 keV (lambda=16.22 A)... Done. DeltaStat=0.08
#   Step 160/1595 at E=0.769 keV (lambda=16.12 A)... Done. DeltaStat=0.11
#   Step 170/1595 at E=0.774 keV (lambda=16.02 A)... Done. DeltaStat=0.13
#   Step 180/1595 at E=0.779 keV (lambda=15.92 A)... Done. DeltaStat=0.15
#   Step 190/1595 at E=0.784 keV (lambda=15.82 A)... Done. DeltaStat=0.18
#   Step 200/1595 at E=0.789 keV (lambda=15.72 A)... Done. DeltaStat=0.20
#   Step 210/1595 at E=0.794 keV (lambda=15.62 A)... Done. DeltaStat=0.21
#   Step 220/1595 at E=0.799 keV (lambda=15.52 A)... Done. DeltaStat=0.20
#   Step 230/1595 at E=0.804 keV (lambda=15.42 A)... Done. DeltaStat=0.19
#   Step 240/1595 at E=0.809 keV (lambda=15.32 A)... Done. DeltaStat=0.16
#   Step 250/1595 at E=0.815 keV (lambda=15.22 A)... Done. DeltaStat=0.12
#   Step 260/1595 at E=0.820 keV (lambda=15.12 A)... Done. DeltaStat=0.07
#   Step 270/1595 at E=0.825 keV (lambda=15.02 A)... Done. DeltaStat=0.03
#   Step 280/1595 at E=0.831 keV (lambda=14.92 A)... Done. DeltaStat=0.00
#   Step 290/1595 at E=0.836 keV (lambda=14.82 A)... Done. DeltaStat=0.00
#   Step 300/1595 at E=0.842 keV (lambda=14.72 A)... Done. DeltaStat=0.04
#   Step 310/1595 at E=0.848 keV (lambda=14.62 A)... Done. DeltaStat=0.11
#   Step 320/1595 at E=0.854 keV (lambda=14.52 A)... Done. DeltaStat=0.23
#   Step 330/1595 at E=0.860 keV (lambda=14.42 A)... Done. DeltaStat=0.37
#   Step 340/1595 at E=0.866 keV (lambda=14.32 A)... Done. DeltaStat=0.53
#   Step 350/1595 at E=0.872 keV (lambda=14.22 A)... Done. DeltaStat=0.68
#   Step 360/1595 at E=0.878 keV (lambda=14.12 A)... Done. DeltaStat=0.82
#   Step 370/1595 at E=0.884 keV (lambda=14.02 A)... Done. DeltaStat=0.92
#   Step 380/1595 at E=0.891 keV (lambda=13.92 A)... Done. DeltaStat=0.98
#   Step 390/1595 at E=0.897 keV (lambda=13.82 A)... Done. DeltaStat=0.99
#   Step 400/1595 at E=0.904 keV (lambda=13.72 A)... Done. DeltaStat=0.94
#   Step 410/1595 at E=0.910 keV (lambda=13.62 A)... Done. DeltaStat=0.84
#   Step 420/1595 at E=0.917 keV (lambda=13.52 A)... Done. DeltaStat=0.69
#   Step 430/1595 at E=0.924 keV (lambda=13.42 A)... Done. DeltaStat=0.52
#   Step 440/1595 at E=0.931 keV (lambda=13.32 A)... Done. DeltaStat=0.33
#   Step 450/1595 at E=0.938 keV (lambda=13.22 A)... Done. DeltaStat=0.17
#   Step 460/1595 at E=0.945 keV (lambda=13.12 A)... Done. DeltaStat=0.05
#   Step 470/1595 at E=0.952 keV (lambda=13.02 A)... Done. DeltaStat=0.00
#   Step 480/1595 at E=0.959 keV (lambda=12.92 A)... Done. DeltaStat=0.04
#   Step 490/1595 at E=0.967 keV (lambda=12.82 A)... Done. DeltaStat=0.19
#   Step 500/1595 at E=0.975 keV (lambda=12.72 A)... Done. DeltaStat=0.44
#   Step 510/1595 at E=0.982 keV (lambda=12.62 A)... Done. DeltaStat=0.74
#   Step 520/1595 at E=0.990 keV (lambda=12.52 A)... Done. DeltaStat=1.07
#   Step 530/1595 at E=0.998 keV (lambda=12.42 A)... Done. DeltaStat=1.34
#   Step 540/1595 at E=1.006 keV (lambda=12.32 A)... Done. DeltaStat=1.51
#   Step 550/1595 at E=1.014 keV (lambda=12.22 A)... Done. DeltaStat=1.54
#   Step 560/1595 at E=1.023 keV (lambda=12.12 A)... Done. DeltaStat=1.42
#   Step 570/1595 at E=1.031 keV (lambda=12.02 A)... Done. DeltaStat=1.16
#   Step 580/1595 at E=1.040 keV (lambda=11.92 A)... Done. DeltaStat=0.87
#   Step 590/1595 at E=1.049 keV (lambda=11.82 A)... Done. DeltaStat=0.57
#   Step 600/1595 at E=1.058 keV (lambda=11.72 A)... Done. DeltaStat=0.34
#   Step 610/1595 at E=1.067 keV (lambda=11.62 A)... Done. DeltaStat=0.18
#   Step 620/1595 at E=1.076 keV (lambda=11.52 A)... Done. DeltaStat=0.10
#   Step 630/1595 at E=1.085 keV (lambda=11.42 A)... Done. DeltaStat=0.07
#   Step 640/1595 at E=1.095 keV (lambda=11.32 A)... Done. DeltaStat=0.08
#   Step 650/1595 at E=1.105 keV (lambda=11.22 A)... Done. DeltaStat=0.12
#   Step 660/1595 at E=1.115 keV (lambda=11.12 A)... Done. DeltaStat=0.20
#   Step 670/1595 at E=1.125 keV (lambda=11.02 A)... Done. DeltaStat=0.35
#   Step 680/1595 at E=1.135 keV (lambda=10.92 A)... Done. DeltaStat=0.55
#   Step 690/1595 at E=1.146 keV (lambda=10.82 A)... Done. DeltaStat=0.78
#   Step 700/1595 at E=1.156 keV (lambda=10.72 A)... Done. DeltaStat=0.99
#   Step 710/1595 at E=1.167 keV (lambda=10.62 A)... Done. DeltaStat=1.15
#   Step 720/1595 at E=1.178 keV (lambda=10.52 A)... Done. DeltaStat=1.23
#   Step 730/1595 at E=1.190 keV (lambda=10.42 A)... Done. DeltaStat=1.21
#   Step 740/1595 at E=1.201 keV (lambda=10.32 A)... Done. DeltaStat=1.10
#   Step 750/1595 at E=1.213 keV (lambda=10.22 A)... Done. DeltaStat=0.90
#   Step 760/1595 at E=1.225 keV (lambda=10.12 A)... Done. DeltaStat=0.64
#   Step 770/1595 at E=1.237 keV (lambda=10.02 A)... Done. DeltaStat=0.37
#   Step 780/1595 at E=1.250 keV (lambda=9.92 A)... Done. DeltaStat=0.14
#   Step 790/1595 at E=1.262 keV (lambda=9.82 A)... Done. DeltaStat=0.01
#   Step 800/1595 at E=1.275 keV (lambda=9.72 A)... Done. DeltaStat=0.05
#   Step 810/1595 at E=1.289 keV (lambda=9.62 A)... Done. DeltaStat=0.34
#   Step 820/1595 at E=1.302 keV (lambda=9.52 A)... Done. DeltaStat=0.90
#   Step 830/1595 at E=1.316 keV (lambda=9.42 A)... Done. DeltaStat=1.71
#   Step 840/1595 at E=1.330 keV (lambda=9.32 A)... Done. DeltaStat=2.65
#   Step 850/1595 at E=1.344 keV (lambda=9.22 A)... Done. DeltaStat=3.60
#   Step 860/1595 at E=1.359 keV (lambda=9.12 A)... Done. DeltaStat=4.50
#   Step 870/1595 at E=1.374 keV (lambda=9.02 A)... Done. DeltaStat=5.31
#   Step 880/1595 at E=1.390 keV (lambda=8.92 A)... Done. DeltaStat=6.08
#   Step 890/1595 at E=1.405 keV (lambda=8.82 A)... Done. DeltaStat=6.85
#   Step 900/1595 at E=1.422 keV (lambda=8.72 A)... Done. DeltaStat=7.63
#   Step 910/1595 at E=1.438 keV (lambda=8.62 A)... Done. DeltaStat=8.34
#   Step 920/1595 at E=1.455 keV (lambda=8.52 A)... Done. DeltaStat=8.70
#   Step 930/1595 at E=1.472 keV (lambda=8.42 A)... Done. DeltaStat=8.43
#   Step 940/1595 at E=1.490 keV (lambda=8.32 A)... Done. DeltaStat=7.39
#   Step 950/1595 at E=1.508 keV (lambda=8.22 A)... Done. DeltaStat=5.69
#   Step 960/1595 at E=1.527 keV (lambda=8.12 A)... Done. DeltaStat=3.71
#   Step 970/1595 at E=1.546 keV (lambda=8.02 A)... Done. DeltaStat=1.83
#   Step 980/1595 at E=1.565 keV (lambda=7.92 A)... Done. DeltaStat=0.49
#   Step 990/1595 at E=1.585 keV (lambda=7.82 A)... Done. DeltaStat=0.00
#   Step 1000/1595 at E=1.606 keV (lambda=7.72 A)... Done. DeltaStat=0.57
#   Step 1010/1595 at E=1.627 keV (lambda=7.62 A)... Done. DeltaStat=1.62
#   Step 1020/1595 at E=1.648 keV (lambda=7.52 A)... Done. DeltaStat=2.54
#   Step 1030/1595 at E=1.670 keV (lambda=7.42 A)... Done. DeltaStat=2.70
#   Step 1040/1595 at E=1.693 keV (lambda=7.32 A)... Done. DeltaStat=2.23
#   Step 1050/1595 at E=1.717 keV (lambda=7.22 A)... Done. DeltaStat=1.68
#   Step 1060/1595 at E=1.741 keV (lambda=7.12 A)... Done. DeltaStat=1.36
#   Step 1070/1595 at E=1.766 keV (lambda=7.02 A)... Done. DeltaStat=1.51
#   Step 1080/1595 at E=1.791 keV (lambda=6.92 A)... Done. DeltaStat=2.05
#   Step 1090/1595 at E=1.817 keV (lambda=6.82 A)... Done. DeltaStat=2.55
#   Step 1100/1595 at E=1.844 keV (lambda=6.72 A)... Done. DeltaStat=2.45
#   Step 1110/1595 at E=1.872 keV (lambda=6.62 A)... Done. DeltaStat=1.88
#   Step 1120/1595 at E=1.901 keV (lambda=6.52 A)... Done. DeltaStat=1.26
#   Step 1130/1595 at E=1.931 keV (lambda=6.42 A)... Done. DeltaStat=0.77
#   Step 1140/1595 at E=1.961 keV (lambda=6.32 A)... Done. DeltaStat=0.35
#   Step 1150/1595 at E=1.993 keV (lambda=6.22 A)... Done. DeltaStat=0.04
#   Step 1160/1595 at E=2.025 keV (lambda=6.12 A)... Done. DeltaStat=0.04
#   Step 1170/1595 at E=2.059 keV (lambda=6.02 A)... Done. DeltaStat=0.24
#   Step 1180/1595 at E=2.094 keV (lambda=5.92 A)... Done. DeltaStat=0.20
#   Step 1190/1595 at E=2.130 keV (lambda=5.82 A)... Done. DeltaStat=0.01
#   Step 1200/1595 at E=2.167 keV (lambda=5.72 A)... Done. DeltaStat=0.81
#   Step 1210/1595 at E=2.205 keV (lambda=5.62 A)... Done. DeltaStat=2.57
#   Step 1220/1595 at E=2.245 keV (lambda=5.52 A)... Done. DeltaStat=3.60
#   Step 1230/1595 at E=2.287 keV (lambda=5.42 A)... Done. DeltaStat=2.24
#   Step 1240/1595 at E=2.330 keV (lambda=5.32 A)... Done. DeltaStat=0.15
#   Step 1250/1595 at E=2.374 keV (lambda=5.22 A)... Done. DeltaStat=0.50
#   Step 1260/1595 at E=2.421 keV (lambda=5.12 A)... Done. DeltaStat=0.78
#   Step 1270/1595 at E=2.469 keV (lambda=5.02 A)... Done. DeltaStat=0.06
#   Step 1280/1595 at E=2.519 keV (lambda=4.92 A)... Done. DeltaStat=0.06
#   Step 1290/1595 at E=2.571 keV (lambda=4.82 A)... Done. DeltaStat=0.00
#   Step 1300/1595 at E=2.626 keV (lambda=4.72 A)... Done. DeltaStat=0.47
#   Step 1310/1595 at E=2.682 keV (lambda=4.62 A)... Done. DeltaStat=0.58
#   Step 1320/1595 at E=2.742 keV (lambda=4.52 A)... Done. DeltaStat=0.01
#   Step 1330/1595 at E=2.804 keV (lambda=4.42 A)... Done. DeltaStat=1.20
#   Step 1340/1595 at E=2.869 keV (lambda=4.32 A)... Done. DeltaStat=1.93
#   Step 1350/1595 at E=2.937 keV (lambda=4.22 A)... Done. DeltaStat=0.57
#   Step 1360/1595 at E=3.008 keV (lambda=4.12 A)... Done. DeltaStat=0.08
#   Step 1370/1595 at E=3.083 keV (lambda=4.02 A)... Done. DeltaStat=1.32
#   Step 1380/1595 at E=3.161 keV (lambda=3.92 A)... Done. DeltaStat=1.24
#   Step 1390/1595 at E=3.244 keV (lambda=3.82 A)... Done. DeltaStat=0.24
#   Step 1400/1595 at E=3.331 keV (lambda=3.72 A)... Done. DeltaStat=1.37
#   Step 1410/1595 at E=3.423 keV (lambda=3.62 A)... Done. DeltaStat=0.15
#   Step 1420/1595 at E=3.520 keV (lambda=3.52 A)... Done. DeltaStat=0.37
#   Step 1430/1595 at E=3.623 keV (lambda=3.42 A)... Done. DeltaStat=0.02
#   Step 1440/1595 at E=3.732 keV (lambda=3.32 A)... Done. DeltaStat=1.15
#   Step 1450/1595 at E=3.848 keV (lambda=3.22 A)... Done. DeltaStat=2.56
#   Step 1460/1595 at E=3.971 keV (lambda=3.12 A)... Done. DeltaStat=0.00
#   Step 1470/1595 at E=4.103 keV (lambda=3.02 A)... Done. DeltaStat=0.55
#   Step 1480/1595 at E=4.243 keV (lambda=2.92 A)... Done. DeltaStat=1.93
#   Step 1490/1595 at E=4.393 keV (lambda=2.82 A)... Done. DeltaStat=0.54
#   Step 1500/1595 at E=4.555 keV (lambda=2.72 A)... Done. DeltaStat=0.13
#   Step 1510/1595 at E=4.729 keV (lambda=2.62 A)... Done. DeltaStat=0.68
#   Step 1520/1595 at E=4.916 keV (lambda=2.52 A)... Done. DeltaStat=0.02
#   Step 1530/1595 at E=5.119 keV (lambda=2.42 A)... Done. DeltaStat=0.33
#   Step 1540/1595 at E=5.339 keV (lambda=2.32 A)... Done. DeltaStat=0.82
#   Step 1550/1595 at E=5.580 keV (lambda=2.22 A)... Done. DeltaStat=0.76
#   Step 1560/1595 at E=5.843 keV (lambda=2.12 A)... Done. DeltaStat=0.19
#   Step 1570/1595 at E=6.132 keV (lambda=2.02 A)... Done. DeltaStat=0.05
#   Step 1580/1595 at E=6.451 keV (lambda=1.92 A)... Done. DeltaStat=1.00
#   Step 1590/1595 at E=6.805 keV (lambda=1.82 A)... Done. DeltaStat=1.38
# Scan complete. Writing results...
# Wrote: /media/kyle/kyle_phd/Swift-j1858.6-0814/products/0865600201/pn/spec/plots/Full_grp/blind_search_Full_grp_native.csv
# Wrote: /media/kyle/kyle_phd/Swift-j1858.6-0814/products/0865600201/pn/spec/plots/Full_grp/blind_search_Full_grp_native.png
# Wrote: /media/kyle/kyle_phd/Swift-j1858.6-0814/products/0865600201/pn/spec/plots/Full_grp/blind_search_Full_grp_manifest.json
# PN blind-search script exit status: 0
# PN blind-search plot: ../products/0865600201/pn/spec/plots/Full_grp/blind_search_Full_grp_native.png
