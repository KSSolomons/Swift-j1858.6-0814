# %%
import xspec as x
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np
from astropy.io import fits

# %%
#Load relxill and test it

# --- STEP 1: DEFINE PATHS ---
# Path to the folder where you compiled relxill (contains lmodel.dat)
# relxill_dir = "/home/kyle/software/relxill"

# Path to the folder containing the heavy FITS tables (often the same dir)
# relxill_tables = "/home/kyle/software/relxill"

# --- STEP 2: SET ENVIRONMENT VARIABLE ---
# This tells relxill where to look for the tables so you don't have to copy them
# os.environ["RELXILL_TABLE_PATH"] = relxill_tables

# --- STEP 3: LOAD THE MODEL ---
# This mimics the "lmod relxill /path" command
# print("Loading Relxill...")
# x.AllModels.lmod("relxill", relxill_dir)

# --- STEP 4: USE IT ---
# Now you can use 'relxill', 'relxillCp', 'relxilllp', etc.
# Example: simple relativistic reflection
# m = x.Model("tbabs * relxillns")

# Verify it loaded
# print(m.componentNames)

# %%
# --- 1. SETUP & DATA LOADING ---
x.AllData.clear()
x.AllModels.clear()

# --- PN: interval + full-spectrum options ---
time_intervals_pn = {
    "Full": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_spectrum.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_spectrum.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf.arf",
    },
    "Full_grp": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_spectrum_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_spectrum.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf.arf",
    },
    "Dipping": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Dipping.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Dipping.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Dipping.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Dipping.arf",
    },
    "Dipping_grp": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Dipping_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Dipping.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Dipping.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Dipping.arf",
    },
    "Persistent": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Persistent.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Persistent.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Persistent.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Persistent.arf",
    },
    "Persistent_grp": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Persistent_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Persistent.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Persistent.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Persistent.arf",
    },
    "Shallow": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Shallow.fits",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Shallow.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Shallow.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Shallow.arf",
    },
    "Shallow_grp": {
        "pn_spec": "../products/0865600201/pn/spec/pn_source_Shallow_grp.pha",
        "pn_bkg":  "../products/0865600201/pn/spec/pn_bkg_Shallow.fits",
        "pn_rmf":  "../products/0865600201/pn/spec/pn_rmf_Shallow.rmf",
        "pn_arf":  "../products/0865600201/pn/spec/pn_arf_Shallow.arf",
    },
}

# %%
# Choose: "Full", "Dipping", "Persistent", "Shallow"
def interval_key(interval, grouped=False):
    return f"{interval}_grp" if grouped else interval

base_interval = "Shallow"
use_grouped = True
use_background = True

selected_interval = interval_key(base_interval, use_grouped)
pn_data = time_intervals_pn[selected_interval]

pn_spec = pn_data["pn_spec"]
pn_bkg  = pn_data["pn_bkg"]
pn_rmf  = pn_data["pn_rmf"]
pn_arf  = pn_data["pn_arf"]

# Load PN (once)
x.AllData(pn_spec)
s = x.AllData(1)
if use_background:
    s.background = pn_bkg
s.response = pn_rmf
s.response.arf = pn_arf

x.AllData.ignore("bad")
s.ignore("**-1.0 7.5-**")  # Ignore outside 0.8-10 keV

# Global XSPEC settings
x.Plot.device = "/null"
x.Plot.xAxis = "keV"
x.Xset.xsect = "vern"
x.Xset.abund = "wilm"


# --- 2. MODEL DEFINITION ---
# Defining the model for the loaded PN data
m1 = x.Model("tbabs * (nthcomp + diskbb)")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: ../products/0865600201/pn/spec/pn_source_Shallow_grp.pha  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.501e+00 +/- 1.026e-02
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-2575
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 3.325e+04 sec
#  Using fit statistic: chi
#  No response loaded.
#
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Net count rate (cts/s) for Spectrum:1  2.719e+00 +/- 2.132e-02 (77.7 % total)
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Response successfully loaded.
# Arf successfully loaded.
#
# ignore:  1098 channels ignored from  source number 1
#     96 channels (1-96) ignored in spectrum #     1
#   1341 channels (1235-2575) ignored in spectrum #     1
#
#  Cross Section Table set to vern:  Verner, Ferland, Korista, and Yakovlev 1996
# ...

# %%
# --- 4. FITTING ---



m1(1).values = 0.4
m1(1).frozen = False
m1(2).values = 1.4
m1(3).values = 5
m1(3).frozen = False
m1(4).link = "p8"

m1(5).values = 1
m1(5).frozen = True
m1(8).values = 0.8
m1(9).values = 0.5

# m1(10).values = 10
# m1(11).values = 0.5
# Out:
# Fit statistic  : Chi-Squared              7.209960e+08     using 1138 bins.
#
# Test statistic : Chi-Squared              7.209960e+08     using 1138 bins.
#  Null hypothesis probability of 0.000000e+00 with 1132 degrees of freedom
#  Current data and model not fit yet.
#   parameter 1 is not frozen.
#
# Fit statistic  : Chi-Squared              1.318542e+09     using 1138 bins.
#
# Test statistic : Chi-Squared              1.318542e+09     using 1138 bins.
#  Null hypothesis probability of 0.000000e+00 with 1132 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.760284e+09     using 1138 bins.
#
# Test statistic : Chi-Squared              1.760284e+09     using 1138 bins.
#  Null hypothesis probability of 0.000000e+00 with 1132 degrees of freedom
#  Current data and model not fit yet.
#   parameter 3 is not frozen.
#
# Fit statistic  : Chi-Squared              3.906107e+10     using 1138 bins.
#
# ...

# %%
x.Fit.statMethod = "cstat"
x.Fit.query = "yes"
x.Fit.perform()
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
#
# Fit statistic  : C-Statistic              4.058788e+07     using 1138 bins.
#
# Test statistic : Chi-Squared              3.302117e+09     using 1138 bins.
#  Null hypothesis probability of 0.000000e+00 with 1132 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH       2:Gamma        3:kT_e        7:norm         8:Tin        9:norm
# 584768       5.12726e+06  -3      0.174715       8.69272       999.126      0.201039      0.141564      0.129985
# 57403.4      450642       -1       8.88569       1.60002       999.700     0.0247383      0.425446     0.0307317
# 4830.18      379248       -2       4.30074       2.21041       999.869     0.0142422      0.171742       337.791
# ...

# %%
print("\n" + "="*110)
print(f"{'GROUP':<5} | {'C#':<3} | {'P#':<3} | {'COMPONENT':<12} | {'PARAMETER':<12} | {'UNIT':<12} | {'VALUE':<12} | {'ERROR'}")
print("-" * 110)

global_par_idx = 1

for comp_idx, comp_name in enumerate(m1.componentNames, start=1):
    comp = getattr(m1, comp_name)
    for par_name in comp.parameterNames:
        par = getattr(comp, par_name)

        # 5 significant figures for numeric values
        val = par.values[0]
        val_str = f"{val:.5g}" if isinstance(val, (int, float, np.floating)) else str(val)

        # Unit column
        unit = getattr(par, "unit", "")
        unit_str = unit if unit not in ("", None) else "-"

        if par.link != "":
            err_str = f"LINKED ({par.link})"
        elif par.frozen:
            err_str = "FROZEN"
        else:
            err_str = f"+/- {par.sigma:.5g}" if par.sigma > 0 else "N/A"

        print(
            f"{'1':<5} | {comp_idx:<3} | {global_par_idx:<3} | "
            f"{comp_name:<12} | {par_name:<12} | {unit_str:<12} | {val_str:<12} | {err_str}"
        )

        global_par_idx += 1

print("-" * 110)
print(f"Final {x.Fit.statMethod.upper()}: {x.Fit.statistic:.5g}")
print(f"Degrees of Freedom: {x.Fit.dof}")
print(f"Reduced Statistic: {(x.Fit.statistic / x.Fit.dof):.5g}")
print("="*110 + "\n")
# Out:
# ...
# GROUP | C#  | P#  | COMPONENT    | PARAMETER    | UNIT         | VALUE        | ERROR
# --------------------------------------------------------------------------------------------------------------
# 1     | 1   | 1   | TBabs        | nH           | 10^22        | 1.2285       | +/- 0.3271
# 1     | 2   | 2   | nthComp      | Gamma        | -            | 2.1154       | +/- 0.18693
# 1     | 2   | 3   | nthComp      | kT_e         | keV          | 302.36       | +/- 13504
# 1     | 2   | 4   | nthComp      | kT_bb        | keV          | 0.14165      | LINKED (= p8)
# 1     | 2   | 5   | nthComp      | inp_type     | 0/1          | 1            | FROZEN
# 1     | 2   | 6   | nthComp      | Redshift     | -            | 0            | FROZEN
# 1     | 2   | 7   | nthComp      | norm         | -            | 0.013559     | +/- 0.0028845
# 1     | 3   | 8   | diskbb       | Tin          | keV          | 0.14165      | +/- 0.013538
# ...

# %%
# --- 5. PLOTTING ---

# Set rebinning for the plot only (e.g., min significance 7, max 10 bins)
# x.Plot.setRebin(1,1)
x.Plot.device = "/null"
x.Plot.xAxis = "keV"
x.Plot.add = True

# Extract Data
x.Plot("data")
energy_x   = x.Plot.x(1)
energy_err = x.Plot.xErr(1)
data_y     = x.Plot.y(1)
data_err   = x.Plot.yErr(1)
model_y    = x.Plot.model(1)


y_units = x.Plot.labels()[1]
print(y_units)
# Extract Residuals
x.Plot("delchi")
residuals  = x.Plot.y(1)


e  = np.array(energy_x)
ee = np.array(energy_err)
dy = np.array(data_y)
de = np.array(data_err)
my = np.array(model_y)
res = np.array(residuals)

#background

if use_background:
    x.Plot("background")
    bkg = x.Plot.y(1)
    bkg_err = x.Plot.yErr(1)
# Out:
# counts s$^{-1}$ keV$^{-1}$

# %%
# Plotting


plt.style.use('default')


plt.figure(figsize=(16, 9), dpi=75)
gs = plt.GridSpec(2, 1, height_ratios=[3, 1], hspace=0)

# Top panel: Data and Model
ax1 = plt.subplot(gs[0])
ax1.errorbar(e, dy, xerr=ee, yerr=de, fmt='o', ms=2, elinewidth=0.8, label='PN Data')
ax1.step(e, my, where='mid', color='C1', lw=1.5, zorder=10, label='Model')
ax1.set_yscale("log")
ax1.set_ylabel(fr"{y_units}", fontsize=16)
ax1.set_title(f"PN Spectrum for {selected_interval}: {m1.expression}")
#background
if use_background:
    ax1.errorbar(e, bkg, yerr=bkg_err, color='black', fmt='o',ms=2, elinewidth=0.8, label='Background')
ax1.set_ylim(1e-2,)

# Bottom panel: Residuals
ax2 = plt.subplot(gs[1], sharex=ax1)
ax2.step(e, res, where='mid', color='black', lw=1.2)
# ax2.errorbar(e, res, xerr=ee, fmt='none', ecolor='black', elinewidth=0.8, capsize=2)
ax2.axhline(0, color='red', linestyle='--')
# ax2.set_ylim(-4,4)

ax2.set_xlabel("Energy (keV)",fontsize=16)
ax2.set_ylabel(r"Residuals ($\chi$)", fontsize=16)
ax1.legend(fontsize=14, loc='best')
plt.tight_layout()
plt.savefig(f'../products/0865600201/pn/spec/pn_{selected_interval}_fit.png', dpi=300, bbox_inches='tight')

# %%
# Quick check: Calculate counts from rates to decide on statistic
exposure = s.exposure
counts = np.array([r * exposure for r in s.values if r > 0])
min_counts = np.min(counts)
median_counts = np.median(counts)

print(f"Exposure: {exposure:.1f} s")
print(f"Min counts/bin: {min_counts:.1f}")
print(f"Median counts/bin: {median_counts:.1f}")

if min_counts < 20:
    print("\n--- RECOMMENDATION ---")
    print(f"Minimum counts ({min_counts:.1f}) is below 20.")
    print("Gaussian statistics (Chi-Squared) are invalid for low-count bins.")
    print("Use 'cstat' for the most reliable results.")
else:
    print("\n--- RECOMMENDATION ---")
    print(f"All bins have >= 20 counts (Min: {min_counts:.1f}).")
    print("You can safely use 'chi' (Chi-Squared) or 'cstat'.")
# Out:
# Exposure: 33249.0 s
# Min counts/bin: 20.0
# Median counts/bin: 48.5
#
# --- RECOMMENDATION ---
# All bins have >= 20 counts (Min: 20.0).
# You can safely use 'chi' (Chi-Squared) or 'cstat'.

# %%
# import os
# import re
# import numpy as np
# from astropy.io import fits
#
# # -----------------------------
# # 1) Configure and run chain
# # -----------------------------
# x.AllChains.clear()
#
# chain_len = 5000
# burn_len = 500
# chain_file = f"../products/0865600201/pn/spec/pn_{selected_interval}_mcmc_chain.fits"
#
# if os.path.exists(chain_file):
#     os.remove(chain_file)
#
# x.AllChains.defLength = chain_len
# x.AllChains.defBurn = burn_len
# x.AllChains.defRand = True
#
# # Some builds support this, some may not
# try:
#     x.AllChains.defProposal = "gaussian fit"
# except Exception:
#     pass
#
# print("AllChains defaults:")
# print("  defLength :", x.AllChains.defLength)
# print("  defBurn   :", x.AllChains.defBurn)
# try:
#     print("  defProposal:", x.AllChains.defProposal)
# except Exception:
#     print("  defProposal: <not available in this PyXspec build>")
# print("  defRand   :", x.AllChains.defRand)
#
# print(f"\nRunning chain: {chain_file}")
# ch = x.Chain(chain_file)
#
#
# # Optional XSPEC-side chain info (works in most builds)
# try:
#     x.AllChains.show()
# except Exception:
#     pass
#
# # Version-safe chain length check: count FITS table rows
# with fits.open(chain_file) as hdul:
#     data = hdul[1].data
#     colnames = list(hdul[1].columns.names)
#     nrows = len(data)
#
# print(f"\nactual chain rows in FITS: {nrows}")
#
# # -----------------------------
# # 2) Build model parameter map
# # -----------------------------
# all_params = []
# global_idx = 1
# for comp_name in m1.componentNames:
#     comp = getattr(m1, comp_name)
#     for par_name in comp.parameterNames:
#         par = getattr(comp, par_name)
#         all_params.append({
#             "idx": global_idx,
#             "name": f"{comp_name}.{par_name}",
#             "frozen": par.frozen,
#             "linked": (par.link != ""),
#             "value": par.values[0],
#             "status": "LINKED" if par.link != "" else ("FROZEN" if par.frozen else "FREE"),
#             "link": par.link
#         })
#         global_idx += 1
#
# free_params = [p for p in all_params if (not p["frozen"] and not p["linked"])]
#
# # -----------------------------
# # 3) Identify chain parameter columns
# # -----------------------------
# exclude = {"FIT_STATISTIC", "STATISTIC", "CHI2", "CHAIN", "ACCEPT", "ACCEPTANCE"}
# par_cols = []
# for c in colnames:
#     if c.upper() in exclude:
#         continue
#     arr = np.asarray(data[c])
#     if np.issubdtype(arr.dtype, np.number):
#         par_cols.append(c)
#
#
# def parse_idx(col):
#     # XSPEC-style names often end with "__<global_index>", e.g. "Gamma__2"
#     m = re.search(r"__(\d+)$", col)
#     return int(m.group(1)) if m else None
#
#
# col_idx = {c: parse_idx(c) for c in par_cols}
# have_explicit_idx = all(v is not None for v in col_idx.values())
#
# if have_explicit_idx:
#     par_cols = sorted(par_cols, key=lambda c: col_idx[c])
#     free_by_idx = {p["idx"]: p for p in free_params}
#     mapped = []
#     for c in par_cols:
#         idx = col_idx[c]
#         if idx in free_by_idx:
#             mapped.append((c, free_by_idx[idx]))
#         else:
#             # Rare fallback if model state changed
#             mapped.append((c, {"idx": idx, "name": c, "status": "FREE"}))
# else:
#     # Fallback by order if no explicit index suffixes are present
#     if len(par_cols) != len(free_params):
#         raise RuntimeError(
#             "Could not map chain columns reliably by order. "
#             f"Columns={par_cols}, free_params={len(free_params)}"
#         )
#     mapped = list(zip(par_cols, free_params))
#
# # -----------------------------
# # 4) Posterior interval table (sampled params)
# # -----------------------------
# print("\n" + "=" * 130)
# print(f"{'P#':<4} {'PARAMETER':<34} {'MEDIAN':>12} {'68% CI':>30} {'90% CI':>30}")
# print("-" * 130)
#
# for col, p in mapped:
#     samples = np.asarray(data[col], dtype=float)
#
#     q16, q50, q84 = np.percentile(samples, [16, 50, 84])  # ~68%
#     q05, q95 = np.percentile(samples, [5, 95])  # 90%
#
#     lo68, hi68 = q50 - q16, q84 - q50
#     lo90, hi90 = q50 - q05, q95 - q50
#
#     print(
#         f"{p['idx']:<4} {p['name']:<34} "
#         f"{q50:>12.5g} "
#         f"[-{lo68:.5g}, +{hi68:.5g}]".rjust(30) + " "
#                                                   f"[-{lo90:.5g}, +{hi90:.5g}]".rjust(30)
#     )
#
# print("=" * 130)
#
# # -----------------------------
# # 5) Non-sampled params table (linked/frozen)
# # -----------------------------
# nonsampled = [p for p in all_params if p["status"] != "FREE"]
# if nonsampled:
#     print("\nNon-sampled model parameters:")
#     print("-" * 90)
#     print(f"{'P#':<4} {'PARAMETER':<34} {'VALUE':>12} {'STATUS':>12} {'LINK':>20}")
#     print("-" * 90)
#     for p in nonsampled:
#         link_txt = p["link"] if p["status"] == "LINKED" else "-"
#         print(f"{p['idx']:<4} {p['name']:<34} {p['value']:>12.5g} {p['status']:>12} {link_txt:>20}")
#     print("-" * 90)

# %%
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Optional extra visual burn-in cut (for plotting only)
# plot_burn_frac = 0.1  # set 0.0 to disable
# nrows = len(data)
# i0 = int(plot_burn_frac * nrows)
#
# n = len(mapped)
# ncols = 3
# nrows_grid = int(np.ceil(n / ncols))
#
# fig, axes = plt.subplots(nrows_grid, ncols, figsize=(5 * ncols, 3.5 * nrows_grid))
# axes = np.atleast_1d(axes).ravel()
#
# for k, (col, p) in enumerate(mapped):
#     s = np.asarray(data[col], dtype=float)[i0:]
#
#     q16, q50, q84 = np.percentile(s, [16, 50, 84])
#
#     ax = axes[k]
#     ax.hist(s, bins=60, density=True, alpha=0.75)
#     ax.axvline(q50, ls='-', lw=1.5, color='k', label='median')
#     ax.axvline(q16, ls='--', lw=1.2, color='k', alpha=0.8)
#     ax.axvline(q84, ls='--', lw=1.2, color='k', alpha=0.8)
#
#     ax.set_title(f"P{p['idx']}: {p['name']}")
#     ax.set_xlabel("value")
#     ax.set_ylabel("density")
#     ax.legend(fontsize=8)
#
# # Hide unused panels
# for j in range(n, len(axes)):
#     axes[j].axis("off")
#
# plt.tight_layout()
# plt.show()

# %%
# import numpy as np
# import corner
# import matplotlib.pyplot as plt
#
# plot_burn_frac = 0.1
# i0 = int(plot_burn_frac * len(data))
#
# samples = np.column_stack([np.asarray(data[col], dtype=float)[i0:] for col, _ in mapped])
# labels = [f"P{p['idx']} {p['name']}" for _, p in mapped]
#
# fig = corner.corner(
#     samples,
#     labels=labels,
#     quantiles=[0.16, 0.5, 0.84],
#     show_titles=True,
#     title_fmt=".4g",
#     bins=40
# )
# plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
#
# # burn-in cut for diagnostics
# i0 = int(0.1 * len(data))
#
# # find chain columns by XSPEC global index
# idx_to_col = {}
# for col, p in mapped:
#     idx_to_col[p["idx"]] = col
#
# if 7 not in idx_to_col or 8 not in idx_to_col:
#     raise RuntimeError("Could not find P7 (nthcomp.norm) and/or P8 (diskbb.Tin) in mapped chain columns.")
#
# n7 = np.asarray(data[idx_to_col[7]], dtype=float)[i0:]  # nthcomp.norm
# t8 = np.asarray(data[idx_to_col[8]], dtype=float)[i0:]  # diskbb.Tin
#
# r = np.corrcoef(n7, t8)[0, 1]
# print(f"Pearson r(P7 nthcomp.norm, P8 diskbb.Tin) = {r:.3f}")
#
# plt.figure(figsize=(6, 5))
# plt.scatter(t8, n7, s=3, alpha=0.2)
# plt.xlabel("P8 diskbb.Tin")
# plt.ylabel("P7 nthcomp.norm")
# plt.title(f"Degeneracy check: r = {r:.3f}")
# plt.tight_layout()
# plt.show()

# %%
# --- 6. MODEL COMPARISON: baseline vs zxipcf ---
def _set_par(model, comp_name, par_name, values=None, frozen=None, link=None):
    """Safely set a parameter only if component/parameter exists in the model."""
    cname_match = next((c for c in model.componentNames if c.lower() == comp_name.lower()), None)
    if not cname_match:
        return False
    comp = getattr(model, cname_match)
    pname_match = next((p for p in comp.parameterNames if p.lower() == par_name.lower()), None)
    if not pname_match:
        return False
    par = getattr(comp, pname_match)
    if values is not None:
        par.values = values
    if frozen is not None:
        par.frozen = frozen
    if link is not None:
        par.link = link
    return True
def _global_par_index(model, target_comp, target_par):
    """Return XSPEC global parameter index for link expressions (p#)."""
    idx = 1
    for comp_name in model.componentNames:
        comp = getattr(model, comp_name)
        for par_name in comp.parameterNames:
            if comp_name.lower() == target_comp.lower() and par_name.lower() == target_par.lower():
                return idx
            idx += 1
    return None
def _n_free_params(model):
    n_free = 0
    for comp_name in model.componentNames:
        comp = getattr(model, comp_name)
        for par_name in comp.parameterNames:
            p = getattr(comp, par_name)
            if (not p.frozen) and (p.link == ""):
                n_free += 1
    return n_free
def _apply_continuum_start_values(model):
    _set_par(model, "tbabs", "nH", values=0.2, frozen=True)
    _set_par(model, "nthcomp", "Gamma", values=1.4)
    _set_par(model, "nthcomp", "kT_e", values=5.0, frozen=False)
    _set_par(model, "nthcomp", "inp_type", values=1.0, frozen=True)
    _set_par(model, "nthcomp", "Redshift", values=0.0, frozen=True)
    _set_par(model, "diskbb", "Tin", values=0.8)
    _set_par(model, "diskbb", "norm", values=0.6)
    # Keep kTbb tied to diskbb Tin as in the original setup.
    tin_idx = _global_par_index(model, "diskbb", "Tin")
    if tin_idx is not None:
        _set_par(model, "nthcomp", "kT_bb", link=f"p{tin_idx}")
def _apply_zxipcf_start_values(model):
    # zxipcf parameter names can vary by build; set only when present.
    candidates = {
        "Nh": 0.2,
        "log_xi": 3.0,
        "CvrFract": 0.5,
        "Redshift": 0.0,
    }
    if not any(c.lower() == "zxipcf" for c in model.componentNames):
        return
    for name, value in candidates.items():
        _set_par(model, "zxipcf", name, values=value)
def fit_model(label, expression, add_zxipcf=False):
    x.AllModels.clear()
    model = x.Model(expression)
    _apply_continuum_start_values(model)
    if add_zxipcf:
        _apply_zxipcf_start_values(model)
    x.Fit.perform()
    stat = float(x.Fit.statistic)
    dof = int(x.Fit.dof)
    red_stat = stat / dof if dof > 0 else np.nan
    k_free = _n_free_params(model)
    n_bins = dof + k_free
    aic = stat + 2 * k_free
    bic = stat + k_free * np.log(n_bins) if n_bins > 0 else np.nan
    return {
        "model": label,
        "expression": expression,
        "stat": stat,
        "dof": dof,
        "red_stat": red_stat,
        "k_free": k_free,
        "n_bins": n_bins,
        "AIC": aic,
        "BIC": bic,
    }, model
# Use the same fit statistic as above
x.Fit.statMethod = "cstat"
x.Fit.query = "yes"
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
#
# Fit statistic  : C-Statistic                 1110.86     using 1138 bins.
#
# Test statistic : Chi-Squared                 1567.80     using 1138 bins.
#  Null hypothesis probability of 1.14e-16 with 1132 degrees of freedom
#  Current data and model not fit yet.

# %%
baseline_result, baseline_model = fit_model(
    "baseline",
    "tbabs * (nthcomp + diskbb)",
    add_zxipcf=False,
)

# IMPORTANT: Extract model data immediately while model is active
def _save_model_and_flux(model_obj):
    """Save parameters and extract folded model flux immediately."""
    params = {}
    for comp_name in model_obj.componentNames:
        comp = getattr(model_obj, comp_name)
        for par_name in comp.parameterNames:
            par = getattr(comp, par_name)
            params[f"{comp_name}.{par_name}"] = {
                "value": par.values[0],
                "frozen": par.frozen,
                "link": par.link,
            }

    # Extract folded model data while active
    x.Plot("data")
    energy = np.array(x.Plot.x(1))
    energy_err = np.array(x.Plot.xErr(1))
    data_y = np.array(x.Plot.y(1))
    data_err = np.array(x.Plot.yErr(1))
    model_y = np.array(x.Plot.model(1))

    # Extract residuals
    x.Plot("delchi")
    residuals = np.array(x.Plot.y(1))

    return params, energy, energy_err, data_y, data_err, model_y, residuals


def _restore_model_from_snapshot(expression, snapshot):
    """Rebuild a live XSPEC model and restore saved parameter values/frozen/link states."""
    x.AllModels.clear()
    model_obj = x.Model(expression)

    # First pass: restore numeric values and frozen flags with links cleared.
    for comp_name in model_obj.componentNames:
        comp = getattr(model_obj, comp_name)
        for par_name in comp.parameterNames:
            key = f"{comp_name}.{par_name}"
            if key not in snapshot:
                continue
            p = getattr(comp, par_name)
            p.link = ""
            p.values = snapshot[key]["value"]
            p.frozen = snapshot[key]["frozen"]

    # Second pass: re-apply links after all parameter values are set.
    for comp_name in model_obj.componentNames:
        comp = getattr(model_obj, comp_name)
        for par_name in comp.parameterNames:
            key = f"{comp_name}.{par_name}"
            if key not in snapshot:
                continue
            link_expr = snapshot[key]["link"]
            if isinstance(link_expr, str):
                # Stored links may appear as "= p8"; XSPEC expects "p8".
                cleaned_link = link_expr.strip()
                if cleaned_link.startswith("="):
                    cleaned_link = cleaned_link[1:].strip()
            else:
                cleaned_link = ""

            if cleaned_link != "":
                try:
                    getattr(comp, par_name).link = cleaned_link
                except Exception:
                    # Skip malformed legacy link strings and continue restoring.
                    pass

    return model_obj

baseline_params, energy_x, energy_err, data_y, data_err, baseline_model_y, baseline_residuals = _save_model_and_flux(baseline_model)
# Out:
# ...
# Model TBabs<1>(nthComp<2> + diskbb<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   nthComp    Gamma               1.70000      +/-  0.0
#    3    2   nthComp    kT_e       keV      100.000      +/-  0.0
#    4    2   nthComp    kT_bb      keV      0.100000     frozen
#    5    2   nthComp    inp_type   0/1      0.0          frozen
#    6    2   nthComp    Redshift            0.0          frozen
#    7    2   nthComp    norm                1.00000      +/-  0.0
#    8    3   diskbb     Tin        keV      1.00000      +/-  0.0
#    9    3   diskbb     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.627665e+07     using 1138 bins.
#
# Test statistic : Chi-Squared              5.007214e+08     using 1138 bins.
# ...

# %%
zxipcf_result, zxipcf_model = fit_model(
    "zxipcf",
    "tbabs * zxipcf * (nthcomp + diskbb)",
    add_zxipcf=True,
)
# Out:
# ...
# Model TBabs<1>*zxipcf<2>(nthComp<3> + diskbb<4>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   zxipcf     Nh         10^22    10.0000      +/-  0.0
#    3    2   zxipcf     log_xi              3.00000      +/-  0.0
#    4    2   zxipcf     CvrFract            0.500000     +/-  0.0
#    5    2   zxipcf     Redshift            0.0          frozen
#    6    3   nthComp    Gamma               1.70000      +/-  0.0
#    7    3   nthComp    kT_e       keV      100.000      +/-  0.0
#    8    3   nthComp    kT_bb      keV      0.100000     frozen
#    9    3   nthComp    inp_type   0/1      0.0          frozen
#   10    3   nthComp    Redshift            0.0          frozen
#   11    3   nthComp    norm                1.00000      +/-  0.0
#   12    4   diskbb     Tin        keV      1.00000      +/-  0.0
# ...

# %%
# Save zxipcf parameters and flux immediately
zxipcf_params, _, _, _, _, zxipcf_model_y, zxipcf_residuals = _save_model_and_flux(zxipcf_model)
fit_compare = pd.DataFrame([baseline_result, zxipcf_result]).set_index("model")
fit_compare["delta_stat_vs_baseline"] = fit_compare["stat"] - fit_compare.loc["baseline", "stat"]
fit_compare["delta_dof_vs_baseline"] = fit_compare["dof"] - fit_compare.loc["baseline", "dof"]
fit_compare["delta_AIC_vs_baseline"] = fit_compare["AIC"] - fit_compare.loc["baseline", "AIC"]
fit_compare["delta_BIC_vs_baseline"] = fit_compare["BIC"] - fit_compare.loc["baseline", "BIC"]
print("Fit comparison (lower stat/AIC/BIC is better):")
display_cols = [
    "expression", "stat", "dof", "red_stat", "k_free", "AIC", "BIC",
    "delta_stat_vs_baseline", "delta_dof_vs_baseline",
    "delta_AIC_vs_baseline", "delta_BIC_vs_baseline",
]
print(fit_compare[display_cols].round(5))
preferred = "zxipcf" if fit_compare.loc["zxipcf", "delta_AIC_vs_baseline"] < 0 else "baseline"
preferred_bic = "zxipcf" if fit_compare.loc["zxipcf", "delta_BIC_vs_baseline"] < 0 else "baseline"
print(f"\nPreferred by AIC: {preferred}")
print(f"Preferred by BIC: {preferred_bic}")
preferred_result = zxipcf_result if preferred == "zxipcf" else baseline_result
preferred_expression = preferred_result["expression"]
preferred_snapshot = zxipcf_params if preferred == "zxipcf" else baseline_params
print("\n--- Parameter Comparison ---")
# Get all possible parameter keys
all_keys = list(baseline_params.keys()) + [k for k in zxipcf_params.keys() if k not in baseline_params]
print(f"{'Parameter':<25} | {'Baseline':<25} | {'zxipcf':<25}")
print("-" * 81)
for k in all_keys:
    b_val = f"{baseline_params[k]['value']:.5g}" if k in baseline_params else "N/A"
    a_val = f"{zxipcf_params[k]['value']:.5g}" if k in zxipcf_params else "N/A"
    b_link = " (linked)" if k in baseline_params and baseline_params[k]["link"] != "" else (" (frozen)" if k in baseline_params and baseline_params[k]["frozen"] else "")
    a_link = " (linked)" if k in zxipcf_params and zxipcf_params[k]["link"] != "" else (" (frozen)" if k in zxipcf_params and zxipcf_params[k]["frozen"] else "")
    b_str = f"{b_val}{b_link}" if b_val != "N/A" else "N/A"
    a_str = f"{a_val}{a_link}" if a_val != "N/A" else "N/A"
    print(f"{k:<25} | {b_str:<25} | {a_str:<25}")
# Out:
# Fit comparison (lower stat/AIC/BIC is better):
#                                    expression        stat   dof  red_stat  \
# model
# baseline           tbabs * (nthcomp + diskbb)  1127.56695  1133   0.99520
# zxipcf    tbabs * zxipcf * (nthcomp + diskbb)  1132.05306  1130   1.00182
#
#           k_free         AIC         BIC  delta_stat_vs_baseline  \
# model
# baseline       5  1137.56695  1162.75209                 0.00000
# zxipcf         8  1148.05306  1188.34928                 4.48611
#
#           delta_dof_vs_baseline  delta_AIC_vs_baseline  delta_BIC_vs_baseline
# model
# baseline                      0                0.00000                0.00000
# zxipcf                       -3               10.48611               25.59719
#
# Preferred by AIC: baseline
# Preferred by BIC: baseline
#
# --- Parameter Comparison ---
# Parameter                 | Baseline                  | zxipcf
# ---------------------------------------------------------------------------------
# ...

# %%
# Keep the best model object in m1 for any follow-up cells.
m1 = _restore_model_from_snapshot(preferred_expression, preferred_snapshot)
# Out:
# ...
# Model TBabs<1>(nthComp<2> + diskbb<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   nthComp    Gamma               1.70000      +/-  0.0
#    3    2   nthComp    kT_e       keV      100.000      +/-  0.0
#    4    2   nthComp    kT_bb      keV      0.100000     frozen
#    5    2   nthComp    inp_type   0/1      0.0          frozen
#    6    2   nthComp    Redshift            0.0          frozen
#    7    2   nthComp    norm                1.00000      +/-  0.0
#    8    3   diskbb     Tin        keV      1.00000      +/-  0.0
#    9    3   diskbb     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.627665e+07     using 1138 bins.
#
# Test statistic : Chi-Squared              5.007214e+08     using 1138 bins.
# ...

# %%
# --- 7. PLOT COMPARISON: baseline vs zxipcf ---
# Create comparison plot
plt.figure(figsize=(16, 10), dpi=75)
gs = plt.GridSpec(2, 1, height_ratios=[3, 1], hspace=0)
# Top panel: Data and both models as overlays
ax1 = plt.subplot(gs[0])
ax1.errorbar(energy_x, data_y, xerr=energy_err, yerr=data_err, fmt='o', ms=2,
             elinewidth=0.8, label='PN Data', color='black', alpha=0.7, zorder=20)
ax1.step(energy_x, baseline_model_y, where='mid', color='C0', lw=2.5,
         zorder=10, label=f'Baseline (χ²={baseline_result["stat"]:.1f})')
ax1.step(energy_x, zxipcf_model_y, where='mid', color='C1', lw=5,
         linestyle='--', zorder=9, label=f'zxipcf (χ²={zxipcf_result["stat"]:.1f})')
ax1.set_yscale("log")
ax1.set_ylabel(y_units, fontsize=14)
ax1.set_title(f"PN Spectrum Comparison: {selected_interval}", fontsize=14, fontweight='bold')
ax1.set_ylim(3.5e-2,)
ax1.legend(fontsize=12, loc='best')
ax1.grid(True, alpha=0.3)
# Bottom panel: Residuals for both models
ax2 = plt.subplot(gs[1], sharex=ax1)
ax2.step(energy_x, baseline_residuals, where='mid', color='C0', lw=1.5, label='Baseline residuals')
ax2.step(energy_x, zxipcf_residuals, where='mid', color='C1', lw=1.5, linestyle='--',
         label='zxipcf residuals')
ax2.axhline(0, color='red', linestyle='--', lw=1)
ax2.fill_between(energy_x, -3, 3, alpha=0.1, color='gray')
ax2.set_xlabel("Energy (keV)", fontsize=14)
ax2.set_ylabel(r"Residuals ($\chi$)", fontsize=14)
ax2.set_ylim(-5, 5)
ax2.legend(fontsize=10, loc='best')
ax2.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(f'../products/0865600201/pn/spec/pn_{selected_interval}_comparison.png',
            dpi=300, bbox_inches='tight')
plt.show()
print("\nComparison plot saved to:")
print(f"  ../products/0865600201/pn/spec/pn_{selected_interval}_comparison.png")
# Out:
# Comparison plot saved to:
#   ../products/0865600201/pn/spec/pn_Shallow_grp_comparison.png

# %%
import os
import shutil
import subprocess
import glob

# --- 8. PYXSPEC NATIVE BLIND LINE SEARCH ---
# We can bypass the TCL script entirely and run the grid search directly in Python!
# This avoids any missing response file issues since PyXspec already has the data natively mapped.

# 8.0 Visual checkpoint: unfolded spectrum and active best-fit model
x.Plot.device = "/null"
x.Plot.xAxis = "keV"
x.Plot.add = False
x.Plot("eufspec")

uf_energy = np.array(x.Plot.x(1))
uf_energy_err = np.array(x.Plot.xErr(1))
uf_data = np.array(x.Plot.y(1))
uf_data_err = np.array(x.Plot.yErr(1))
uf_model = np.array(x.Plot.model(1))
uf_y_label = x.Plot.labels()[1] if len(x.Plot.labels()) > 1 else r"E$^2$ F(E)"

print("Preparing native PyXspec blind line search...")

# Always initialize blind search from the selected best-fit snapshot.
m1 = _restore_model_from_snapshot(preferred_expression, preferred_snapshot)

# 8.1 Setup Search Grid
v_width_km_s = 1000.0
c_km_s = 299792.458
conversion = 12.39841975

# Keep the blind search on chi2 for parity with the requested workflow.
x.Fit.statMethod = "cstat"
x.Fit.query = "yes"

# Match legacy TCL fit controls where available in this PyXspec build.
try:
    x.Fit.weight = "churazov"
except Exception:
    try:
        x.Xset.exec_("weight churazov")
    except Exception:
        print("Warning: could not set Churazov weighting in this PyXspec build.")

#x.Fit.nIterations = 1000
try:
    x.Xset.parallel.leven = 2
except Exception:
    pass

# Energy limits
E_min_keV = 1.0
E_max_keV = 7.5

# Step size in constant wavelength (Angstroms) just like the TCL script
dL_angstrom = 0.01
L_min_ang = conversion / E_max_keV
L_max_ang = conversion / E_min_keV
Emin = conversion / L_max_ang
Emax = conversion / L_min_ang
estimated_steps = int(np.ceil((L_max_ang - L_min_ang) / dL_angstrom))

# 8.2 Save baseline parameters exactly as evaluated
# Re-fit once with the exact blind-search settings so baseline and scan are consistent.
x.Xset.chatter = 0
x.Fit.perform()
continuumfitstatistic = float(x.Fit.statistic)
continuumdegreesoffreedom = int(x.Fit.dof)
x.Xset.chatter = 10
print(f"Baseline Stat: {continuumfitstatistic:.2f} | DoF: {continuumdegreesoffreedom}")


total_old_params = m1.nParameters
saved_vals = [m1(i).values[0] for i in range(1, total_old_params + 1)]

# Make XSPEC quiet so it doesn't spam warnings when evaluating the new model string
x.Xset.chatter = 0

# 8.3 Add Gaussian component
# E.g. "tbabs*(nthcomp+diskbb)" becomes "tbabs*(nthcomp+diskbb) + gauss"
m1 = x.Model(m1.expression + " + gauss")

# 8.4 Restore baseline exactly and freeze it completely safely
# The new gauss component will be the last 3 parameters (LineE, Sigma, norm)
for i in range(1, total_old_params + 1):
    p = m1(i)
    # Remove any XSPEC model memory links to avoid syntax crashes
    p.link = ""
    # Force physical parameter value
    p.values = [saved_vals[i-1]]
    # Freeze the parameter for the blind search natively
    p.frozen = True

x.Xset.chatter = 10
frozen_continuum = sum(1 for i in range(1, total_old_params + 1) if m1(i).frozen)
print(f"Continuum frozen parameters: {frozen_continuum}/{total_old_params}")
x.Xset.chatter = 0

# Indexes for the new Gaussian parameters at the end of the model
idx_E     = m1.nParameters - 2
idx_Sigma = m1.nParameters - 1
idx_Norm  = m1.nParameters

# Configure line parameters to mirror the legacy TCL bounds/behavior.
m1(idx_E).frozen = True
m1(idx_Sigma).frozen = True
m1(idx_Norm).values = [1e-4, 1.0e-8, -1.0, -1.0, 1.0, 1.0]
m1(idx_Norm).frozen = False

# Silent the fit printouts to keep notebook clean during the full scan
x.Xset.chatter = 0

# 8.5 Loop over Grid
results = []
print(f"Starting search across ~{estimated_steps} energy steps...")

updatedgaussianenergy = float(Emin)
step_idx = 0

while updatedgaussianenergy < Emax:
    Lequivalent = float(conversion / updatedgaussianenergy)
    gaussianwidthE = float((v_width_km_s / c_km_s) * updatedgaussianenergy)

    # Set line energy/width at this grid point and fit for norm only.
    m1(idx_E).values = updatedgaussianenergy
    m1(idx_Sigma).values = gaussianwidthE
    m1(idx_Norm).values = [1e-4, 1.0e-8, -1.0, -1.0, 1.0, 1.0]
    m1(idx_Norm).frozen = False

    fit_failed = False
    try:
        x.Fit.perform()
    except Exception:
        fit_failed = True

    if fit_failed:
        normalisation = 0.0
        fitstatistic = float(continuumfitstatistic)
        degreesoffreedom = int(continuumdegreesoffreedom - 1)
        normerrormin = np.nan
        normerrorplus = np.nan
    else:
        # Mirrors the legacy script's second fit call in the success branch.
        x.Fit.perform()
        normalisation = float(m1(idx_Norm).values[0])
        fitstatistic = float(x.Fit.statistic)
        degreesoffreedom = int(x.Fit.dof)

        try:
            x.Fit.error(f"1.0 {idx_Norm}")
            errnorml = float(m1(idx_Norm).error[0])
            errnormh = float(m1(idx_Norm).error[1])
            normerrormin = normalisation - errnorml
            normerrorplus = errnormh - normalisation
        except Exception:
            normerrormin = np.nan
            normerrorplus = np.nan

    deltastat = float(continuumfitstatistic - fitstatistic)
    deltadof = int(continuumdegreesoffreedom - degreesoffreedom)

    results.append({
        "Wavelength_Ang": Lequivalent,
        "E_keV": float(updatedgaussianenergy),
        "Norm": normalisation,
        "Norm_err_lo": normerrormin,
        "Norm_err_hi": normerrorplus,
        "Stat": fitstatistic,
        "DoF": degreesoffreedom,
        "Delta_Stat": deltastat,
        "Delta_DoF": deltadof,
    })

    step_idx += 1
    if step_idx % 50 == 0:
        print(
            f"Progress: {step_idx}/{estimated_steps} | E = {updatedgaussianenergy:.3f} keV "
            f"(λ = {Lequivalent:.2f} Å) | ΔStat = {deltastat:.2f}"
        )

    # Advance by fixed wavelength step, matching the TCL stepping logic.
    Lnew = float(Lequivalent - dL_angstrom)
    if Lnew <= 0:
        break
    updatedgaussianenergy = float(conversion / Lnew)

# Restore output verbosity
x.Xset.chatter = 10

# 8.6 Output and Plot
df_search = pd.DataFrame(results)

output_csv = f"../products/0865600201/pn/spec/blind_search_{selected_interval}_native.csv"
df_search.to_csv(output_csv, index=False)
print(f"\nSearch complete. Results saved to {output_csv}")
# Out:
# Preparing native PyXspec blind line search...
# ***Warning: Fit is not current.
#
# ...
# Model TBabs<1>(nthComp<2> + diskbb<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   nthComp    Gamma               1.70000      +/-  0.0
#    3    2   nthComp    kT_e       keV      100.000      +/-  0.0
#    4    2   nthComp    kT_bb      keV      0.100000     frozen
#    5    2   nthComp    inp_type   0/1      0.0          frozen
#    6    2   nthComp    Redshift            0.0          frozen
#    7    2   nthComp    norm                1.00000      +/-  0.0
#    8    3   diskbb     Tin        keV      1.00000      +/-  0.0
#    9    3   diskbb     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.627665e+07     using 1138 bins.
#
# ...

# %%
# Build one subplot figure: unfolded spectrum (top) + blind-search Delta chi2 (bottom)
# Sort by energy for plotting since we iterated by increasing wavelength (decreasing energy)
df_plot = df_search.sort_values("E_keV")
df_plot["Signed_Delta_Stat"] = np.abs(df_plot["Delta_Stat"]) * np.sign(df_plot["Norm"])
fig, (ax1, ax2) = plt.subplots(
    2,
    1,
    figsize=(11, 9),
    dpi=200,
    sharex=True,
    gridspec_kw={"height_ratios": [2.2, 1.3], "hspace": 0.05},
)

ax1.errorbar(
    uf_energy,
    uf_data,
    xerr=uf_energy_err,
    yerr=uf_data_err,
    fmt='o',
    ms=2,
    elinewidth=0.8,
    color='black',
    alpha=0.7,
    label='Unfolded data',
)
ax1.step(uf_energy, uf_model, where='mid', color='C1', lw=1.8, label='Unfolded model')
ax1.set_yscale("log")
ax1.set_ylabel(uf_y_label, fontsize=12)
ax1.set_title(f"Unfolded spectrum + native blind search ({selected_interval})", fontsize=13)
ax1.grid(alpha=0.3)
ax1.legend(loc='best')

ax2.plot(
    df_plot["E_keV"],
    df_plot["Signed_Delta_Stat"],
    color="red",
    lw=2,
    label=r"Signed $\Delta\chi^2$ ($|\Delta\chi^2|\times$ sign(norm))",
)
ax2.plot(
    df_plot["E_keV"],
    df_plot["Delta_Stat"],
    color="gray",
    lw=1.0,
    alpha=0.5,
    label=r"Unsigned $\Delta\chi^2$ (reference)",
)
ax2.axhline(0, color="black", linestyle="--")
ax2.axhline(9, color="blue", linestyle=":", label="$\sim 3\sigma$ threshold (stat=9)")
ax2.axhline(-9, color="blue", linestyle=":", alpha=0.7)
ax2.set_xlim(E_min_keV, E_max_keV)
ax2.set_xlabel("Energy (keV)", fontsize=12)
ax2.set_ylabel(r"Signed $\Delta \chi^2$", fontsize=12)
ax2.grid(alpha=0.3)
ax2.legend(loc='best')

combined_plot_path = f"../products/0865600201/pn/spec/blind_search_{selected_interval}_native.png"
fig.tight_layout()
fig.savefig(combined_plot_path, dpi=300, bbox_inches='tight')
plt.show()
print(f"Saved combined subplot figure to: {combined_plot_path}")
# Out:
# /tmp/ipykernel_119497/2313971835.py:58: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Saved combined subplot figure to: ../products/0865600201/pn/spec/blind_search_Shallow_grp_native.png
